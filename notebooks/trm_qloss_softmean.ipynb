# %%
# define Meta data

# rec_loops = 3

# %% [markdown]
# ### Paper : Less is More: Recursive Reasoning with Tiny Networks, Oct 2025
# (https://arxiv.org/pdf/2510.04871)

# %% [markdown]
# ## Problem Overview
#
# We study Recursive Reasoning using Tiny Networks (TRM).
#
# Goal:
# Instead of increasing model size, we improve reasoning by:
# - reusing the same network multiple times
# - learning when to halt (q_halt)
#
# Key Idea:
# Compute multiple reasoning steps and decide dynamically when to stop.

# %%
import torch
from torch import nn

# %% [markdown]
# ## Model Architecture
#
# Components:
# - f: prediction head
# - q_halt: halting probability
#
# At each step t:
# 1. Model updates hidden state
# 2. Predicts output
# 3. Predicts whether to stop
#
# Final output depends on halting decision.

# %% [markdown]
# - Latent layers are not directly tracked in gradients.
# - They are used to refine the internal states.
# - This helps y and z move toward a stable representation before reasoning begins.

# %%
class TinyRModel(nn.Module):
  def __init__(self, hidden_size, vocab_size, inp_seq_len, out_seq_len):
    super().__init__()
    self.net = nn.Sequential(nn.Linear(hidden_size, hidden_size),
                              nn.ReLU(),
                              nn.Linear(hidden_size, hidden_size))

    self.embedding = nn.Embedding(vocab_size, hidden_size)
    self.input_proj = nn.Linear(inp_seq_len * hidden_size, hidden_size)


    self.out = nn.Linear(hidden_size, out_seq_len * vocab_size)
    self.halt = nn.Linear(hidden_size, 1)



  def latent(self, x, y, z, n=6):
      # Phase 1: update z (n times), x included
      for i in range(n):
          z = self.net(x + y + z)   # element-wise add → D-dim input

      # Phase 2: update y once, WITHOUT x
      y = self.net(y + z)           # same net, different input mix

      return y, z



  def forward(self, x, y, z, T, n=6):

    x = self.embedding(x)          # (B, L, H)
    x = x.view(x.size(0), -1)              # flatten
    x = self.input_proj(x)                 # (B, H)

    with torch.no_grad():
      for j in range(T-1):
        y, z= self.latent(x,y,z,n)

    y, z = self.latent(x, y, z, n)

    f_out = self.out(y)

    halt= self.halt(y) #calculate halt from y

    return f_out, halt, y, z

# %% [markdown]
# ### Dataset Description: Majority Task
# The dataset consists of fixed-length binary sequences ($0$s and $1$s). The goal is to classify the sequence based on the majority bit:
# - **Label 1**: If the count of $1$s is greater than the count of $0$s.
# - **Label 0**: If the count of $0$s is greater than the count of $1$s.
#
# Ties are excluded to ensure unambiguous labeling. This serves as a simple reasoning task for the recursive model.

# %%
# Simple dataset

# import torch
# import random
# from torch.utils.data import Dataset, DataLoader, random_split

# # ── config ───────────────────────────────────────────────────────────────
# hidden_size = 64
# batch_size  = 32
# device      = 'cuda' if torch.cuda.is_available() else 'cpu'
# vocab_size  = 2    # only real tokens: 0 and 1
# num_classes = 2    # label 0 or 1
# seq_len     = 15   # fixed length — no padding needed

# # ── dataset ──────────────────────────────────────────────────────────────
# class MajorityDataset(Dataset):
#     """
#     Fixed-length binary sequences, no padding, no masking.
#     Label = 1 if 1s are majority, 0 if 0s are majority.
#     Ties skipped to avoid ambiguous labels.
#     """
#     def __init__(self, num_samples=10000, seq_len=seq_len):
#         self.samples = self._generate(num_samples, seq_len)

#     def _generate(self, n, seq_len):
#         samples = []
#         while len(samples) < n:
#             seq   = [random.randint(0, 1) for _ in range(seq_len)]
#             ones  = sum(seq)
#             zeros = seq_len - ones
#             if ones == zeros:       # skip ties
#                 continue
#             label = 1 if ones > zeros else 0
#             samples.append((seq, label))
#         return samples

#     def __len__(self):
#         return len(self.samples)

#     def __getitem__(self, idx):
#         seq, label = self.samples[idx]
#         return {
#             "input_ids": torch.tensor(seq,   dtype=torch.long),
#             "labels":    torch.tensor(label, dtype=torch.long),
#         }

# # ── dataloaders ──────────────────────────────────────────────────────────
# dataset  = MajorityDataset(num_samples=10000)
# val_size = 1000
# train_set, val_set = random_split(dataset, [len(dataset) - val_size, val_size])

# train_loader = DataLoader(train_set, batch_size=batch_size, shuffle=True)
# val_loader   = DataLoader(val_set,   batch_size=batch_size, shuffle=False)

# %% [markdown]
# ## Addition Dataset

# %%
import torch
import random
from torch.utils.data import Dataset, DataLoader, random_split

def generate_pair(num_digits):
    a = random.randint(10**(num_digits-1), 10**num_digits - 1)
    b = random.randint(10**(num_digits-1), 10**num_digits - 1)
    return str(a), str(b)


operands_a, operands_b = [], []

for sample_idx in range(50000):
    num_a, num_b = generate_pair(num_digits=4)

    operands_a.append(num_a)
    operands_b.append(num_b)

# %%
dataset = []

for num_a, num_b in zip(operands_a, operands_b):

    input_sequence = list(num_a) + ['+'] + list(num_b)

    rev_a = list(reversed(num_a))
    rev_b = list(reversed(num_b))

    num_digits = len(num_a)

    result_digits = []
    carry_sequence = []

    carry = 0
    current_chain_length = 0
    max_carry_chain = 0

    for digit_a, digit_b in zip(rev_a, rev_b):

        digit_sum = int(digit_a) + int(digit_b) + carry

        output_digit = digit_sum % 10
        new_carry = digit_sum // 10

        result_digits.append(output_digit)
        carry_sequence.append(new_carry)

        if new_carry == 1:
            current_chain_length += 1
            max_carry_chain = max(max_carry_chain, current_chain_length)
        else:
            current_chain_length = 0

        carry = new_carry

    if carry > 0:
        result_digits.append(carry)

    final_output = list(reversed(result_digits))

    data = {
        'input': input_sequence,
        'output': final_output,
        'num_digits': num_digits,
        'carry_sequence': carry_sequence,
        'max_carry_chain': max_carry_chain
    }

    dataset.append(data)

print(dataset[0], len(dataset))
# Out:
# {'input': ['2', '1', '0', '5', '+', '8', '7', '8', '5'], 'output': [1, 0, 8, 9, 0], 'num_digits': 4, 'carry_sequence': [1, 0, 0, 1], 'max_carry_chain': 1} 50000

# %%
import torch
from torch.utils.data import Dataset

device = 'cuda' if torch.cuda.is_available() else 'cpu'

PAD_TOKEN = 11
PLUS_TOKEN = 10

inp_seq_len = 9
out_seq_len = 5


class AdditionDataset(Dataset):
    def __init__(self, dataset_list, max_input_len=inp_seq_len, max_output_len=out_seq_len):
        self.data = dataset_list
        self.max_input_len = max_input_len
        self.max_output_len = max_output_len

    def pad(self, seq, max_len, pad_value=PAD_TOKEN):
        return seq + [pad_value] * (max_len - len(seq))

    def encode_input(self, input_seq):
        return [
            int(x) if x != '+' else PLUS_TOKEN
            for x in input_seq
        ]

    def __len__(self):
        return len(self.data)

    def __getitem__(self, idx):
        sample = self.data[idx]

        input_ids = self.encode_input(sample['input'])
        labels    = sample['output']

        input_ids = self.pad(input_ids, self.max_input_len)
        labels    = self.pad(labels, self.max_output_len)

        return {
            "input_ids": torch.tensor(input_ids, dtype=torch.long),
            "labels": torch.tensor(labels, dtype=torch.long)
        }



hidden_size = 256

batch_size  = 32

vocab_size = 12

dataset = AdditionDataset(dataset)

val_size = 5000
train_size = len(dataset) - val_size

train_set, val_set = random_split(dataset, [train_size, val_size])

train_loader = DataLoader(train_set, batch_size=batch_size, shuffle=True)
val_loader   = DataLoader(val_set,   batch_size=batch_size)

# %% [markdown]
# ## Loss Function
#
# We use two losses:
#
# 1. Prediction Loss:
#    Cross entropy between prediction and label
#
# 2. Halting Loss:
#    Binary classification:
#    - 1 if prediction correct
#    - 0 otherwise
#
# This encourages:
# → stop when correct
# → continue when wrong

# %%
# def Q_LOSS(q_halt, f_out, y_true):
#     print(f_out.argmax(dim=-1), y_true)
#     target = f_out.argmax(dim=-1) == y_true
#     print(target)
#     return F.binary_cross_entropy_with_logits(q_halt, target)

# %%
# def model_training_and_validation_with_mask(c, T, n_sup):
#     model = TinyRModel(hidden_size, vocab_size, inp_seq_len=12, out_seq_len=6).to(device)
#     optimizer = torch.optim.Adam(model.parameters(), lr=1e-4)

#     print('PAD_TOKEN: ', PAD_TOKEN)
#     criterion = nn.CrossEntropyLoss(reduction='none', ignore_index=PAD_TOKEN)

#     running_loss = 0
#     running_q = 0

#     print('Training Logs ------ \n')
#     model.train()
#     for step, batch in enumerate(train_loader):
#         input_ids = batch['input_ids'].to(device)
#         labels = batch['labels'].to(device)
#         batch_size_curr = input_ids.size(0)
#         seq_len = labels.size(1)

#         active_mask = torch.ones(batch_size_curr, dtype=torch.bool, device=device)

#         x = input_ids
#         y = torch.zeros(batch_size_curr, hidden_size, device=device)
#         z = torch.zeros(batch_size_curr, hidden_size, device=device)

#         step_loss = step_q = 0
#         overall_loss = torch.tensor(0.0, device=device)

#         for i in range(n_sup):
#             y_new, z_new, halt, out = model(x, y, z, halt, out)


#             y = torch.where(active_mask.unsqueeze(1), y_new.detach(), y)
#             z = torch.where(active_mask.unsqueeze(1), z_new.detach(), y)

#             loss_per_token = crossntropy(f_out.view(-1, vocab_size), labels.view(-1))

# %%
import torch.nn.functional as F

def Q_LOSS(q_halt, f_out, y_true, pad_token=PAD_TOKEN):
    preds = f_out.argmax(dim=-1)                     # (B, L)
    correct = (preds == y_true).float()              # (B, L)
    non_pad = (y_true != pad_token).float()          # (B, L)
    target = (correct * non_pad).sum(dim=-1, keepdim=True) / (non_pad.sum(dim=-1, keepdim=True) + 1e-8)
    return F.binary_cross_entropy_with_logits(q_halt, target)

# %%
### calude generate this diagnostic script but i guided it what to do


from torch.utils.data import Subset


def diagnostic_per_sup_step(c=0.1, T=3, n_sup=16, num_epochs=100):
    model = TinyRModel(hidden_size, vocab_size, inp_seq_len = inp_seq_len, out_seq_len = out_seq_len).to(device)
    optimizer = torch.optim.Adam(model.parameters(), lr=1e-4)
    criterion_noreduce = nn.CrossEntropyLoss(reduction='none', ignore_index=PAD_TOKEN)
    criterion = nn.CrossEntropyLoss(ignore_index=PAD_TOKEN)

    diag_subset = Subset(train_set, range(max(10000, len(train_set))))
    diag_loader = DataLoader(diag_subset, batch_size=64, shuffle=True)

    model.train()

    for epoch in range(num_epochs):
        print(f'processing epoch {epoch} \n')
        for batch in diag_loader:
            input_ids = batch['input_ids'].to(device)
            labels = batch['labels'].to(device)
            batch_size_curr = input_ids.size(0)
            seq_len = labels.size(1)

            x = input_ids
            y = torch.zeros(batch_size_curr, hidden_size, device=device)
            z = torch.zeros(batch_size_curr, hidden_size, device=device)

            total_loss = torch.tensor(0.0, device=device)

            for i in range(n_sup):
                f_out, halt, y_new, z_new = model(x, y, z, T, n=6)
                y = y_new.detach()
                z = z_new.detach()

                loss = criterion(f_out.view(-1, vocab_size), labels.view(-1))

                # Add Q-loss with the SAME formula as masked run
                seq_len = labels.size(1)
                q_loss = Q_LOSS(halt, f_out.view(-1, seq_len, vocab_size), labels)

                total_loss += (loss + c * q_loss.squeeze())  # same coefficient as masked run

            total_loss /= n_sup

            optimizer.zero_grad()
            total_loss.backward()
            optimizer.step()

        # --- Detailed per-step evaluation every 10 epochs ---
        if epoch % 10 == 0:
            model.eval()
            with torch.no_grad():
                test_batch = next(iter(diag_loader))
                input_ids = test_batch['input_ids'].to(device)
                labels = test_batch['labels'].to(device)
                batch_size_curr = input_ids.size(0)
                seq_len = labels.size(1)

                x = input_ids
                y_state = torch.zeros(batch_size_curr, hidden_size, device=device)
                z_state = torch.zeros(batch_size_curr, hidden_size, device=device)

                print(f"Epoch {epoch:3d} | CE per supervision step (same batch):")

                prev_ce = None
                for i in range(n_sup):
                    f_out, halt, y_new, z_new = model(x, y_state, z_state, T, n=6)
                    y_state = y_new.detach()
                    z_state = z_new.detach()

                    print(f"sup_step_{i+1} | mean={halt.mean().item():.3f} "
                          f"std={halt.std().item():.3f} "
                          f"median={halt.median().item():.3f} "
                          f"%>0={(halt > 0).float().mean().item():.1%} "
                          f"first5={halt[:5].squeeze().tolist()}")

                    # Per-token CE (ignoring padding)
                    loss_per_token = criterion_noreduce(f_out.view(-1, vocab_size), labels.view(-1))
                    # Reshape to (Batch, Seq)
                    loss_grid = loss_per_token.view(batch_size_curr, seq_len)
                    non_pad = (labels != PAD_TOKEN)
                    # Per-sample CE on real tokens only
                    ce_per_sample = (loss_grid * non_pad.float()).sum(dim=1) / non_pad.float().sum(dim=1).clamp(min=1)
                    avg_ce = ce_per_sample.mean().item()

                    # Token accuracy EXCLUDING padding
                    preds = f_out.view(-1, seq_len, vocab_size).argmax(dim=-1)
                    correct = (preds == labels) & non_pad
                    token_acc = correct.sum().item() / non_pad.sum().item()

                    # Exact match: all NON-PAD positions correct
                    per_sample_correct = ((preds == labels) | ~non_pad).all(dim=-1).float()
                    exact = per_sample_correct.mean().item()

                    # CE change from previous step
                    delta = ""
                    if prev_ce is not None:
                        diff = prev_ce - avg_ce
                        delta = f"| Delta: {diff:+.4f} {'IMPROVED' if diff > 0.01 else 'FLAT' if diff > -0.01 else 'WORSE'}"
                    prev_ce = avg_ce

                    # Prediction diversity
                    pred_strings = [tuple(p.cpu().tolist()) for p in preds]
                    unique_preds = len(set(pred_strings))

                    print(f"  Sup {i:2d} | CE: {avg_ce:.4f} | TokAcc: {token_acc:.4f} | Exact: {exact:.4f} | Unique: {unique_preds}/{batch_size_curr} {delta}")

                print()

                # Show sample predictions at LAST sup step (non-pad only)
                if epoch % 50 == 0:
                    print(f"--- Sample Predictions at Epoch {epoch}, Last Sup Step ---")
                    for j in range(min(10, batch_size_curr)):
                        mask = non_pad[j]
                        pred_real = preds[j][mask].cpu().tolist()
                        true_real = labels[j][mask].cpu().tolist()
                        inp = input_ids[j].cpu().tolist()
                        # Decode input nicely
                        inp_str = ''.join([str(t) if t < 10 else '+' if t == 10 else '' for t in inp])
                        match = "MATCH" if pred_real == true_real else "WRONG"
                        print(f"  {inp_str} | Pred: {pred_real} True: {true_real} {match}")
                    print()

            model.train()

    # --- Final comprehensive breakdown ---
    print("=" * 70)
    print("FINAL BREAKDOWN: All Supervision Steps (Last Epoch)")
    print("=" * 70)

    model.eval()
    with torch.no_grad():
        test_batch = next(iter(diag_loader))
        input_ids = test_batch['input_ids'].to(device)
        labels = test_batch['labels'].to(device)
        batch_size_curr = input_ids.size(0)
        seq_len = labels.size(1)

        x = input_ids
        y_state = torch.zeros(batch_size_curr, hidden_size, device=device)
        z_state = torch.zeros(batch_size_curr, hidden_size, device=device)

        non_pad = (labels != PAD_TOKEN)

        for i in range(n_sup):
            f_out, halt, y_new, z_new = model(x, y_state, z_state, T, n=6)
            y_state = y_new.detach()
            z_state = z_new.detach()

            loss_per_token = criterion_noreduce(f_out.view(-1, vocab_size), labels.view(-1))
            loss_grid = loss_per_token.view(batch_size_curr, seq_len)
            ce_per_sample = (loss_grid * non_pad.float()).sum(dim=1) / non_pad.float().sum(dim=1).clamp(min=1)
            avg_ce = ce_per_sample.mean().item()

            preds = f_out.view(-1, seq_len, vocab_size).argmax(dim=-1)
            correct = (preds == labels) & non_pad
            token_acc = correct.sum().item() / non_pad.sum().item()

            per_sample_correct = ((preds == labels) | ~non_pad).all(dim=-1).float()
            exact = per_sample_correct.mean().item()

            pred_strings = [tuple(p.cpu().tolist()) for p in preds]
            unique_preds = len(set(pred_strings))

            q_mean = halt.mean().item()

            print(f"  Sup {i:2d} | CE: {avg_ce:.4f} | TokAcc: {token_acc:.4f} | Exact: {exact:.4f} | Unique: {unique_preds}/{batch_size_curr} | Q: {q_mean:.4f}")

        # Final sample predictions
        print(f"\n--- Final Sample Predictions ---")
        for j in range(min(10, batch_size_curr)):
            mask = non_pad[j]
            pred_real = preds[j][mask].cpu().tolist()
            true_real = labels[j][mask].cpu().tolist()
            inp = input_ids[j].cpu().tolist()
            inp_str = ''.join([str(t) if t < 10 else '+' if t == 10 else '' for t in inp])
            match = "MATCH" if pred_real == true_real else "WRONG"
            print(f"  {inp_str} | Pred: {pred_real} True: {true_real} {match}")

    return model

model = diagnostic_per_sup_step(c=0.1, T=3, n_sup=16, num_epochs=100)
# Out:
# processing epoch 0
#
# Epoch   0 | CE per supervision step (same batch):
# sup_step_1 | mean=-0.505 std=0.225 median=-0.408 %>0=0.0% first5=[-0.4124372899532318, -0.8408550024032593, -0.8252072334289551, -0.3700857162475586, -0.3055182695388794]
#   Sup  0 | CE: 1.7461 | TokAcc: 0.3356 | Exact: 0.0000 | Unique: 37/64
# sup_step_2 | mean=-0.509 std=0.349 median=-0.308 %>0=0.0% first5=[-0.18920747935771942, -1.0488280057907104, -1.034751057624817, -0.24434232711791992, -0.2401829957962036]
#   Sup  1 | CE: 1.6715 | TokAcc: 0.3523 | Exact: 0.0000 | Unique: 33/64 | Delta: +0.0745 IMPROVED
# sup_step_3 | mean=-0.526 std=0.380 median=-0.330 %>0=0.0% first5=[-0.17124690115451813, -1.1077646017074585, -1.1072587966918945, -0.30159395933151245, -0.2395230531692505]
#   Sup  2 | CE: 1.6569 | TokAcc: 0.3658 | Exact: 0.0000 | Unique: 36/64 | Delta: +0.0146 IMPROVED
# sup_step_4 | mean=-0.531 std=0.389 median=-0.367 %>0=0.0% first5=[-0.16340766847133636, -1.1192479133605957, -1.132420301437378, -0.39430221915245056, -0.23456227779388428]
#   Sup  3 | CE: 1.6606 | TokAcc: 0.3557 | Exact: 0.0000 | Unique: 33/64 | Delta: -0.0037 FLAT
# sup_step_5 | mean=-0.533 std=0.391 median=-0.379 %>0=0.0% first5=[-0.16574010252952576, -1.1198545694351196, -1.1406338214874268, -0.3911348879337311, -0.23409056663513184]
#   Sup  4 | CE: 1.6627 | TokAcc: 0.3557 | Exact: 0.0000 | Unique: 32/64 | Delta: -0.0021 FLAT
# sup_step_6 | mean=-0.534 std=0.392 median=-0.374 %>0=0.0% first5=[-0.16770561039447784, -1.1185017824172974, -1.1432669162750244, -0.37393370270729065, -0.2351166009902954]
#   Sup  5 | CE: 1.6632 | TokAcc: 0.3557 | Exact: 0.0000 | Unique: 34/64 | Delta: -0.0006 FLAT
# sup_step_7 | mean=-0.534 std=0.392 median=-0.367 %>0=0.0% first5=[-0.16866251826286316, -1.1174224615097046, -1.144091010093689, -0.36672502756118774, -0.23657310009002686]
#   Sup  6 | CE: 1.6636 | TokAcc: 0.3557 | Exact: 0.0000 | Unique: 33/64 | Delta: -0.0004 FLAT
# sup_step_8 | mean=-0.534 std=0.392 median=-0.368 %>0=0.0% first5=[-0.16908201575279236, -1.1168218851089478, -1.1443418264389038, -0.3681085705757141, -0.23714494705200195]
#   Sup  7 | CE: 1.6640 | TokAcc: 0.3557 | Exact: 0.0000 | Unique: 33/64 | Delta: -0.0004 FLAT
# sup_step_9 | mean=-0.534 std=0.392 median=-0.370 %>0=0.0% first5=[-0.16923363506793976, -1.1165333986282349, -1.1444135904312134, -0.37072235345840454, -0.23736047744750977]
#   Sup  8 | CE: 1.6643 | TokAcc: 0.3557 | Exact: 0.0000 | Unique: 33/64 | Delta: -0.0003 FLAT
# sup_step_10 | mean=-0.534 std=0.392 median=-0.371 %>0=0.0% first5=[-0.16927744448184967, -1.116405725479126, -1.144431710243225, -0.37136852741241455, -0.2374427318572998]
#   Sup  9 | CE: 1.6645 | TokAcc: 0.3557 | Exact: 0.0000 | Unique: 33/64 | Delta: -0.0002 FLAT
# sup_step_11 | mean=-0.534 std=0.392 median=-0.371 %>0=0.0% first5=[-0.16928526759147644, -1.1163524389266968, -1.1444357633590698, -0.3709627091884613, -0.2374742031097412]
#   Sup 10 | CE: 1.6646 | TokAcc: 0.3557 | Exact: 0.0000 | Unique: 33/64 | Delta: -0.0001 FLAT
# sup_step_12 | mean=-0.534 std=0.392 median=-0.371 %>0=0.0% first5=[-0.16928507387638092, -1.1163305044174194, -1.1444361209869385, -0.37062233686447144, -0.2374868392944336]
#   Sup 11 | CE: 1.6646 | TokAcc: 0.3557 | Exact: 0.0000 | Unique: 33/64 | Delta: -0.0000 FLAT
# sup_step_13 | mean=-0.534 std=0.392 median=-0.371 %>0=0.0% first5=[-0.16928306221961975, -1.1163212060928345, -1.1444358825683594, -0.37060216069221497, -0.23749113082885742]
#   Sup 12 | CE: 1.6646 | TokAcc: 0.3557 | Exact: 0.0000 | Unique: 33/64 | Delta: -0.0000 FLAT
# sup_step_14 | mean=-0.534 std=0.392 median=-0.371 %>0=0.0% first5=[-0.16928213834762573, -1.1163184642791748, -1.1444355249404907, -0.37068209052085876, -0.23749232292175293]
#   Sup 13 | CE: 1.6646 | TokAcc: 0.3557 | Exact: 0.0000 | Unique: 33/64 | Delta: -0.0000 FLAT
# sup_step_15 | mean=-0.534 std=0.392 median=-0.371 %>0=0.0% first5=[-0.16928143799304962, -1.1163171529769897, -1.1444355249404907, -0.3707183599472046, -0.23749315738677979]
#   Sup 14 | CE: 1.6647 | TokAcc: 0.3557 | Exact: 0.0000 | Unique: 33/64 | Delta: -0.0000 FLAT
# sup_step_16 | mean=-0.534 std=0.392 median=-0.371 %>0=0.0% first5=[-0.16928163170814514, -1.1163169145584106, -1.1444354057312012, -0.37071162462234497, -0.23749375343322754]
#   Sup 15 | CE: 1.6647 | TokAcc: 0.3557 | Exact: 0.0000 | Unique: 33/64 | Delta: -0.0000 FLAT
#
# --- Sample Predictions at Epoch 0, Last Sup Step ---
#   5420+6522 | Pred: [1, 1, 7, 5, 1] True: [1, 1, 9, 4, 2] WRONG
#   4678+3781 | Pred: [8, 2, 7, 3] True: [8, 4, 5, 9] WRONG
#   4795+1458 | Pred: [6, 2, 5, 9] True: [6, 2, 5, 3] WRONG
#   4987+9974 | Pred: [1, 5, 7, 7, 6] True: [1, 4, 9, 6, 1] WRONG
#   6988+6976 | Pred: [1, 3, 7, 7, 1] True: [1, 3, 9, 6, 4] WRONG
#   6294+3156 | Pred: [8, 3, 7, 5] True: [9, 4, 5, 0] WRONG
#   3962+8331 | Pred: [1, 1, 7, 7, 1] True: [1, 2, 2, 9, 3] WRONG
#   9174+1260 | Pred: [1, 0, 3, 7, 1] True: [1, 0, 4, 3, 4] WRONG
#   2963+3871 | Pred: [6, 2, 5, 9] True: [6, 8, 3, 4] WRONG
#   5566+4297 | Pred: [9, 0, 8, 5] True: [9, 8, 6, 3] WRONG
#
# processing epoch 1
#
# processing epoch 2
#
# processing epoch 3
#
# processing epoch 4
#
# processing epoch 5
#
# processing epoch 6
#
# processing epoch 7
#
# processing epoch 8
#
# processing epoch 9
#
# processing epoch 10
#
# Epoch  10 | CE per supervision step (same batch):
# sup_step_1 | mean=0.164 std=0.241 median=0.176 %>0=70.3% first5=[0.5489879846572876, 0.3688513934612274, -0.023080497980117798, 0.20986828207969666, 0.01575806736946106]
#   Sup  0 | CE: 1.2872 | TokAcc: 0.5103 | Exact: 0.0000 | Unique: 60/64
# sup_step_2 | mean=0.162 std=0.236 median=0.145 %>0=68.8% first5=[0.5319089889526367, 0.3448264002799988, -0.007743567228317261, 0.12991294264793396, 0.03337891399860382]
#   Sup  1 | CE: 1.1945 | TokAcc: 0.5655 | Exact: 0.0000 | Unique: 58/64 | Delta: +0.0926 IMPROVED
# sup_step_3 | mean=0.171 std=0.243 median=0.139 %>0=67.2% first5=[0.5563133955001831, 0.2922953963279724, -0.013303667306900024, 0.20807918906211853, 0.023456737399101257]
#   Sup  2 | CE: 1.1766 | TokAcc: 0.5621 | Exact: 0.0156 | Unique: 60/64 | Delta: +0.0179 IMPROVED
# sup_step_4 | mean=0.171 std=0.243 median=0.143 %>0=67.2% first5=[0.5560145378112793, 0.4022550880908966, -0.013016849756240845, 0.18261656165122986, 0.030590787529945374]
#   Sup  3 | CE: 1.1809 | TokAcc: 0.5586 | Exact: 0.0000 | Unique: 57/64 | Delta: -0.0042 FLAT
# sup_step_5 | mean=0.172 std=0.242 median=0.143 %>0=67.2% first5=[0.5448274612426758, 0.3834720551967621, -0.012897282838821411, 0.1872853934764862, 0.030166178941726685]
#   Sup  4 | CE: 1.1826 | TokAcc: 0.5655 | Exact: 0.0000 | Unique: 59/64 | Delta: -0.0017 FLAT
# sup_step_6 | mean=0.173 std=0.244 median=0.141 %>0=67.2% first5=[0.5485635995864868, 0.3838784396648407, -0.012884825468063354, 0.1878872811794281, 0.030044838786125183]
#   Sup  5 | CE: 1.1779 | TokAcc: 0.5586 | Exact: 0.0000 | Unique: 59/64 | Delta: +0.0046 FLAT
# sup_step_7 | mean=0.172 std=0.243 median=0.142 %>0=67.2% first5=[0.551260232925415, 0.408828467130661, -0.012903839349746704, 0.18828639388084412, 0.03007499873638153]
#   Sup  6 | CE: 1.1802 | TokAcc: 0.5621 | Exact: 0.0000 | Unique: 57/64 | Delta: -0.0023 FLAT
# sup_step_8 | mean=0.174 std=0.244 median=0.142 %>0=67.2% first5=[0.5491811037063599, 0.39824485778808594, -0.012898534536361694, 0.18780753016471863, 0.030076801776885986]
#   Sup  7 | CE: 1.1789 | TokAcc: 0.5621 | Exact: 0.0000 | Unique: 58/64 | Delta: +0.0013 FLAT
# sup_step_9 | mean=0.173 std=0.244 median=0.142 %>0=67.2% first5=[0.5489053726196289, 0.4028758406639099, -0.01289936900138855, 0.18800649046897888, 0.030075103044509888]
#   Sup  8 | CE: 1.1779 | TokAcc: 0.5655 | Exact: 0.0000 | Unique: 57/64 | Delta: +0.0010 FLAT
# sup_step_10 | mean=0.173 std=0.243 median=0.142 %>0=67.2% first5=[0.5499409437179565, 0.4083060622215271, -0.0128994882106781, 0.18796834349632263, 0.030075058341026306]
#   Sup  9 | CE: 1.1804 | TokAcc: 0.5621 | Exact: 0.0000 | Unique: 58/64 | Delta: -0.0024 FLAT
# sup_step_11 | mean=0.173 std=0.244 median=0.142 %>0=67.2% first5=[0.5496212244033813, 0.4020712971687317, -0.012899667024612427, 0.18797513842582703, 0.03007514774799347]
#   Sup 10 | CE: 1.1784 | TokAcc: 0.5655 | Exact: 0.0000 | Unique: 57/64 | Delta: +0.0020 FLAT
# sup_step_12 | mean=0.172 std=0.243 median=0.142 %>0=67.2% first5=[0.5492955446243286, 0.4049612581729889, -0.012899249792098999, 0.1879696547985077, 0.03007526695728302]
#   Sup 11 | CE: 1.1787 | TokAcc: 0.5621 | Exact: 0.0000 | Unique: 58/64 | Delta: -0.0003 FLAT
# sup_step_13 | mean=0.173 std=0.244 median=0.142 %>0=67.2% first5=[0.5495799779891968, 0.4064476788043976, -0.012899428606033325, 0.18797287344932556, 0.030074983835220337]
#   Sup 12 | CE: 1.1797 | TokAcc: 0.5621 | Exact: 0.0000 | Unique: 58/64 | Delta: -0.0010 FLAT
# sup_step_14 | mean=0.173 std=0.244 median=0.142 %>0=67.2% first5=[0.5496002435684204, 0.4038224518299103, -0.012899428606033325, 0.18797239661216736, 0.030075207352638245]
#   Sup 13 | CE: 1.1781 | TokAcc: 0.5655 | Exact: 0.0000 | Unique: 57/64 | Delta: +0.0015 FLAT
# sup_step_15 | mean=0.173 std=0.243 median=0.142 %>0=67.2% first5=[0.5494636297225952, 0.4052647650241852, -0.012899428606033325, 0.18797191977500916, 0.030075252056121826]
#   Sup 14 | CE: 1.1792 | TokAcc: 0.5621 | Exact: 0.0000 | Unique: 58/64 | Delta: -0.0011 FLAT
# sup_step_16 | mean=0.173 std=0.244 median=0.142 %>0=67.2% first5=[0.549514889717102, 0.4055558741092682, -0.0128994882106781, 0.18797215819358826, 0.030075550079345703]
#   Sup 15 | CE: 1.1790 | TokAcc: 0.5655 | Exact: 0.0000 | Unique: 58/64 | Delta: +0.0002 FLAT
#
# processing epoch 11
#
# processing epoch 12
#
# processing epoch 13
#
# processing epoch 14
#
# processing epoch 15
#
# processing epoch 16
#
# processing epoch 17
#
# processing epoch 18
#
# processing epoch 19
#
# processing epoch 20
#
# Epoch  20 | CE per supervision step (same batch):
# sup_step_1 | mean=0.831 std=0.205 median=0.815 %>0=100.0% first5=[0.6981396079063416, 0.8161764144897461, 0.6875427961349487, 0.5698092579841614, 0.7103692293167114]
#   Sup  0 | CE: 0.9163 | TokAcc: 0.6107 | Exact: 0.0312 | Unique: 64/64
# sup_step_2 | mean=0.807 std=0.218 median=0.783 %>0=100.0% first5=[0.7115697860717773, 0.7831060886383057, 0.5140881538391113, 0.6468291282653809, 0.5264923572540283]
#   Sup  1 | CE: 0.7843 | TokAcc: 0.7081 | Exact: 0.0781 | Unique: 64/64 | Delta: +0.1321 IMPROVED
# sup_step_3 | mean=0.822 std=0.216 median=0.789 %>0=100.0% first5=[0.7248178720474243, 0.855090856552124, 0.5838102102279663, 0.6616209745407104, 0.5645347833633423]
#   Sup  2 | CE: 0.7617 | TokAcc: 0.6913 | Exact: 0.0781 | Unique: 64/64 | Delta: +0.0226 IMPROVED
# sup_step_4 | mean=0.820 std=0.218 median=0.813 %>0=100.0% first5=[0.7234625816345215, 0.813461422920227, 0.5438016653060913, 0.637946367263794, 0.5529202222824097]
#   Sup  3 | CE: 0.7643 | TokAcc: 0.6879 | Exact: 0.0781 | Unique: 64/64 | Delta: -0.0026 FLAT
# sup_step_5 | mean=0.817 std=0.216 median=0.797 %>0=100.0% first5=[0.7251504063606262, 0.8136993646621704, 0.5410287380218506, 0.6450095772743225, 0.5512634515762329]
#   Sup  4 | CE: 0.7496 | TokAcc: 0.6946 | Exact: 0.0781 | Unique: 64/64 | Delta: +0.0146 IMPROVED
# sup_step_6 | mean=0.821 std=0.217 median=0.831 %>0=100.0% first5=[0.7244406938552856, 0.8473537564277649, 0.5534642934799194, 0.6466400623321533, 0.5565974712371826]
#   Sup  5 | CE: 0.7560 | TokAcc: 0.6980 | Exact: 0.0781 | Unique: 64/64 | Delta: -0.0064 FLAT
# sup_step_7 | mean=0.818 std=0.217 median=0.791 %>0=100.0% first5=[0.724764883518219, 0.7891191244125366, 0.5229443311691284, 0.6441611647605896, 0.5518300533294678]
#   Sup  6 | CE: 0.7540 | TokAcc: 0.6946 | Exact: 0.0781 | Unique: 64/64 | Delta: +0.0020 FLAT
# sup_step_8 | mean=0.819 std=0.216 median=0.830 %>0=100.0% first5=[0.7247411012649536, 0.8662130832672119, 0.5420874357223511, 0.6452990770339966, 0.5526891946792603]
#   Sup  7 | CE: 0.7502 | TokAcc: 0.6980 | Exact: 0.0781 | Unique: 64/64 | Delta: +0.0037 FLAT
# sup_step_9 | mean=0.821 std=0.218 median=0.790 %>0=100.0% first5=[0.7247453927993774, 0.7749549150466919, 0.5319498777389526, 0.6450675129890442, 0.554008960723877]
#   Sup  8 | CE: 0.7532 | TokAcc: 0.6946 | Exact: 0.0781 | Unique: 64/64 | Delta: -0.0030 FLAT
# sup_step_10 | mean=0.818 std=0.216 median=0.814 %>0=100.0% first5=[0.7247508764266968, 0.8717072010040283, 0.5337486267089844, 0.6450016498565674, 0.5522183179855347]
#   Sup  9 | CE: 0.7507 | TokAcc: 0.6946 | Exact: 0.0781 | Unique: 64/64 | Delta: +0.0025 FLAT
# sup_step_11 | mean=0.818 std=0.217 median=0.790 %>0=100.0% first5=[0.7247477769851685, 0.7726660966873169, 0.5363450050354004, 0.6450793743133545, 0.5533530712127686]
#   Sup 10 | CE: 0.7513 | TokAcc: 0.6946 | Exact: 0.0781 | Unique: 64/64 | Delta: -0.0006 FLAT
# sup_step_12 | mean=0.823 std=0.219 median=0.834 %>0=100.0% first5=[0.7247492074966431, 0.8670121431350708, 0.5277270078659058, 0.6450455784797668, 0.5531110763549805]
#   Sup 11 | CE: 0.7529 | TokAcc: 0.6946 | Exact: 0.0781 | Unique: 64/64 | Delta: -0.0016 FLAT
# sup_step_13 | mean=0.816 std=0.216 median=0.790 %>0=100.0% first5=[0.724748969078064, 0.7809805274009705, 0.5344107151031494, 0.6450519561767578, 0.5527821779251099]
#   Sup 12 | CE: 0.7488 | TokAcc: 0.6946 | Exact: 0.0781 | Unique: 64/64 | Delta: +0.0041 FLAT
# sup_step_14 | mean=0.819 std=0.216 median=0.833 %>0=100.0% first5=[0.7247494459152222, 0.854225754737854, 0.530960202217102, 0.6450538635253906, 0.5532305240631104]
#   Sup 13 | CE: 0.7520 | TokAcc: 0.6946 | Exact: 0.0781 | Unique: 64/64 | Delta: -0.0032 FLAT
# sup_step_15 | mean=0.822 std=0.219 median=0.796 %>0=100.0% first5=[0.7247496843338013, 0.7960439920425415, 0.5307339429855347, 0.6450515985488892, 0.5529513359069824]
#   Sup 14 | CE: 0.7512 | TokAcc: 0.6946 | Exact: 0.0781 | Unique: 64/64 | Delta: +0.0008 FLAT
# sup_step_16 | mean=0.817 std=0.216 median=0.832 %>0=100.0% first5=[0.7247494459152222, 0.8377217054367065, 0.532896876335144, 0.6450526714324951, 0.5530033111572266]
#   Sup 15 | CE: 0.7500 | TokAcc: 0.6946 | Exact: 0.0781 | Unique: 64/64 | Delta: +0.0011 FLAT
#
# processing epoch 21
#
# processing epoch 22
#
# processing epoch 23
#
# processing epoch 24
#
# processing epoch 25
#
# processing epoch 26
#
# processing epoch 27
#
# processing epoch 28
#
# processing epoch 29
#
# processing epoch 30
#
# Epoch  30 | CE per supervision step (same batch):
# sup_step_1 | mean=1.187 std=0.187 median=1.156 %>0=100.0% first5=[1.170225739479065, 0.9936373233795166, 1.1140227317810059, 1.5497359037399292, 1.0335370302200317]
#   Sup  0 | CE: 0.6872 | TokAcc: 0.7440 | Exact: 0.0938 | Unique: 63/64
# sup_step_2 | mean=1.199 std=0.180 median=1.222 %>0=100.0% first5=[1.1633235216140747, 1.0668563842773438, 1.2221784591674805, 1.4982870817184448, 1.082017183303833]
#   Sup  1 | CE: 0.6132 | TokAcc: 0.7645 | Exact: 0.0938 | Unique: 63/64 | Delta: +0.0741 IMPROVED
# sup_step_3 | mean=1.191 std=0.174 median=1.174 %>0=100.0% first5=[1.1663658618927002, 1.0410242080688477, 1.1745685338974, 1.514245629310608, 1.118636131286621]
#   Sup  2 | CE: 0.5823 | TokAcc: 0.7816 | Exact: 0.1094 | Unique: 63/64 | Delta: +0.0308 IMPROVED
# sup_step_4 | mean=1.191 std=0.174 median=1.193 %>0=100.0% first5=[1.1682072877883911, 1.046141505241394, 1.2007746696472168, 1.5038429498672485, 1.1070324182510376]
#   Sup  3 | CE: 0.5859 | TokAcc: 0.7782 | Exact: 0.1094 | Unique: 63/64 | Delta: -0.0036 FLAT
# sup_step_5 | mean=1.193 std=0.174 median=1.184 %>0=100.0% first5=[1.167048692703247, 1.046007513999939, 1.1895982027053833, 1.5038585662841797, 1.097883701324463]
#   Sup  4 | CE: 0.5840 | TokAcc: 0.7747 | Exact: 0.0938 | Unique: 63/64 | Delta: +0.0019 FLAT
# sup_step_6 | mean=1.194 std=0.174 median=1.193 %>0=100.0% first5=[1.167352557182312, 1.0457046031951904, 1.1929553747177124, 1.5046629905700684, 1.1005412340164185]
#   Sup  5 | CE: 0.5852 | TokAcc: 0.7747 | Exact: 0.0938 | Unique: 63/64 | Delta: -0.0012 FLAT
# sup_step_7 | mean=1.192 std=0.174 median=1.188 %>0=100.0% first5=[1.1672855615615845, 1.0458208322525024, 1.1922439336776733, 1.5047541856765747, 1.1034139394760132]
#   Sup  6 | CE: 0.5857 | TokAcc: 0.7747 | Exact: 0.0938 | Unique: 63/64 | Delta: -0.0005 FLAT
# sup_step_8 | mean=1.191 std=0.174 median=1.188 %>0=100.0% first5=[1.1672966480255127, 1.045820951461792, 1.1922965049743652, 1.5047192573547363, 1.1029795408248901]
#   Sup  7 | CE: 0.5851 | TokAcc: 0.7747 | Exact: 0.0938 | Unique: 63/64 | Delta: +0.0005 FLAT
# sup_step_9 | mean=1.192 std=0.174 median=1.188 %>0=100.0% first5=[1.1672981977462769, 1.0458041429519653, 1.1923471689224243, 1.5047128200531006, 1.1021689176559448]
#   Sup  8 | CE: 0.5853 | TokAcc: 0.7747 | Exact: 0.0938 | Unique: 63/64 | Delta: -0.0001 FLAT
# sup_step_10 | mean=1.195 std=0.174 median=1.192 %>0=100.0% first5=[1.16729736328125, 1.0458112955093384, 1.1923103332519531, 1.5047115087509155, 1.1023283004760742]
#   Sup  9 | CE: 0.5846 | TokAcc: 0.7747 | Exact: 0.0938 | Unique: 63/64 | Delta: +0.0007 FLAT
# sup_step_11 | mean=1.192 std=0.173 median=1.191 %>0=100.0% first5=[1.1672965288162231, 1.0458111763000488, 1.1923257112503052, 1.5047122240066528, 1.1025612354278564]
#   Sup 10 | CE: 0.5852 | TokAcc: 0.7747 | Exact: 0.0938 | Unique: 63/64 | Delta: -0.0005 FLAT
# sup_step_12 | mean=1.190 std=0.174 median=1.184 %>0=100.0% first5=[1.1672974824905396, 1.0458099842071533, 1.192322015762329, 1.5047119855880737, 1.102520227432251]
#   Sup 11 | CE: 0.5855 | TokAcc: 0.7747 | Exact: 0.0938 | Unique: 63/64 | Delta: -0.0004 FLAT
# sup_step_13 | mean=1.191 std=0.174 median=1.184 %>0=100.0% first5=[1.167297601699829, 1.0458102226257324, 1.1923221349716187, 1.5047115087509155, 1.102454662322998]
#   Sup 12 | CE: 0.5849 | TokAcc: 0.7747 | Exact: 0.0938 | Unique: 63/64 | Delta: +0.0007 FLAT
# sup_step_14 | mean=1.194 std=0.174 median=1.192 %>0=100.0% first5=[1.1672977209091187, 1.0458104610443115, 1.1923223733901978, 1.504711627960205, 1.1024659872055054]
#   Sup 13 | CE: 0.5847 | TokAcc: 0.7747 | Exact: 0.0938 | Unique: 63/64 | Delta: +0.0002 FLAT
# sup_step_15 | mean=1.193 std=0.173 median=1.192 %>0=100.0% first5=[1.1672972440719604, 1.0458104610443115, 1.1923221349716187, 1.5047118663787842, 1.102483868598938]
#   Sup 14 | CE: 0.5852 | TokAcc: 0.7747 | Exact: 0.0938 | Unique: 63/64 | Delta: -0.0005 FLAT
# sup_step_16 | mean=1.191 std=0.174 median=1.185 %>0=100.0% first5=[1.1672972440719604, 1.0458104610443115, 1.1923223733901978, 1.5047123432159424, 1.1024812459945679]
#   Sup 15 | CE: 0.5853 | TokAcc: 0.7747 | Exact: 0.0938 | Unique: 63/64 | Delta: -0.0001 FLAT
#
# processing epoch 31
#
# processing epoch 32
#
# processing epoch 33
#
# processing epoch 34
#
# processing epoch 35
#
# processing epoch 36
#
# processing epoch 37
#
# processing epoch 38
#
# processing epoch 39
#
# processing epoch 40
#
# Epoch  40 | CE per supervision step (same batch):
# sup_step_1 | mean=2.789 std=0.515 median=2.802 %>0=100.0% first5=[3.449069023132324, 2.773855209350586, 1.743387222290039, 3.0971508026123047, 3.000176429748535]
#   Sup  0 | CE: 0.3593 | TokAcc: 0.8615 | Exact: 0.4531 | Unique: 63/64
# sup_step_2 | mean=3.130 std=0.462 median=3.125 %>0=100.0% first5=[3.4698987007141113, 3.847579002380371, 2.782471179962158, 3.319047451019287, 3.134683132171631]
#   Sup  1 | CE: 0.1038 | TokAcc: 0.9628 | Exact: 0.8281 | Unique: 64/64 | Delta: +0.2555 IMPROVED
# sup_step_3 | mean=3.157 std=0.452 median=3.099 %>0=100.0% first5=[3.5794100761413574, 3.8153693675994873, 2.9350733757019043, 3.2614598274230957, 3.146585702896118]
#   Sup  2 | CE: 0.0914 | TokAcc: 0.9730 | Exact: 0.8750 | Unique: 64/64 | Delta: +0.0124 IMPROVED
# sup_step_4 | mean=3.137 std=0.438 median=3.110 %>0=100.0% first5=[3.5905277729034424, 3.873229742050171, 3.0671584606170654, 3.356405735015869, 3.13987398147583]
#   Sup  3 | CE: 0.1020 | TokAcc: 0.9764 | Exact: 0.8906 | Unique: 64/64 | Delta: -0.0106 WORSE
# sup_step_5 | mean=3.140 std=0.425 median=3.082 %>0=100.0% first5=[3.588186025619507, 3.90259051322937, 3.1121737957000732, 3.290459394454956, 3.1450788974761963]
#   Sup  4 | CE: 0.0892 | TokAcc: 0.9797 | Exact: 0.9062 | Unique: 64/64 | Delta: +0.0128 IMPROVED
# sup_step_6 | mean=3.145 std=0.429 median=3.115 %>0=100.0% first5=[3.592369556427002, 3.8890604972839355, 3.1166348457336426, 3.328589677810669, 3.143482208251953]
#   Sup  5 | CE: 0.1003 | TokAcc: 0.9696 | Exact: 0.8594 | Unique: 64/64 | Delta: -0.0111 WORSE
# sup_step_7 | mean=3.142 std=0.424 median=3.084 %>0=100.0% first5=[3.5918378829956055, 3.883514881134033, 3.1278958320617676, 3.308969020843506, 3.144599437713623]
#   Sup  6 | CE: 0.0913 | TokAcc: 0.9730 | Exact: 0.8750 | Unique: 64/64 | Delta: +0.0090 FLAT
# sup_step_8 | mean=3.142 std=0.420 median=3.118 %>0=100.0% first5=[3.5911948680877686, 3.8853278160095215, 3.137032985687256, 3.319047451019287, 3.1444873809814453]
#   Sup  7 | CE: 0.0957 | TokAcc: 0.9730 | Exact: 0.8750 | Unique: 64/64 | Delta: -0.0044 FLAT
# sup_step_9 | mean=3.137 std=0.442 median=3.095 %>0=100.0% first5=[3.591069221496582, 3.8881070613861084, 3.14060115814209, 3.3145334720611572, 3.1444058418273926]
#   Sup  8 | CE: 0.0853 | TokAcc: 0.9730 | Exact: 0.8750 | Unique: 64/64 | Delta: +0.0104 IMPROVED
# sup_step_10 | mean=3.145 std=0.425 median=3.118 %>0=100.0% first5=[3.591423988342285, 3.886918783187866, 3.1422994136810303, 3.3162589073181152, 3.1444106101989746]
#   Sup  9 | CE: 0.0906 | TokAcc: 0.9730 | Exact: 0.8750 | Unique: 64/64 | Delta: -0.0053 FLAT
# sup_step_11 | mean=3.127 std=0.433 median=3.098 %>0=100.0% first5=[3.5913829803466797, 3.8864192962646484, 3.143441677093506, 3.315803289413452, 3.1444172859191895]
#   Sup 10 | CE: 0.0866 | TokAcc: 0.9797 | Exact: 0.9062 | Unique: 64/64 | Delta: +0.0040 FLAT
# sup_step_12 | mean=3.154 std=0.428 median=3.118 %>0=100.0% first5=[3.591266632080078, 3.886714458465576, 3.144005537033081, 3.3157315254211426, 3.1444168090820312]
#   Sup 11 | CE: 0.0843 | TokAcc: 0.9730 | Exact: 0.8750 | Unique: 64/64 | Delta: +0.0024 FLAT
# sup_step_13 | mean=3.143 std=0.426 median=3.099 %>0=100.0% first5=[3.591297149658203, 3.886831283569336, 3.144254207611084, 3.3159849643707275, 3.1444168090820312]
#   Sup 12 | CE: 0.0875 | TokAcc: 0.9764 | Exact: 0.8906 | Unique: 64/64 | Delta: -0.0033 FLAT
# sup_step_14 | mean=3.140 std=0.424 median=3.118 %>0=100.0% first5=[3.59133243560791, 3.886763334274292, 3.144399881362915, 3.315741777420044, 3.1444168090820312]
#   Sup 13 | CE: 0.0859 | TokAcc: 0.9764 | Exact: 0.8906 | Unique: 64/64 | Delta: +0.0017 FLAT
# sup_step_15 | mean=3.140 std=0.432 median=3.098 %>0=100.0% first5=[3.5913162231445312, 3.8867251873016357, 3.144477605819702, 3.3159382343292236, 3.144416570663452]
#   Sup 14 | CE: 0.0876 | TokAcc: 0.9764 | Exact: 0.8906 | Unique: 64/64 | Delta: -0.0017 FLAT
# sup_step_16 | mean=3.138 std=0.434 median=3.118 %>0=100.0% first5=[3.5913076400756836, 3.886744737625122, 3.144514560699463, 3.3158092498779297, 3.1444168090820312]
#   Sup 15 | CE: 0.0848 | TokAcc: 0.9730 | Exact: 0.8750 | Unique: 64/64 | Delta: +0.0028 FLAT
#
# processing epoch 41
#
# processing epoch 42
#
# processing epoch 43
#
# processing epoch 44
#
# processing epoch 45
#
# processing epoch 46
#
# processing epoch 47
#
# processing epoch 48
#
# processing epoch 49
#
# processing epoch 50
#
# Epoch  50 | CE per supervision step (same batch):
# sup_step_1 | mean=2.269 std=0.887 median=2.387 %>0=100.0% first5=[2.9160568714141846, 1.2054953575134277, 2.8780417442321777, 2.8743016719818115, 2.196244955062866]
#   Sup  0 | CE: 0.3377 | TokAcc: 0.8930 | Exact: 0.6562 | Unique: 63/64
# sup_step_2 | mean=2.866 std=0.797 median=2.880 %>0=100.0% first5=[2.2298567295074463, 2.6296067237854004, 2.7081995010375977, 3.491854429244995, 2.3605034351348877]
#   Sup  1 | CE: 0.1709 | TokAcc: 0.9465 | Exact: 0.7656 | Unique: 63/64 | Delta: +0.1668 IMPROVED
# sup_step_3 | mean=2.853 std=0.851 median=2.868 %>0=100.0% first5=[2.5581557750701904, 2.436232805252075, 2.868274211883545, 3.3319575786590576, 2.156599998474121]
#   Sup  2 | CE: 0.1768 | TokAcc: 0.9498 | Exact: 0.8281 | Unique: 63/64 | Delta: -0.0059 FLAT
# sup_step_4 | mean=2.860 std=0.773 median=2.867 %>0=100.0% first5=[2.669233798980713, 2.5256779193878174, 2.8699917793273926, 3.29345965385437, 2.072263717651367]
#   Sup  3 | CE: 0.1121 | TokAcc: 0.9666 | Exact: 0.8594 | Unique: 63/64 | Delta: +0.0647 IMPROVED
# sup_step_5 | mean=2.852 std=0.777 median=2.839 %>0=100.0% first5=[2.594146966934204, 2.5612452030181885, 2.8390426635742188, 3.2776944637298584, 2.1052775382995605]
#   Sup  4 | CE: 0.1052 | TokAcc: 0.9599 | Exact: 0.8438 | Unique: 63/64 | Delta: +0.0069 FLAT
# sup_step_6 | mean=2.841 std=0.782 median=2.847 %>0=100.0% first5=[2.626770257949829, 2.534930944442749, 2.846985101699829, 3.2803404331207275, 2.116790294647217]
#   Sup  5 | CE: 0.1110 | TokAcc: 0.9599 | Exact: 0.8594 | Unique: 63/64 | Delta: -0.0058 FLAT
# sup_step_7 | mean=2.860 std=0.795 median=2.853 %>0=100.0% first5=[2.6179709434509277, 2.5472848415374756, 2.8494362831115723, 3.2813973426818848, 2.1064367294311523]
#   Sup  6 | CE: 0.1224 | TokAcc: 0.9599 | Exact: 0.8281 | Unique: 63/64 | Delta: -0.0114 WORSE
# sup_step_8 | mean=2.832 std=0.809 median=2.835 %>0=100.0% first5=[2.6120173931121826, 2.5490007400512695, 2.848719596862793, 3.2821247577667236, 2.1061720848083496]
#   Sup  7 | CE: 0.1299 | TokAcc: 0.9599 | Exact: 0.8438 | Unique: 63/64 | Delta: -0.0075 FLAT
# sup_step_9 | mean=2.847 std=0.803 median=2.849 %>0=100.0% first5=[2.616361618041992, 2.5451951026916504, 2.8485207557678223, 3.2819650173187256, 2.1080379486083984]
#   Sup  8 | CE: 0.1096 | TokAcc: 0.9599 | Exact: 0.8281 | Unique: 63/64 | Delta: +0.0202 IMPROVED
# sup_step_10 | mean=2.840 std=0.796 median=2.845 %>0=100.0% first5=[2.615018844604492, 2.547701597213745, 2.8482773303985596, 3.2818758487701416, 2.107576370239258]
#   Sup  9 | CE: 0.1194 | TokAcc: 0.9565 | Exact: 0.8281 | Unique: 63/64 | Delta: -0.0097 FLAT
# sup_step_11 | mean=2.854 std=0.782 median=2.843 %>0=100.0% first5=[2.615173101425171, 2.547455072402954, 2.8484115600585938, 3.2818939685821533, 2.1073780059814453]
#   Sup 10 | CE: 0.1079 | TokAcc: 0.9666 | Exact: 0.8594 | Unique: 63/64 | Delta: +0.0114 IMPROVED
# sup_step_12 | mean=2.861 std=0.770 median=2.841 %>0=100.0% first5=[2.6154792308807373, 2.546802520751953, 2.848493814468384, 3.2818968296051025, 2.1075098514556885]
#   Sup 11 | CE: 0.0921 | TokAcc: 0.9666 | Exact: 0.8438 | Unique: 63/64 | Delta: +0.0159 IMPROVED
# sup_step_13 | mean=2.835 std=0.798 median=2.842 %>0=100.0% first5=[2.615286111831665, 2.5474061965942383, 2.8484609127044678, 3.2818963527679443, 2.1074986457824707]
#   Sup 12 | CE: 0.1459 | TokAcc: 0.9599 | Exact: 0.8438 | Unique: 63/64 | Delta: -0.0538 WORSE
# sup_step_14 | mean=2.851 std=0.795 median=2.848 %>0=100.0% first5=[2.6153440475463867, 2.5471928119659424, 2.8484365940093994, 3.2818939685821533, 2.1074812412261963]
#   Sup 13 | CE: 0.1134 | TokAcc: 0.9632 | Exact: 0.8438 | Unique: 63/64 | Delta: +0.0324 IMPROVED
# sup_step_15 | mean=2.830 std=0.817 median=2.842 %>0=100.0% first5=[2.6153337955474854, 2.5471408367156982, 2.8484408855438232, 3.281895875930786, 2.107487916946411]
#   Sup 14 | CE: 0.1454 | TokAcc: 0.9565 | Exact: 0.8438 | Unique: 63/64 | Delta: -0.0320 WORSE
# sup_step_16 | mean=2.841 std=0.792 median=2.842 %>0=100.0% first5=[2.6153225898742676, 2.5472567081451416, 2.848447799682617, 3.281895875930786, 2.1074883937835693]
#   Sup 15 | CE: 0.0999 | TokAcc: 0.9599 | Exact: 0.8438 | Unique: 63/64 | Delta: +0.0456 IMPROVED
#
# --- Sample Predictions at Epoch 50, Last Sup Step ---
#   2508+5041 | Pred: [7, 5, 4, 9] True: [7, 5, 4, 9] MATCH
#   7833+1500 | Pred: [9, 3, 3, 3] True: [9, 3, 3, 3] MATCH
#   1829+5787 | Pred: [7, 6, 1, 6] True: [7, 6, 1, 6] MATCH
#   4398+7859 | Pred: [1, 2, 2, 5, 7] True: [1, 2, 2, 5, 7] MATCH
#   7216+1131 | Pred: [8, 3, 4, 7] True: [8, 3, 4, 7] MATCH
#   2816+2054 | Pred: [4, 8, 7, 0] True: [4, 8, 7, 0] MATCH
#   2915+8890 | Pred: [1, 1, 8, 0, 5] True: [1, 1, 8, 0, 5] MATCH
#   5485+6977 | Pred: [1, 2, 4, 6, 2] True: [1, 2, 4, 6, 2] MATCH
#   2107+3941 | Pred: [6, 0, 4, 8] True: [6, 0, 4, 8] MATCH
#   8840+8528 | Pred: [1, 7, 3, 6, 8] True: [1, 7, 3, 6, 8] MATCH
#
# processing epoch 51
#
# processing epoch 52
#
# processing epoch 53
#
# processing epoch 54
#
# processing epoch 55
#
# processing epoch 56
#
# processing epoch 57
#
# processing epoch 58
#
# processing epoch 59
#
# processing epoch 60
#
# Epoch  60 | CE per supervision step (same batch):
# sup_step_1 | mean=4.130 std=0.849 median=4.144 %>0=100.0% first5=[2.6753201484680176, 3.502830743789673, 3.166468381881714, 2.9102141857147217, 3.1979479789733887]
#   Sup  0 | CE: 0.1277 | TokAcc: 0.9492 | Exact: 0.8125 | Unique: 64/64
# sup_step_2 | mean=4.630 std=0.757 median=4.656 %>0=100.0% first5=[4.785257339477539, 3.710894823074341, 3.6678686141967773, 4.052343368530273, 4.295933723449707]
#   Sup  1 | CE: 0.0386 | TokAcc: 0.9898 | Exact: 0.9531 | Unique: 64/64 | Delta: +0.0891 IMPROVED
# sup_step_3 | mean=4.676 std=0.732 median=4.692 %>0=100.0% first5=[4.375657558441162, 3.8126237392425537, 3.714143991470337, 4.0399956703186035, 4.3261027336120605]
#   Sup  2 | CE: 0.0320 | TokAcc: 0.9966 | Exact: 0.9844 | Unique: 64/64 | Delta: +0.0066 FLAT
# sup_step_4 | mean=4.659 std=0.737 median=4.749 %>0=100.0% first5=[4.349368095397949, 3.810007333755493, 3.694704532623291, 4.152376651763916, 4.267577171325684]
#   Sup  3 | CE: 0.0223 | TokAcc: 1.0000 | Exact: 1.0000 | Unique: 64/64 | Delta: +0.0096 FLAT
# sup_step_5 | mean=4.668 std=0.735 median=4.711 %>0=100.0% first5=[4.38638162612915, 3.7970287799835205, 3.693679094314575, 4.128422737121582, 4.275699138641357]
#   Sup  4 | CE: 0.0227 | TokAcc: 1.0000 | Exact: 1.0000 | Unique: 64/64 | Delta: -0.0004 FLAT
# sup_step_6 | mean=4.666 std=0.735 median=4.722 %>0=100.0% first5=[4.3672380447387695, 3.794966459274292, 3.6953580379486084, 4.138722896575928, 4.2755818367004395]
#   Sup  5 | CE: 0.0232 | TokAcc: 1.0000 | Exact: 1.0000 | Unique: 64/64 | Delta: -0.0005 FLAT
# sup_step_7 | mean=4.667 std=0.737 median=4.709 %>0=100.0% first5=[4.3558549880981445, 3.7969067096710205, 3.6951916217803955, 4.1546502113342285, 4.274365425109863]
#   Sup  6 | CE: 0.0223 | TokAcc: 1.0000 | Exact: 1.0000 | Unique: 64/64 | Delta: +0.0009 FLAT
# sup_step_8 | mean=4.663 std=0.738 median=4.726 %>0=100.0% first5=[4.358602523803711, 3.796895980834961, 3.6951773166656494, 4.130537033081055, 4.274996280670166]
#   Sup  7 | CE: 0.0222 | TokAcc: 1.0000 | Exact: 1.0000 | Unique: 64/64 | Delta: +0.0001 FLAT
# sup_step_9 | mean=4.666 std=0.733 median=4.731 %>0=100.0% first5=[4.360764026641846, 3.7966325283050537, 3.6951863765716553, 4.151975631713867, 4.274803161621094]
#   Sup  8 | CE: 0.0223 | TokAcc: 1.0000 | Exact: 1.0000 | Unique: 64/64 | Delta: -0.0000 FLAT
# sup_step_10 | mean=4.663 std=0.733 median=4.720 %>0=100.0% first5=[4.360604763031006, 3.796674966812134, 3.6951804161071777, 4.1416730880737305, 4.27484130859375]
#   Sup  9 | CE: 0.0224 | TokAcc: 1.0000 | Exact: 1.0000 | Unique: 64/64 | Delta: -0.0002 FLAT
# sup_step_11 | mean=4.660 std=0.735 median=4.717 %>0=100.0% first5=[4.3603010177612305, 3.796710729598999, 3.695178985595703, 4.139726161956787, 4.274847507476807]
#   Sup 10 | CE: 0.0222 | TokAcc: 1.0000 | Exact: 1.0000 | Unique: 64/64 | Delta: +0.0002 FLAT
# sup_step_12 | mean=4.659 std=0.734 median=4.719 %>0=100.0% first5=[4.360286235809326, 3.7966980934143066, 3.695180892944336, 4.150291442871094, 4.274835109710693]
#   Sup 11 | CE: 0.0222 | TokAcc: 1.0000 | Exact: 1.0000 | Unique: 64/64 | Delta: +0.0000 FLAT
# sup_step_13 | mean=4.656 std=0.734 median=4.717 %>0=100.0% first5=[4.360321044921875, 3.796694040298462, 3.695178270339966, 4.136748313903809, 4.274843215942383]
#   Sup 12 | CE: 0.0223 | TokAcc: 1.0000 | Exact: 1.0000 | Unique: 64/64 | Delta: -0.0002 FLAT
# sup_step_14 | mean=4.657 std=0.733 median=4.708 %>0=100.0% first5=[4.360327243804932, 3.796696662902832, 3.695178270339966, 4.146646976470947, 4.274838447570801]
#   Sup 13 | CE: 0.0223 | TokAcc: 1.0000 | Exact: 1.0000 | Unique: 64/64 | Delta: +0.0000 FLAT
# sup_step_15 | mean=4.649 std=0.738 median=4.717 %>0=100.0% first5=[4.360324382781982, 3.7966959476470947, 3.6951797008514404, 4.143977165222168, 4.274842262268066]
#   Sup 14 | CE: 0.0222 | TokAcc: 1.0000 | Exact: 1.0000 | Unique: 64/64 | Delta: +0.0001 FLAT
# sup_step_16 | mean=4.653 std=0.737 median=4.718 %>0=100.0% first5=[4.360325813293457, 3.7966973781585693, 3.6951797008514404, 4.140210151672363, 4.274840354919434]
#   Sup 15 | CE: 0.0222 | TokAcc: 1.0000 | Exact: 1.0000 | Unique: 64/64 | Delta: -0.0001 FLAT
#
# processing epoch 61
#
# processing epoch 62
#
# processing epoch 63
#
# processing epoch 64
#
# processing epoch 65
#
# processing epoch 66
#
# processing epoch 67
#
# processing epoch 68
#
# processing epoch 69
#
# processing epoch 70
#
# Epoch  70 | CE per supervision step (same batch):
# sup_step_1 | mean=4.091 std=1.026 median=4.058 %>0=100.0% first5=[3.9348881244659424, 3.9061479568481445, 4.849973201751709, 5.622535228729248, 5.236553192138672]
#   Sup  0 | CE: 0.1350 | TokAcc: 0.9488 | Exact: 0.7969 | Unique: 64/64
# sup_step_2 | mean=4.668 std=0.828 median=4.730 %>0=100.0% first5=[5.1521806716918945, 4.214225769042969, 5.676312446594238, 5.235595703125, 6.155075550079346]
#   Sup  1 | CE: 0.0255 | TokAcc: 0.9966 | Exact: 0.9844 | Unique: 64/64 | Delta: +0.1095 IMPROVED
# sup_step_3 | mean=4.812 std=0.757 median=4.860 %>0=100.0% first5=[5.043289661407471, 4.611659049987793, 5.65885066986084, 5.269120693206787, 6.304094314575195]
#   Sup  2 | CE: 0.0219 | TokAcc: 0.9966 | Exact: 0.9844 | Unique: 64/64 | Delta: +0.0036 FLAT
# sup_step_4 | mean=4.782 std=0.753 median=4.681 %>0=100.0% first5=[5.226466655731201, 4.586310863494873, 5.560210704803467, 5.289993762969971, 6.3400068283081055]
#   Sup  3 | CE: 0.0272 | TokAcc: 0.9966 | Exact: 0.9844 | Unique: 64/64 | Delta: -0.0053 FLAT
# sup_step_5 | mean=4.765 std=0.775 median=4.674 %>0=100.0% first5=[5.239535808563232, 4.539670944213867, 5.631807804107666, 5.260470867156982, 6.32029390335083]
#   Sup  4 | CE: 0.0129 | TokAcc: 1.0000 | Exact: 1.0000 | Unique: 64/64 | Delta: +0.0143 IMPROVED
# sup_step_6 | mean=4.775 std=0.765 median=4.658 %>0=100.0% first5=[5.224258899688721, 4.546032905578613, 5.6265082359313965, 5.268407344818115, 6.310051918029785]
#   Sup  5 | CE: 0.0127 | TokAcc: 1.0000 | Exact: 1.0000 | Unique: 64/64 | Delta: +0.0001 FLAT
# sup_step_7 | mean=4.772 std=0.768 median=4.655 %>0=100.0% first5=[5.223169803619385, 4.54770040512085, 5.61229944229126, 5.275229454040527, 6.310375690460205]
#   Sup  6 | CE: 0.0126 | TokAcc: 1.0000 | Exact: 1.0000 | Unique: 64/64 | Delta: +0.0002 FLAT
# sup_step_8 | mean=4.767 std=0.771 median=4.652 %>0=100.0% first5=[5.224369525909424, 4.547602653503418, 5.619189739227295, 5.270627498626709, 6.3110127449035645]
#   Sup  7 | CE: 0.0135 | TokAcc: 1.0000 | Exact: 1.0000 | Unique: 64/64 | Delta: -0.0009 FLAT
# sup_step_9 | mean=4.765 std=0.771 median=4.653 %>0=100.0% first5=[5.2243781089782715, 4.547492504119873, 5.619884490966797, 5.271333694458008, 6.311089515686035]
#   Sup  8 | CE: 0.0135 | TokAcc: 1.0000 | Exact: 1.0000 | Unique: 64/64 | Delta: +0.0001 FLAT
# sup_step_10 | mean=4.764 std=0.771 median=4.654 %>0=100.0% first5=[5.224294662475586, 4.547357082366943, 5.6180925369262695, 5.272010326385498, 6.3111748695373535]
#   Sup  9 | CE: 0.0132 | TokAcc: 1.0000 | Exact: 1.0000 | Unique: 64/64 | Delta: +0.0003 FLAT
# sup_step_11 | mean=4.761 std=0.775 median=4.653 %>0=100.0% first5=[5.224294662475586, 4.547430992126465, 5.618528366088867, 5.271411418914795, 6.311220645904541]
#   Sup 10 | CE: 0.0132 | TokAcc: 1.0000 | Exact: 1.0000 | Unique: 64/64 | Delta: +0.0000 FLAT
# sup_step_12 | mean=4.755 std=0.783 median=4.653 %>0=100.0% first5=[5.22430419921875, 4.547427177429199, 5.618771076202393, 5.271590232849121, 6.311198711395264]
#   Sup 11 | CE: 0.0146 | TokAcc: 1.0000 | Exact: 1.0000 | Unique: 64/64 | Delta: -0.0014 FLAT
# sup_step_13 | mean=4.749 std=0.795 median=4.653 %>0=100.0% first5=[5.224303245544434, 4.547424793243408, 5.618603706359863, 5.271656513214111, 6.311181545257568]
#   Sup 12 | CE: 0.0157 | TokAcc: 0.9966 | Exact: 0.9844 | Unique: 64/64 | Delta: -0.0011 FLAT
# sup_step_14 | mean=4.748 std=0.795 median=4.653 %>0=100.0% first5=[5.224301815032959, 4.54742431640625, 5.618603706359863, 5.271566867828369, 6.311180591583252]
#   Sup 13 | CE: 0.0137 | TokAcc: 1.0000 | Exact: 1.0000 | Unique: 64/64 | Delta: +0.0020 FLAT
# sup_step_15 | mean=4.752 std=0.787 median=4.653 %>0=100.0% first5=[5.22430419921875, 4.547422885894775, 5.618638515472412, 5.271600246429443, 6.311183929443359]
#   Sup 14 | CE: 0.0124 | TokAcc: 1.0000 | Exact: 1.0000 | Unique: 64/64 | Delta: +0.0014 FLAT
# sup_step_16 | mean=4.756 std=0.779 median=4.653 %>0=100.0% first5=[5.224301338195801, 4.547423362731934, 5.6186299324035645, 5.271605014801025, 6.311185359954834]
#   Sup 15 | CE: 0.0121 | TokAcc: 1.0000 | Exact: 1.0000 | Unique: 64/64 | Delta: +0.0003 FLAT
#
# processing epoch 71
#
# processing epoch 72
#
# processing epoch 73
#
# processing epoch 74
#
# processing epoch 75
#
# processing epoch 76
#
# processing epoch 77
#
# processing epoch 78
#
# processing epoch 79
#
# processing epoch 80
#
# Epoch  80 | CE per supervision step (same batch):
# sup_step_1 | mean=5.946 std=1.341 median=6.105 %>0=100.0% first5=[6.840913772583008, 7.663035869598389, 4.121339797973633, 7.1131696701049805, 5.6472907066345215]
#   Sup  0 | CE: 0.0930 | TokAcc: 0.9661 | Exact: 0.8594 | Unique: 64/64
# sup_step_2 | mean=6.663 std=1.052 median=6.752 %>0=100.0% first5=[7.16239070892334, 8.648833274841309, 3.627047538757324, 6.841568946838379, 6.047645568847656]
#   Sup  1 | CE: 0.0234 | TokAcc: 0.9966 | Exact: 0.9844 | Unique: 64/64 | Delta: +0.0696 IMPROVED
# sup_step_3 | mean=6.712 std=1.085 median=6.844 %>0=100.0% first5=[7.128174304962158, 8.978564262390137, 3.2380778789520264, 6.863384246826172, 6.4437456130981445]
#   Sup  2 | CE: 0.0216 | TokAcc: 0.9932 | Exact: 0.9688 | Unique: 64/64 | Delta: +0.0018 FLAT
# sup_step_4 | mean=6.673 std=1.074 median=6.761 %>0=100.0% first5=[7.109104633331299, 9.048535346984863, 2.867645502090454, 6.8517680168151855, 6.362587928771973]
#   Sup  3 | CE: 0.0244 | TokAcc: 0.9932 | Exact: 0.9688 | Unique: 64/64 | Delta: -0.0028 FLAT
# sup_step_5 | mean=6.692 std=1.042 median=6.783 %>0=100.0% first5=[7.125861644744873, 8.999666213989258, 3.176459550857544, 6.8485426902771, 6.307135105133057]
#   Sup  4 | CE: 0.0130 | TokAcc: 0.9966 | Exact: 0.9844 | Unique: 64/64 | Delta: +0.0114 IMPROVED
# sup_step_6 | mean=6.691 std=1.053 median=6.840 %>0=100.0% first5=[7.125020980834961, 8.943450927734375, 2.9677395820617676, 6.852684020996094, 6.284400939941406]
#   Sup  5 | CE: 0.0133 | TokAcc: 0.9966 | Exact: 0.9844 | Unique: 64/64 | Delta: -0.0004 FLAT
# sup_step_7 | mean=6.680 std=1.068 median=6.821 %>0=100.0% first5=[7.1189093589782715, 8.9308500289917, 2.9957427978515625, 6.853256702423096, 6.262918472290039]
#   Sup  6 | CE: 0.0143 | TokAcc: 0.9966 | Exact: 0.9844 | Unique: 64/64 | Delta: -0.0010 FLAT
# sup_step_8 | mean=6.684 std=1.079 median=6.827 %>0=100.0% first5=[7.11973762512207, 8.951985359191895, 3.0321693420410156, 6.852459907531738, 6.261671543121338]
#   Sup  7 | CE: 0.0145 | TokAcc: 0.9966 | Exact: 0.9844 | Unique: 64/64 | Delta: -0.0002 FLAT
# sup_step_9 | mean=6.698 std=1.044 median=6.826 %>0=100.0% first5=[7.121808052062988, 8.9750394821167, 3.0515854358673096, 6.85233736038208, 6.268077850341797]
#   Sup  8 | CE: 0.0139 | TokAcc: 0.9966 | Exact: 0.9844 | Unique: 64/64 | Delta: +0.0006 FLAT
# sup_step_10 | mean=6.689 std=1.045 median=6.827 %>0=100.0% first5=[7.121159553527832, 8.980612754821777, 3.06422758102417, 6.852394104003906, 6.27157735824585]
#   Sup  9 | CE: 0.0137 | TokAcc: 0.9966 | Exact: 0.9844 | Unique: 64/64 | Delta: +0.0002 FLAT
# sup_step_11 | mean=6.675 std=1.065 median=6.666 %>0=100.0% first5=[7.120587348937988, 8.971840858459473, 3.055159568786621, 6.852407455444336, 6.272425651550293]
#   Sup 10 | CE: 0.0137 | TokAcc: 0.9966 | Exact: 0.9844 | Unique: 64/64 | Delta: +0.0001 FLAT
# sup_step_12 | mean=6.663 std=1.076 median=6.666 %>0=100.0% first5=[7.120926856994629, 8.962008476257324, 3.0476279258728027, 6.852417945861816, 6.271996021270752]
#   Sup 11 | CE: 0.0135 | TokAcc: 0.9966 | Exact: 0.9844 | Unique: 64/64 | Delta: +0.0002 FLAT
# sup_step_13 | mean=6.689 std=1.045 median=6.715 %>0=100.0% first5=[7.121060371398926, 8.959502220153809, 3.0448310375213623, 6.852416038513184, 6.271551132202148]
#   Sup 12 | CE: 0.0133 | TokAcc: 0.9966 | Exact: 0.9844 | Unique: 64/64 | Delta: +0.0001 FLAT
# sup_step_14 | mean=6.687 std=1.049 median=6.828 %>0=100.0% first5=[7.120919704437256, 8.963164329528809, 3.042912483215332, 6.85241174697876, 6.27138090133667]
#   Sup 13 | CE: 0.0138 | TokAcc: 0.9966 | Exact: 0.9844 | Unique: 64/64 | Delta: -0.0005 FLAT
# sup_step_15 | mean=6.671 std=1.074 median=6.828 %>0=100.0% first5=[7.120901107788086, 8.967361450195312, 3.0423200130462646, 6.852410793304443, 6.271368026733398]
#   Sup 14 | CE: 0.0138 | TokAcc: 0.9966 | Exact: 0.9844 | Unique: 64/64 | Delta: +0.0001 FLAT
# sup_step_16 | mean=6.669 std=1.085 median=6.828 %>0=100.0% first5=[7.120952129364014, 8.968484878540039, 3.042318344116211, 6.852412700653076, 6.271400451660156]
#   Sup 15 | CE: 0.0133 | TokAcc: 0.9966 | Exact: 0.9844 | Unique: 64/64 | Delta: +0.0004 FLAT
#
# processing epoch 81
#
# processing epoch 82
#
# processing epoch 83
#
# processing epoch 84
#
# processing epoch 85
#
# processing epoch 86
#
# processing epoch 87
#
# processing epoch 88
#
# processing epoch 89
#
# processing epoch 90
#
# Epoch  90 | CE per supervision step (same batch):
# sup_step_1 | mean=5.312 std=0.987 median=5.283 %>0=100.0% first5=[6.953802585601807, 5.3757004737854, 6.120808124542236, 5.429047584533691, 4.240599155426025]
#   Sup  0 | CE: 0.0560 | TokAcc: 0.9863 | Exact: 0.9375 | Unique: 64/64
# sup_step_2 | mean=5.783 std=0.862 median=5.783 %>0=100.0% first5=[7.304698944091797, 5.78291654586792, 6.486093044281006, 5.759066104888916, 5.223392486572266]
#   Sup  1 | CE: 0.0285 | TokAcc: 0.9931 | Exact: 0.9688 | Unique: 64/64 | Delta: +0.0275 IMPROVED
# sup_step_3 | mean=5.840 std=0.818 median=5.813 %>0=100.0% first5=[7.23567008972168, 5.968015193939209, 6.512796401977539, 6.027955055236816, 5.5546088218688965]
#   Sup  2 | CE: 0.0188 | TokAcc: 0.9966 | Exact: 0.9844 | Unique: 64/64 | Delta: +0.0097 FLAT
# sup_step_4 | mean=5.806 std=0.845 median=5.811 %>0=100.0% first5=[7.203774929046631, 5.971842288970947, 6.46135950088501, 6.07495641708374, 5.411378383636475]
#   Sup  3 | CE: 0.0194 | TokAcc: 0.9966 | Exact: 0.9844 | Unique: 64/64 | Delta: -0.0006 FLAT
# sup_step_5 | mean=5.813 std=0.840 median=5.818 %>0=100.0% first5=[7.197651386260986, 5.849836349487305, 6.49569845199585, 6.038596153259277, 5.335666656494141]
#   Sup  4 | CE: 0.0197 | TokAcc: 0.9966 | Exact: 0.9844 | Unique: 64/64 | Delta: -0.0003 FLAT
# sup_step_6 | mean=5.808 std=0.834 median=5.813 %>0=100.0% first5=[7.200209617614746, 5.812835216522217, 6.501877307891846, 5.97098970413208, 5.34108304977417]
#   Sup  5 | CE: 0.0197 | TokAcc: 0.9966 | Exact: 0.9844 | Unique: 64/64 | Delta: -0.0000 FLAT
# sup_step_7 | mean=5.811 std=0.836 median=5.826 %>0=100.0% first5=[7.200515270233154, 5.8675150871276855, 6.494324207305908, 5.989560127258301, 5.353485584259033]
#   Sup  6 | CE: 0.0195 | TokAcc: 0.9966 | Exact: 0.9844 | Unique: 64/64 | Delta: +0.0002 FLAT
# sup_step_8 | mean=5.818 std=0.833 median=5.821 %>0=100.0% first5=[7.200300216674805, 5.883665561676025, 6.4938459396362305, 6.014576435089111, 5.351657390594482]
#   Sup  7 | CE: 0.0195 | TokAcc: 0.9966 | Exact: 0.9844 | Unique: 64/64 | Delta: +0.0001 FLAT
# sup_step_9 | mean=5.816 std=0.828 median=5.824 %>0=100.0% first5=[7.200352668762207, 5.85385274887085, 6.495090961456299, 6.011595249176025, 5.348931789398193]
#   Sup  8 | CE: 0.0194 | TokAcc: 0.9966 | Exact: 0.9844 | Unique: 64/64 | Delta: +0.0000 FLAT
# sup_step_10 | mean=5.811 std=0.825 median=5.826 %>0=100.0% first5=[7.2003655433654785, 5.851200580596924, 6.495287895202637, 5.999849796295166, 5.349754810333252]
#   Sup  9 | CE: 0.0195 | TokAcc: 0.9966 | Exact: 0.9844 | Unique: 64/64 | Delta: -0.0001 FLAT
# sup_step_11 | mean=5.811 std=0.829 median=5.824 %>0=100.0% first5=[7.200358867645264, 5.8672776222229, 6.495054721832275, 6.000176429748535, 5.350466251373291]
#   Sup 10 | CE: 0.0195 | TokAcc: 0.9966 | Exact: 0.9844 | Unique: 64/64 | Delta: +0.0000 FLAT
# sup_step_12 | mean=5.815 std=0.830 median=5.824 %>0=100.0% first5=[7.200357913970947, 5.865206241607666, 6.494967460632324, 6.00506067276001, 5.350244045257568]
#   Sup 11 | CE: 0.0194 | TokAcc: 0.9966 | Exact: 0.9844 | Unique: 64/64 | Delta: +0.0000 FLAT
# sup_step_13 | mean=5.817 std=0.834 median=5.825 %>0=100.0% first5=[7.200356483459473, 5.8568806648254395, 6.49502420425415, 6.005354881286621, 5.350081920623779]
#   Sup 12 | CE: 0.0195 | TokAcc: 0.9966 | Exact: 0.9844 | Unique: 64/64 | Delta: -0.0000 FLAT
# sup_step_14 | mean=5.816 std=0.835 median=5.824 %>0=100.0% first5=[7.200357913970947, 5.860010623931885, 6.495051383972168, 6.0033183097839355, 5.350146293640137]
#   Sup 13 | CE: 0.0195 | TokAcc: 0.9966 | Exact: 0.9844 | Unique: 64/64 | Delta: -0.0000 FLAT
# sup_step_15 | mean=5.814 std=0.831 median=5.824 %>0=100.0% first5=[7.200358867645264, 5.863851547241211, 6.495038032531738, 6.00294828414917, 5.350180625915527]
#   Sup 14 | CE: 0.0195 | TokAcc: 0.9966 | Exact: 0.9844 | Unique: 64/64 | Delta: -0.0000 FLAT
# sup_step_16 | mean=5.814 std=0.829 median=5.824 %>0=100.0% first5=[7.2003583908081055, 5.86121940612793, 6.495029926300049, 6.003790378570557, 5.350161075592041]
#   Sup 15 | CE: 0.0195 | TokAcc: 0.9966 | Exact: 0.9844 | Unique: 64/64 | Delta: -0.0000 FLAT
#
# processing epoch 91
#
# processing epoch 92
#
# processing epoch 93
#
# processing epoch 94
#
# processing epoch 95
#
# processing epoch 96
#
# processing epoch 97
#
# processing epoch 98
#
# processing epoch 99
#
# ======================================================================
# FINAL BREAKDOWN: All Supervision Steps (Last Epoch)
# ======================================================================
#   Sup  0 | CE: 0.7125 | TokAcc: 0.8707 | Exact: 0.5469 | Unique: 64/64 | Q: 2.5838
#   Sup  1 | CE: 0.8006 | TokAcc: 0.8810 | Exact: 0.6562 | Unique: 64/64 | Q: 3.2578
#   Sup  2 | CE: 0.7449 | TokAcc: 0.8810 | Exact: 0.6094 | Unique: 64/64 | Q: 3.3081
#   Sup  3 | CE: 0.7361 | TokAcc: 0.8878 | Exact: 0.6250 | Unique: 64/64 | Q: 3.2435
#   Sup  4 | CE: 0.7360 | TokAcc: 0.8878 | Exact: 0.6094 | Unique: 64/64 | Q: 3.2151
#   Sup  5 | CE: 0.7354 | TokAcc: 0.8912 | Exact: 0.6250 | Unique: 64/64 | Q: 3.2371
#   Sup  6 | CE: 0.7138 | TokAcc: 0.8912 | Exact: 0.6250 | Unique: 64/64 | Q: 3.2486
#   Sup  7 | CE: 0.6958 | TokAcc: 0.8878 | Exact: 0.6250 | Unique: 64/64 | Q: 3.2388
#   Sup  8 | CE: 0.6977 | TokAcc: 0.8844 | Exact: 0.6094 | Unique: 64/64 | Q: 3.2385
#   Sup  9 | CE: 0.7078 | TokAcc: 0.8844 | Exact: 0.6094 | Unique: 64/64 | Q: 3.2464
#   Sup 10 | CE: 0.7214 | TokAcc: 0.8878 | Exact: 0.6250 | Unique: 64/64 | Q: 3.2460
#   Sup 11 | CE: 0.7366 | TokAcc: 0.8912 | Exact: 0.6250 | Unique: 64/64 | Q: 3.2404
#   Sup 12 | CE: 0.7413 | TokAcc: 0.8912 | Exact: 0.6250 | Unique: 64/64 | Q: 3.2418
#   Sup 13 | CE: 0.7324 | TokAcc: 0.8878 | Exact: 0.6094 | Unique: 64/64 | Q: 3.2396
#   Sup 14 | CE: 0.7086 | TokAcc: 0.8912 | Exact: 0.6250 | Unique: 64/64 | Q: 3.2350
#   Sup 15 | CE: 0.6915 | TokAcc: 0.8878 | Exact: 0.6250 | Unique: 64/64 | Q: 3.2426
#
# --- Final Sample Predictions ---
#   7248+4119 | Pred: [1, 0, 3, 6, 7] True: [1, 1, 3, 6, 7] WRONG
#   9860+9858 | Pred: [1, 9, 7, 1, 7] True: [1, 9, 7, 1, 8] WRONG
#   1899+4975 | Pred: [6, 8, 7, 4] True: [6, 8, 7, 4] MATCH
#   8436+7000 | Pred: [1, 5, 4, 3, 6] True: [1, 5, 4, 3, 6] MATCH
#   5883+2577 | Pred: [8, 4, 6, 0] True: [8, 4, 6, 0] MATCH
#   2863+7349 | Pred: [1, 0, 2, 1, 2] True: [1, 0, 2, 1, 2] MATCH
#   5681+8219 | Pred: [1, 3, 9, 9, 9] True: [1, 3, 9, 0, 0] WRONG
#   1364+7643 | Pred: [9, 0, 0, 7] True: [9, 0, 0, 7] MATCH
#   7097+8451 | Pred: [1, 5, 5, 4, 8] True: [1, 5, 5, 4, 8] MATCH
#   9917+1923 | Pred: [1, 1, 8, 3, 9] True: [1, 1, 8, 4, 0] WRONG

# %%
# ============================================================================
# Q-LOSS AND HALT MECHANISM: STEP-BY-STEP DEBUGGING JOURNEY
# 4-digit addition with TRM, single-head soft-mean Q-loss
# ============================================================================


# ----------------------------------------------------------------------------
# STEP 1: THE INITIAL ILLUSION OF SUCCESS
# ----------------------------------------------------------------------------
# Trained masked run for 100 epochs. CE dropped to ~0.008, Q-loss to ~0.20,
# avg_steps went from 5 down to 1. On the surface this looked like the model
# was learning to halt early once it had the answer figured out.
#
# The framing was: "model got smart, learned it only needs one step,
# adaptive halting working as designed."


# ----------------------------------------------------------------------------
# STEP 2: avg_steps = 1.0 IS NOT EFFICIENT HALTING, IT IS COLLAPSE
# ----------------------------------------------------------------------------
# At epoch 10, val accuracy was only 2.5% but halt was already firing at
# step 1 for 100% of validation samples. By epoch 30, val accuracy was 18%.
# Step-1 halting was happening LONG before the model had learned anything.
#
# This means recursion across supervision steps was never actually used.
# The model learned 4-digit addition entirely through the depth of one
# forward pass (T*n + 1 = 19 net evaluations). The halt head became
# vestigial - always saying "stop now" regardless of correctness.


# ----------------------------------------------------------------------------
# STEP 3: METRIC FIX - avg_steps WAS PER-BATCH-MAX, NOT PER-SAMPLE-MEAN
# ----------------------------------------------------------------------------
# The avg_steps metric was computed using when the loop breaks (when ALL
# samples halt). That gives the per-batch maximum, not the per-sample mean.
#
# Fixed by tracking halt_step per sample, then computing distribution stats:
# mean, median, %step1, %never_halted, full distribution. This gave us the
# real picture - at epoch 10, %step1 was already 88.9%.


# ----------------------------------------------------------------------------
# STEP 4: BUG IN Q_LOSS - PAD TOKENS WERE INFLATING THE TARGET
# ----------------------------------------------------------------------------
# The soft-mean target was computed over ALL positions including pad.
# When the model learned to predict PAD at pad positions, those matches
# counted as "correct", artificially inflating the target value.
#
# Concretely: a 4-digit answer (5 positions, 1 pad) where 2 of 4 real
# digits are right has true token accuracy 2/4 = 0.5, but the soft-mean
# computed it as 3/5 = 0.6, pushing halt logit harder toward firing.
#
# Fixed by masking pad positions in the target computation. But this was
# not the root cause - it was a symptom of the deeper target-design issue.


# ----------------------------------------------------------------------------
# STEP 5: WORKED OUT THE GRADIENT DYNAMICS PRECISELY
# ----------------------------------------------------------------------------
# Q-loss is binary cross-entropy on halt logit h with target t.
# Even though we never call sigmoid in the code, BCE-with-logits applies
# it internally.
#
# The gradient on h is: dL/dh = sigmoid(h) - t
# The optimizer subtracts the gradient, so h moves toward logit(t).
#
# Initial state: h is near 0 (random init), so sigmoid(h) is near 0.5.
# Gradient direction depends on whether target is above or below 0.5:
#
#     t < 0.5: gradient is positive, h decreases, halt does not fire
#     t = 0.5: gradient is zero, h stays put
#     t > 0.5: gradient is negative, h increases, halt fires
#
# The decision rule "halt > 0" is equivalent to "sigmoid(halt) > 0.5"
# because sigmoid is monotonic and sigmoid(0) = 0.5.
#
# So halt fires when target crosses 0.5. With soft-mean target, this means
# halt fires when token accuracy crosses 0.5. But we want halt to fire when
# the WHOLE answer is right (EM = 1.0), not when half the tokens are right.
#
# The semantic mismatch: target measures partial correctness, decision rule
# expects full correctness. They were never aligned.


# ----------------------------------------------------------------------------
# STEP 6: TRIED A "BISTABILITY" FRAMEWORK - FALSIFIED BY DATA
# ----------------------------------------------------------------------------
# Hypothesis: same Q-loss might converge to opposite policies in different
# regimes. With masked training (loop breaks on halt), the Q-head sees
# gradient mostly from early supervision steps. With diagnostic training
# (full rollout), it sees gradient from all 16 steps. Maybe these produce
# opposite equilibria - "always halt" vs "never halt".
#
# Tested by directly logging halt logits at epoch 0 in both regimes:
#     Masked epoch 0:     mean halt = -0.65, %>0 = 0%
#     Diagnostic epoch 0: mean halt = -0.66, %>0 = 0%
#
# Identical starting points. By epoch 10 BOTH regimes had halt logits
# above 0 with 100% firing. No bistability. The driver is target value
# crossing 0.5, not regime-specific gradient distribution.
#
# The simpler story holds: as token accuracy crosses 0.5 across training,
# the equilibrium logit crosses 0, and halt fires regardless of regime.


# ----------------------------------------------------------------------------
# STEP 7: SETTLED ON HYPOTHESIS C (BOTH PROBLEMS, INDEPENDENT)
# ----------------------------------------------------------------------------
#
# A) TASK SIMPLICITY:
#    Diagnostic run (no halt, full rollout) showed Sup 0 -> Sup 1 buys
#    ~19 EM points, but Sup 1 -> Sup 15 is flat. Recursion plateaus
#    after one refinement step. 4-digit addition is a fixed-depth
#    computation - one deep pass plus optionally one refinement is enough.
#
# B) Q-LOSS BROKEN:
#    Halt fires when token accuracy crosses 0.5, far below sequence-level
#    correctness. Step 6 showed this happens regardless of training regime.
#
# C) BOTH ARE TRUE AND THEY ARE INDEPENDENT:
#    On this task, fixing Q-loss alone gets you at most the bounded
#    recursion benefit (~19 EM points from one refinement step).
#    The two failures don't compound - they live in separate parts of
#    the system.


# ----------------------------------------------------------------------------
# STEP 8: EARLY ATTEMPT - SIMPLY CHANGE TARGET TO BINARY EM (REJECTED)
# ----------------------------------------------------------------------------
# Suggested: replace soft-mean with binary EM (1 if all tokens right, else 0).
#
# User rightly pushed back: this target is too aggressive for sequence
# tasks. Until any sample achieves EM, target is always 0 and the Q-head
# has no learning signal at all. Gradient sparsity becomes the new failure.
#
# This pushed us toward needing a warmup phase OR a softer continuous
# target that still tracks EM more closely than soft-mean.


# ----------------------------------------------------------------------------
# STEP 9: TRIED OPTION 1 - THRESHOLD SHIFT (halt > 1.5 instead of halt > 0)
# ----------------------------------------------------------------------------
# Reasoning: if halt > 0 corresponds to sigmoid(h) > 0.5 (token accuracy
# 50%), then halt > 1.5 corresponds to sigmoid(h) > 0.82 (token accuracy
# 82%). Closer to EM. Should delay halt firing until model is much better.
#
# Result over 90 epochs:
#     Phase 1 (epochs 0-30): halt logits below 1.5, halt rarely fires,
#         model uses all 5 supervision steps, val accuracy slowly builds
#         (0.06% -> 13.9%).
#     Phase 2 (epochs 30-90): token accuracy gets high enough that target
#         saturates near 1, halt logits explode past 1.5, collapse re-emerges.
#         Val accuracy reaches 99.24% by epoch 90.
#
# Key observation: halt logits across supervision steps within ONE forward
# pass are nearly identical (e.g., 0.84, 0.86, 0.86, 0.86, 0.86). The Q-head
# is not discriminating by latent state - it outputs roughly the same logit
# regardless of where in the recursion we are. This confirms the latent
# state hits a fixed point fast on this task.


# ----------------------------------------------------------------------------
# STEP 10: WHY THRESHOLD SHIFT IS NOT A REAL FIX (ONLY A DELAY)
# ----------------------------------------------------------------------------
# As the model improves, token accuracy approaches 1.
# As token accuracy approaches 1, soft-mean target approaches 1.
# As target approaches 1, the equilibrium halt logit logit(t) approaches +infinity.
# Any fixed threshold gets crossed eventually.
#
# So threshold shift only buys time. The 30-epoch delay let us train with
# full recursion early on, and that produced a better final model than V1
# (99% vs ?, where V1 was last measured at 87% at epoch 40 - we never ran
# V1 to epoch 90 to get a fair comparison).
#
# The improvement might come from "early recursion as curriculum" rather
# than from the threshold shift directly. We cannot tell without running
# V1 to the same epoch count.


# ----------------------------------------------------------------------------
# STEP 11: TWO REAL FIXES STILL UNTESTED
# ----------------------------------------------------------------------------
#
# OPTION 2: GEOMETRIC MEAN OF PROBABILITIES
#     Target = product of per-token probabilities, then take L-th root.
#     Any low-probability token drags target down sharply. Closer to EM
#     in spirit but stays continuous, so gradient signal is preserved.
#     Note: geometric mean of binary indicators reduces to binary EM,
#     so the useful version uses the model's softmax probabilities.
#
# OPTION 3: BINARY EM WITH WARMUP
#     Target is 1 only when full sequence is correct, else 0. This matches
#     what halt > 0 should mean exactly.
#     Solves gradient sparsity by training CE only for the first N epochs,
#     then turning on Q-loss once train EM exceeds some threshold (e.g. 5%).
#     Use train EM (not val EM) because that determines whether Q-targets
#     are non-trivial during training.


# ----------------------------------------------------------------------------
# STEP 12: WHY WE DID NOT GO WITH PAPER'S TWO-HEAD BOOTSTRAP
# ----------------------------------------------------------------------------
# Paper uses Q_halt and Q_continue, where Q_continue is bootstrapped from
# next step's Q-values. This gives non-stationary targets that don't
# saturate as model improves.
#
# We rejected this because TRM's appeal is single-head simplicity.
# Adding a second head defeats the architectural premise. The interesting
# research question is: can we keep one head and find a target that works?


# ----------------------------------------------------------------------------
# CORE LESSON FROM ALL OF THIS
# ----------------------------------------------------------------------------
# The Q-loss bug is not "target value too lenient" or "stationary target"
# or "regime-dependent bistability". Those framings were tried and refined
# or falsified.
#
# The real bug is a SEMANTIC MISMATCH between target and decision rule:
#     Target (soft-mean)       = expected token accuracy
#     Decision rule (halt > 0) = "model has solved the problem"
# These two quantities are not the same thing.
#
# Any honest fix must either:
#     (a) Change target to match the rule (binary EM with warmup, or
#         geometric mean of probabilities)
#     (b) Change the decision rule to match the target (threshold shift,
#         which only delays the issue because the target saturates at 1)
#
# On 4-digit addition, the bug coexists with task simplicity, so even a
# perfect Q-loss only buys us bounded improvement. The fix needs to be
# tested on a task with real iterative depth (Sudoku, Maze) to show
# meaningful recursion utilization.


# ----------------------------------------------------------------------------
# QUICK MATH REFERENCE
# ----------------------------------------------------------------------------
# halt > 0  <=>  sigmoid(halt) > 0.5
# BCE-with-logits gradient: dL/dh = sigmoid(h) - t
# Optimizer pulls halt logit toward logit(t) = log(t / (1 - t))
# logit(0.5) = 0  -> this is the threshold-flipping point
# logit(0.95) = +2.94  -> halt > 3 fires only when target ~ 0.95
# As t -> 1, logit(t) -> +infinity, so any fixed threshold eventually crossed

# %%
import torch
import torch.nn.functional as F
from collections import Counter

# --- Training Loop ---

def model_training_and_validation_with_mask(c, T, n_sup, HALT_THRESHOLD):
  model = TinyRModel(hidden_size, vocab_size, inp_seq_len=inp_seq_len, out_seq_len=out_seq_len).to(device)
  optimizer = torch.optim.Adam(model.parameters(), lr=1e-4)

  print('PAD_TOKEN: ', PAD_TOKEN)
  criterion = nn.CrossEntropyLoss(reduction='none', ignore_index=PAD_TOKEN)

  epochs = 100


  print('Training Logs ------ \n')
  for epoch in range(epochs):
        model.train()

        running_loss = 0
        running_q = 0
        running_n_taken = 0

        all_halt_steps = []
        all_halt_logits = []

        for step, batch in enumerate(train_loader):
            input_ids = batch['input_ids'].to(device)
            labels = batch['labels'].to(device)
            batch_size_curr = input_ids.size(0)
            seq_len = labels.size(1)

            active_mask = torch.ones(batch_size_curr, dtype=torch.bool, device=device)

            x = input_ids
            y = torch.zeros(batch_size_curr, hidden_size, device=device)
            z = torch.zeros(batch_size_curr, hidden_size, device=device)

            step_loss = step_q = 0
            overall_loss = torch.tensor(0.0, device=device)

            # at the start of each batch
            halt_step = torch.full((batch_size_curr,), n_sup, dtype=torch.long, device=device)


            for i in range(n_sup):
                f_out, halt, y_new, z_new = model(x, y, z, T, n=6)

                all_halt_logits.append(halt.squeeze().detach().cpu())

                # Update hidden states only for active samples
                y = torch.where(active_mask.unsqueeze(1), y_new.detach(), y)
                z = torch.where(active_mask.unsqueeze(1), z_new.detach(), z)

                seq_len = labels.size(1)  #this is padded to length 6 for now

                # Prediction Loss (Per Token: Batch * SeqLen)
                loss_per_token = criterion(f_out.view(-1, vocab_size), labels.view(-1))

                # Halting Loss (Per Sample: Batch)
                q_loss_per_sample = Q_LOSS(halt, f_out.view(-1, seq_len, vocab_size), labels)

                # Expand active mask to token level for prediction loss
                # active_mask: (B) -> (B, Seq) -> (B*Seq)


                token_mask = active_mask.unsqueeze(1).expand(-1, seq_len).reshape(-1).float()
                sample_mask = active_mask.float()

                num_active_tokens = token_mask.sum() + 1e-8
                num_active_samples = sample_mask.sum() + 1e-8

                # Weighted sum of losses for active samples
                current_step_loss = (loss_per_token * token_mask).sum() / num_active_tokens
                current_step_q = (q_loss_per_sample.squeeze() * sample_mask).sum() / num_active_samples

                overall_loss += (current_step_loss + c * current_step_q)

                step_loss += current_step_loss.item()
                step_q += current_step_q.item()

                # Update halting decision
                halt_decision = (halt.squeeze() > HALT_THRESHOLD) & active_mask

                # inside the for i in range(n_sup): loop, after halt_decision is computed
                halt_step[halt_decision] = i + 1

                active_mask = active_mask & (~halt_decision)

                if active_mask.sum() == 0:
                  break

            # at the end of the batch, accumulate
            all_halt_steps.append(halt_step.cpu())

            n_taken = i + 1
            overall_loss /= n_taken
            # inside the step loop, after `n_taken = i + 1`:
            running_n_taken += n_taken

            optimizer.zero_grad()
            overall_loss.backward()
            optimizer.step()

            running_loss += step_loss / n_taken
            running_q += step_q / n_taken



        avg_loss = running_loss / len(train_loader)
        avg_q_loss = running_q / len(train_loader)

        avg_steps = running_n_taken / len(train_loader)

        print(f'Training processed epoch {epoch}')
        if epoch % 10 == 0:
            print(f" Training epoch {epoch} | CE: {avg_loss:.4f} | Q-Loss: {avg_q_loss:.4f} | Avg Steps: {avg_steps}")

            all_halt_steps = torch.cat(all_halt_steps)
            all_halt_logits = torch.cat(all_halt_logits)

            mean_h = all_halt_steps.float().mean().item()
            median_h = all_halt_steps.float().median().item()
            frac_1 = (all_halt_steps == 1).float().mean().item()
            frac_max = (all_halt_steps == n_sup).float().mean().item()
            dist = dict(Counter(all_halt_steps.tolist()))

            print(f"halt logit: mean={all_halt_logits.mean().item():.3f} "
                  f"std={all_halt_logits.std().item():.3f} "
                  f"max={all_halt_logits.max().item():.3f} "
                  f"%>0={(all_halt_logits > 0).float().mean().item():.1%} "
                  f"%>1.5={(all_halt_logits > 1.5).float().mean().item():.1%}")

            print(f"halt steps: mean={mean_h:.2f} median={median_h:.0f} "
                  f"%step1={frac_1:.1%} %never={frac_max:.1%} dist={dist}")

        running_loss = running_q = 0


        if epoch % 10 == 0:
            print('\nValidation Logs ------ \n')
            model.eval()
            correct = 0
            total = 0

            all_halt_steps_validation = []

            with torch.no_grad():
                for val_step, batch in enumerate(val_loader):
                    input_ids = batch['input_ids'].to(device)
                    labels = batch['labels'].to(device)
                    batch_size_curr = input_ids.size(0)

                    active_mask = torch.ones(batch_size_curr, dtype=torch.bool, device=device)

                    # at the start of each batch
                    val_halt_step = torch.full((batch_size_curr,), n_sup, dtype=torch.long, device=device)

                    x = input_ids
                    y = torch.zeros(input_ids.size(0), hidden_size, device=device)
                    z = torch.zeros(input_ids.size(0), hidden_size, device=device)

                    final_logits = torch.zeros(batch_size_curr, out_seq_len * vocab_size, device=device)

                    for i in range(n_sup):
                        f_out_val, val_halt, y_new, z_new = model(x, y, z, T, n=6)
                        y, z = y_new.detach(), z_new.detach()

                        # Update halting decision
                        if val_step == 0:
                            print(f"sup_step_{i+1} | mean={val_halt.mean().item():.3f} "
                                  f"std={val_halt.std().item():.3f} "
                                  f"median={val_halt.median().item():.3f} "
                                  f"%>0={(val_halt > 0).float().mean().item():.1%} "
                                  f"%>1.5={(val_halt > 1.5).float().mean().item():.1%} "
                                  f"first5={val_halt[:5].squeeze().tolist()}")

                        halt_decision = (val_halt.squeeze() > HALT_THRESHOLD) & active_mask
                               # inside the for i in range(n_sup): loop, after halt_decision is computed
                        val_halt_step[halt_decision] = i + 1

                        active_mask = active_mask & (~halt_decision)

                        final_logits[halt_decision] = f_out_val[halt_decision]

                        if active_mask.sum() == 0:
                           break

                    # at the end of the batch, accumulate
                    all_halt_steps_validation.append(val_halt_step.cpu())

                    final_logits[active_mask] = f_out_val[active_mask]

                    preds = final_logits.view(-1, seq_len, vocab_size).argmax(dim=-1)
                    non_pad = (labels != PAD_TOKEN)
                    matches_per_token = (preds == labels) | ~non_pad
                    exact = matches_per_token.all(dim=-1)

                    correct += exact.sum().item()
                    total   += labels.size(0)


            print(f"\nValidation Accuracy: {100 * correct / total:.2f}%")

            all_halt_steps_validation = torch.cat(all_halt_steps_validation)

            mean_h = all_halt_steps_validation.float().mean().item()
            median_h = all_halt_steps_validation.float().median().item()
            frac_1 = (all_halt_steps_validation == 1).float().mean().item()
            frac_max = (all_halt_steps_validation == n_sup).float().mean().item()
            dist = dict(Counter(all_halt_steps_validation.tolist()))

            print(f"validation halt steps: mean={mean_h:.2f} median={median_h:.0f} "
                  f"%step1={frac_1:.1%} %never={frac_max:.1%} dist={dist}")

# %%
import torch
import torch.nn.functional as F

def model_training_and_validation(c, T, n_sup):
    running_loss = 0
    running_q = 0

    # Use PAD_TOKEN for ignoring index in loss
    criterion = nn.CrossEntropyLoss(ignore_index=PAD_TOKEN)

    # Initialize model with correct sequence lengths
    model = TinyRModel(hidden_size, vocab_size, inp_seq_len, out_seq_len).to(device)
    optimizer = torch.optim.Adam(model.parameters(), lr=1e-4)

    epochs = 100

    print('Training Logs ------ \n')
    for _ in range(epochs):
        model.train()
        for step, batch in enumerate(train_loader):
            input_ids = batch['input_ids'].to(device)
            labels = batch['labels'].to(device)

            x = input_ids
            # Initial states must be (Batch, hidden_size)
            y = torch.zeros(input_ids.size(0), hidden_size, device=device)
            z = torch.zeros(input_ids.size(0), hidden_size, device=device)

            step_loss = step_q = 0
            overall_loss = 0
            n_taken = 0

            for i in range(n_sup):
                n_taken = i + 1
                f_out, halt, y_new, z_new = model(x, y, z, T, n=6)
                y, z = y_new.detach(), z_new.detach()

                # Map f_out (B, out_seq_len * vocab_size) to (B * out_seq_len, vocab_size)
                seq_len = labels.size(1)

                logits = f_out.view(-1, vocab_size)
                targets = labels.view(-1)

                # print(halt.shape, targets.shape, labels.shape, logits.shape)

                loss = criterion(logits, targets)

                # print(f_out.shape, labels.shape)
                q_loss_val = Q_LOSS(halt, f_out.view(-1, seq_len, vocab_size), labels)

                overall_loss += (loss + c * q_loss_val)
                step_loss += loss.item()
                step_q += q_loss_val.item()

                if (halt > 0).all():
                    break

            overall_loss = overall_loss / n_taken
            optimizer.zero_grad()
            overall_loss.backward()
            optimizer.step()

            running_loss += step_loss / n_taken
            running_q += step_q / n_taken

            if step % 50 == 0 and step > 0 and n_taken<n_sup:
                print(f"Step {step} | CE: {running_loss/50:.4f} | Q-Loss: {running_q/50:.4f} | Avg Steps: {n_taken}")
                running_loss = running_q = 0

        print('\nValidation Logs ------ \n')
        model.eval()
        correct = 0
        total = 0
        with torch.no_grad():
            for val_step, batch in enumerate(val_loader):
                input_ids = batch['input_ids'].to(device)
                labels = batch['labels'].to(device)
                x = input_ids
                y = torch.zeros(input_ids.size(0), hidden_size, device=device)
                z = torch.zeros(input_ids.size(0), hidden_size, device=device)

                for i in range(n_sup):
                    f_out_val, val_halt, y_new, z_new = model(x, y, z, T, n=6)
                    y, z = y_new.detach(), z_new.detach()
                    if (val_halt > 0).all(): break

                logits = f_out_val.view(-1, vocab_size)
                targets = labels.view(-1)
                predictions = logits.argmax(dim=1)

                mask = targets != PAD_TOKEN
                correct += (predictions[mask] == targets[mask]).sum().item()
                total += mask.sum().item()

        if epoch % 10 == 0:
            print(f"\nValidation Accuracy: {100 * correct / total:.2f}%")

# %%
# Accessing the underlying .data list from the AdditionDataset object
# Start with 2-digit additions with no carries
easy_dataset = [d for d in dataset.data if d['num_digits'] <= 2 and d['max_carry_chain'] == 0]
print(f"Easy examples: {len(easy_dataset)}")

# If that works, try with carries
medium_dataset = [d for d in dataset.data if d['num_digits'] <= 2]
print(f"Medium examples: {len(medium_dataset)}")

# Then scale up
hard_dataset = [d for d in dataset.data if d['num_digits'] == 4]
print(f"Hard examples: {len(hard_dataset)}")
# Out:
# Easy examples: 0
# Medium examples: 0
# Hard examples: 50000

# %%
## t-0

# Config: n_sup=5, halt > 0, c=0.1, T=3, 100 epochs
# Prediction: halt firing tracks train exact-match, not token accuracy.
# Early epochs: all-zero targets push halt negative -> %never = 100%, full recursion used, slower epochs.
# Log: training-logs/binary-em-halt-0.txt

HALT_THRESHOLD = 0
model_training_and_validation_with_mask(c=0.1, T=3, n_sup=5, HALT_THRESHOLD = HALT_THRESHOLD)
# Out:
# PAD_TOKEN:  11
# Training Logs ------
#
# Training processed epoch 0
#  Training epoch 0 | CE: 1.6185 | Q-Loss: 0.6229 | Avg Steps: 5.0
# halt logit: mean=-0.743 std=0.402 max=0.267 %>0=0.3% %>1.5=0.0%
# halt steps: mean=4.95 median=5 %step1=1.4% %never=98.6% dist={5: 44386, 1: 613, 4: 1}
#
# Validation Logs ------
#
# sup_step_1 | mean=-0.473 std=0.272 median=-0.447 %>0=0.0% %>1.5=0.0% first5=[-0.24260683357715607, -0.6449634432792664, -0.25519806146621704, -0.8330612778663635, -0.8427722454071045]
# sup_step_2 | mean=-0.455 std=0.240 median=-0.433 %>0=0.0% %>1.5=0.0% first5=[-0.10977038741111755, -0.6103752255439758, -0.38367992639541626, -0.720511257648468, -0.8893991112709045]
# sup_step_3 | mean=-0.465 std=0.225 median=-0.400 %>0=0.0% %>1.5=0.0% first5=[-0.20350085198879242, -0.6307965517044067, -0.3609260320663452, -0.7263540029525757, -0.8548501133918762]
# sup_step_4 | mean=-0.461 std=0.231 median=-0.391 %>0=0.0% %>1.5=0.0% first5=[-0.17860421538352966, -0.6297150254249573, -0.35481399297714233, -0.7248542904853821, -0.8804582953453064]
# sup_step_5 | mean=-0.463 std=0.229 median=-0.389 %>0=0.0% %>1.5=0.0% first5=[-0.18801690638065338, -0.6303167343139648, -0.3546368479728699, -0.7246167659759521, -0.872224748134613]
#
# Validation Accuracy: 0.08%
# validation halt steps: mean=4.97 median=5 %step1=0.0% %never=99.1% dist={5: 4954, 2: 46}
# Training processed epoch 1
# Training processed epoch 2
# Training processed epoch 3
# Training processed epoch 4
# Training processed epoch 5
# Training processed epoch 6
# Training processed epoch 7
# Training processed epoch 8
# Training processed epoch 9
# Training processed epoch 10
#  Training epoch 10 | CE: 0.9364 | Q-Loss: 0.6574 | Avg Steps: 1.953091684434968
# halt logit: mean=0.381 std=0.286 max=1.861 %>0=90.6% %>1.5=0.0%
# halt steps: mean=1.13 median=1 %step1=96.4% %never=3.2% dist={1: 43358, 5: 1445, 2: 181, 3: 16}
#
# Validation Logs ------
#
# sup_step_1 | mean=0.354 std=0.194 median=0.327 %>0=96.9% %>1.5=0.0% first5=[0.495130717754364, 0.07075183838605881, 0.32713091373443604, 0.008658021688461304, 0.2782770097255707]
# sup_step_2 | mean=0.345 std=0.193 median=0.326 %>0=100.0% %>1.5=0.0% first5=[0.5040760636329651, 0.09399799257516861, 0.3259601593017578, 0.031672559678554535, 0.26809602975845337]
#
# Validation Accuracy: 2.52%
# validation halt steps: mean=1.06 median=1 %step1=98.2% %never=1.5% dist={1: 4908, 2: 19, 5: 73}
# Training processed epoch 11
# Training processed epoch 12
# Training processed epoch 13
# Training processed epoch 14
# Training processed epoch 15
# Training processed epoch 16
# Training processed epoch 17
# Training processed epoch 18
# Training processed epoch 19
# Training processed epoch 20
#  Training epoch 20 | CE: 0.5481 | Q-Loss: 0.5377 | Avg Steps: 1.0
# halt logit: mean=1.220 std=0.196 max=1.926 %>0=100.0% %>1.5=7.8%
# halt steps: mean=1.00 median=1 %step1=100.0% %never=0.0% dist={1: 45000}
#
# Validation Logs ------
#
# sup_step_1 | mean=1.207 std=0.217 median=1.156 %>0=100.0% %>1.5=12.5% first5=[1.5031601190567017, 0.9672111868858337, 1.4922146797180176, 1.0119315385818481, 0.9141359925270081]
#
# Validation Accuracy: 9.18%
# validation halt steps: mean=1.00 median=1 %step1=100.0% %never=0.0% dist={1: 5000}
# Training processed epoch 21
# Training processed epoch 22
# Training processed epoch 23
# Training processed epoch 24
# Training processed epoch 25
# Training processed epoch 26
# Training processed epoch 27
# Training processed epoch 28
# Training processed epoch 29
# Training processed epoch 30
#  Training epoch 30 | CE: 0.3628 | Q-Loss: 0.4190 | Avg Steps: 1.0
# halt logit: mean=1.767 std=0.322 max=3.216 %>0=100.0% %>1.5=79.9%
# halt steps: mean=1.00 median=1 %step1=100.0% %never=0.0% dist={1: 45000}
#
# Validation Logs ------
#
# sup_step_1 | mean=2.083 std=0.291 median=2.048 %>0=100.0% %>1.5=96.9% first5=[2.177508592605591, 1.8933086395263672, 1.7915997505187988, 2.6267218589782715, 1.5965774059295654]
#
# Validation Accuracy: 44.58%
# validation halt steps: mean=1.00 median=1 %step1=100.0% %never=0.0% dist={1: 5000}
# Training processed epoch 31
# Training processed epoch 32
# Training processed epoch 33
# Training processed epoch 34
# Training processed epoch 35
# Training processed epoch 36
# Training processed epoch 37
# Training processed epoch 38
# Training processed epoch 39
# Training processed epoch 40
#  Training epoch 40 | CE: 0.0341 | Q-Loss: 0.0604 | Avg Steps: 1.0
# halt logit: mean=4.832 std=0.907 max=8.342 %>0=100.0% %>1.5=100.0%
# halt steps: mean=1.00 median=1 %step1=100.0% %never=0.0% dist={1: 45000}
#
# Validation Logs ------
#
# sup_step_1 | mean=4.816 std=0.707 median=4.787 %>0=100.0% %>1.5=100.0% first5=[4.440218448638916, 4.6984686851501465, 4.80906343460083, 4.898975849151611, 3.726741075515747]
#
# Validation Accuracy: 95.44%
# validation halt steps: mean=1.00 median=1 %step1=100.0% %never=0.0% dist={1: 5000}
# Training processed epoch 41
# Training processed epoch 42
# Training processed epoch 43
# Training processed epoch 44
# Training processed epoch 45
# Training processed epoch 46
# Training processed epoch 47
# Training processed epoch 48
# Training processed epoch 49
# Training processed epoch 50
#  Training epoch 50 | CE: 0.0253 | Q-Loss: 0.0458 | Avg Steps: 1.0
# halt logit: mean=5.457 std=1.238 max=9.940 %>0=100.0% %>1.5=100.0%
# halt steps: mean=1.00 median=1 %step1=100.0% %never=0.0% dist={1: 45000}
#
# Validation Logs ------
#
# sup_step_1 | mean=5.092 std=0.648 median=5.240 %>0=100.0% %>1.5=100.0% first5=[5.239624500274658, 5.135335445404053, 6.119482040405273, 5.3292717933654785, 3.675665855407715]
#
# Validation Accuracy: 97.34%
# validation halt steps: mean=1.00 median=1 %step1=100.0% %never=0.0% dist={1: 5000}
# Training processed epoch 51
# Training processed epoch 52
# Training processed epoch 53
# Training processed epoch 54
# Training processed epoch 55
# Training processed epoch 56
# Training processed epoch 57
# Training processed epoch 58
# Training processed epoch 59
# Training processed epoch 60
#  Training epoch 60 | CE: 0.0223 | Q-Loss: 0.0364 | Avg Steps: 1.0
# halt logit: mean=5.836 std=1.358 max=10.234 %>0=100.0% %>1.5=100.0%
# halt steps: mean=1.00 median=1 %step1=100.0% %never=0.0% dist={1: 45000}
#
# Validation Logs ------
#
# sup_step_1 | mean=7.288 std=1.009 median=7.210 %>0=100.0% %>1.5=100.0% first5=[6.900219917297363, 7.8558783531188965, 7.576567649841309, 7.569206714630127, 5.70414400100708]
#
# Validation Accuracy: 99.66%
# validation halt steps: mean=1.00 median=1 %step1=100.0% %never=0.0% dist={1: 5000}
# Training processed epoch 61
# Training processed epoch 62
# Training processed epoch 63
# Training processed epoch 64
# Training processed epoch 65
# Training processed epoch 66
# Training processed epoch 67
# Training processed epoch 68
# Training processed epoch 69
# Training processed epoch 70
#  Training epoch 70 | CE: 0.0387 | Q-Loss: 0.0446 | Avg Steps: 1.0021321961620469
# halt logit: mean=5.909 std=1.637 max=10.760 %>0=100.0% %>1.5=99.6%
# halt steps: mean=1.00 median=1 %step1=100.0% %never=0.0% dist={1: 44998, 2: 1, 3: 1}
#
# Validation Logs ------
#
# sup_step_1 | mean=6.995 std=0.958 median=6.943 %>0=100.0% %>1.5=100.0% first5=[6.982028484344482, 7.658236026763916, 7.706181526184082, 5.993388652801514, 5.488143444061279]
#
# Validation Accuracy: 99.68%
# validation halt steps: mean=1.00 median=1 %step1=100.0% %never=0.0% dist={1: 5000}
# Training processed epoch 71
# Training processed epoch 72
# Training processed epoch 73
# Training processed epoch 74
# Training processed epoch 75
# Training processed epoch 76
# Training processed epoch 77
# Training processed epoch 78
# Training processed epoch 79
# Training processed epoch 80
#  Training epoch 80 | CE: 0.0118 | Q-Loss: 0.0236 | Avg Steps: 1.0
# halt logit: mean=6.425 std=1.305 max=11.255 %>0=100.0% %>1.5=100.0%
# halt steps: mean=1.00 median=1 %step1=100.0% %never=0.0% dist={1: 45000}
#
# Validation Logs ------
#
# sup_step_1 | mean=5.286 std=0.648 median=5.124 %>0=100.0% %>1.5=100.0% first5=[4.954612731933594, 5.508529186248779, 4.297282695770264, 4.945849418640137, 5.0367536544799805]
#
# Validation Accuracy: 96.86%
# validation halt steps: mean=1.00 median=1 %step1=100.0% %never=0.0% dist={1: 5000}
# Training processed epoch 81
# Training processed epoch 82
# Training processed epoch 83
# Training processed epoch 84
# Training processed epoch 85
# Training processed epoch 86
# Training processed epoch 87
# Training processed epoch 88
# Training processed epoch 89
# Training processed epoch 90
#  Training epoch 90 | CE: 0.0157 | Q-Loss: 0.0272 | Avg Steps: 1.0
# halt logit: mean=6.152 std=1.300 max=10.542 %>0=100.0% %>1.5=100.0%
# halt steps: mean=1.00 median=1 %step1=100.0% %never=0.0% dist={1: 45000}
#
# Validation Logs ------
#
# sup_step_1 | mean=5.511 std=0.737 median=5.359 %>0=100.0% %>1.5=100.0% first5=[6.297363758087158, 6.069319248199463, 5.305107593536377, 5.35872220993042, 4.129765510559082]
#
# Validation Accuracy: 97.26%
# validation halt steps: mean=1.00 median=1 %step1=100.0% %never=0.0% dist={1: 5000}
# Training processed epoch 91
# Training processed epoch 92
# Training processed epoch 93
# Training processed epoch 94
# Training processed epoch 95
# Training processed epoch 96
# Training processed epoch 97
# Training processed epoch 98
# Training processed epoch 99

# %%
## t-1.5

# Config: n_sup=5, halt > 1.5, c=0.1, T=3, 100 epochs
# Prediction: near-identical to halt > 0. With a 0/1 target the equilibrium logit diverges
# per sample, so a fixed threshold in between should not matter (threshold-insensitivity test).
# Log: training-logs/binary-em-halt-1.5.txt

HALT_THRESHOLD = 1.5
model_training_and_validation_with_mask(c=0.1, T=3, n_sup=5, HALT_THRESHOLD = HALT_THRESHOLD)
# Out:
# PAD_TOKEN:  11
# Training Logs ------
#
# Training processed epoch 0
#  Training epoch 0 | CE: 1.6268 | Q-Loss: 0.6183 | Avg Steps: 5.0
# halt logit: mean=-0.752 std=0.418 max=0.083 %>0=0.1% %>1.5=0.0%
# halt steps: mean=5.00 median=5 %step1=0.0% %never=100.0% dist={5: 45000}
#
# Validation Logs ------
#
# sup_step_1 | mean=-0.601 std=0.331 median=-0.453 %>0=0.0% %>1.5=0.0% first5=[-0.45943352580070496, -0.6810863018035889, -0.3335372507572174, -1.057335376739502, -1.0602827072143555]
# sup_step_2 | mean=-0.575 std=0.288 median=-0.414 %>0=0.0% %>1.5=0.0% first5=[-0.42962077260017395, -0.7186231017112732, -0.35200944542884827, -0.9042237997055054, -0.836114764213562]
# sup_step_3 | mean=-0.579 std=0.300 median=-0.396 %>0=0.0% %>1.5=0.0% first5=[-0.43431827425956726, -0.7341224551200867, -0.36563363671302795, -0.901260256767273, -0.9130454659461975]
# sup_step_4 | mean=-0.581 std=0.302 median=-0.396 %>0=0.0% %>1.5=0.0% first5=[-0.4348297417163849, -0.7341899871826172, -0.35400500893592834, -0.9222186803817749, -0.9054664373397827]
# sup_step_5 | mean=-0.581 std=0.301 median=-0.397 %>0=0.0% %>1.5=0.0% first5=[-0.43489983677864075, -0.7336872816085815, -0.3535989820957184, -0.9166061878204346, -0.9117873907089233]
#
# Validation Accuracy: 0.08%
# validation halt steps: mean=5.00 median=5 %step1=0.0% %never=100.0% dist={5: 5000}
# Training processed epoch 1
# Training processed epoch 2
# Training processed epoch 3
# Training processed epoch 4
# Training processed epoch 5
# Training processed epoch 6
# Training processed epoch 7
# Training processed epoch 8
# Training processed epoch 9
# Training processed epoch 10
#  Training epoch 10 | CE: 0.7100 | Q-Loss: 0.6067 | Avg Steps: 5.0
# halt logit: mean=0.881 std=0.251 max=1.792 %>0=99.8% %>1.5=0.3%
# halt steps: mean=4.97 median=5 %step1=0.4% %never=99.3% dist={5: 44671, 1: 181, 2: 127, 3: 21}
#
# Validation Logs ------
#
# sup_step_1 | mean=0.944 std=0.229 median=0.967 %>0=100.0% %>1.5=0.0% first5=[0.7341403961181641, 0.7038458585739136, 1.169071078300476, 0.808385968208313, 1.0195239782333374]
# sup_step_2 | mean=0.978 std=0.207 median=0.950 %>0=100.0% %>1.5=0.0% first5=[0.9194667339324951, 0.6109918355941772, 1.2358728647232056, 0.8422316312789917, 0.9502502679824829]
# sup_step_3 | mean=0.969 std=0.222 median=1.010 %>0=100.0% %>1.5=0.0% first5=[0.9491366147994995, 0.623066782951355, 1.2739366292953491, 0.782475471496582, 0.8531469106674194]
# sup_step_4 | mean=0.971 std=0.216 median=0.991 %>0=100.0% %>1.5=0.0% first5=[0.9847581386566162, 0.646102786064148, 1.2762082815170288, 0.7854984402656555, 0.9218267202377319]
# sup_step_5 | mean=0.973 std=0.219 median=1.029 %>0=100.0% %>1.5=0.0% first5=[0.9898775815963745, 0.6285343170166016, 1.2777026891708374, 0.788078784942627, 0.9016481637954712]
#
# Validation Accuracy: 6.44%
# validation halt steps: mean=4.97 median=5 %step1=0.5% %never=99.1% dist={5: 4957, 1: 24, 2: 14, 3: 5}
# Training processed epoch 11
# Training processed epoch 12
# Training processed epoch 13
# Training processed epoch 14
# Training processed epoch 15
# Training processed epoch 16
# Training processed epoch 17
# Training processed epoch 18
# Training processed epoch 19
# Training processed epoch 20
#  Training epoch 20 | CE: 0.5510 | Q-Loss: 0.5381 | Avg Steps: 5.0
# halt logit: mean=1.218 std=0.203 max=2.009 %>0=100.0% %>1.5=7.9%
# halt steps: mean=4.61 median=5 %step1=7.3% %never=89.4% dist={5: 40216, 1: 3284, 2: 1375, 3: 109, 4: 16}
#
# Validation Logs ------
#
# sup_step_1 | mean=1.210 std=0.236 median=1.191 %>0=100.0% %>1.5=9.4% first5=[1.4568636417388916, 1.204683542251587, 1.3810805082321167, 0.8651300072669983, 0.9267469048500061]
# sup_step_2 | mean=1.237 std=0.208 median=1.267 %>0=100.0% %>1.5=9.4% first5=[1.4623440504074097, 1.1899659633636475, 1.3629205226898193, 1.06876802444458, 1.0224149227142334]
# sup_step_3 | mean=1.237 std=0.214 median=1.240 %>0=100.0% %>1.5=6.2% first5=[1.4392774105072021, 1.183265209197998, 1.369698166847229, 1.0133640766143799, 1.040457844734192]
# sup_step_4 | mean=1.237 std=0.217 median=1.243 %>0=100.0% %>1.5=6.2% first5=[1.4396021366119385, 1.1809340715408325, 1.3752168416976929, 1.0128870010375977, 1.0351817607879639]
# sup_step_5 | mean=1.237 std=0.214 median=1.245 %>0=100.0% %>1.5=9.4% first5=[1.441047191619873, 1.1826276779174805, 1.373289942741394, 1.0120353698730469, 1.0367257595062256]
#
# Validation Accuracy: 8.32%
# validation halt steps: mean=4.55 median=5 %step1=7.2% %never=87.4% dist={5: 4368, 1: 358, 2: 253, 3: 20, 4: 1}
# Training processed epoch 21
# Training processed epoch 22
# Training processed epoch 23
# Training processed epoch 24
# Training processed epoch 25
# Training processed epoch 26
# Training processed epoch 27
# Training processed epoch 28
# Training processed epoch 29
# Training processed epoch 30
#  Training epoch 30 | CE: 0.5084 | Q-Loss: 0.5127 | Avg Steps: 5.0
# halt logit: mean=1.335 std=0.179 max=2.062 %>0=100.0% %>1.5=18.9%
# halt steps: mean=4.14 median=5 %step1=16.9% %never=76.9% dist={5: 34622, 1: 7590, 2: 2599, 4: 26, 3: 163}
#
# Validation Logs ------
#
# sup_step_1 | mean=1.384 std=0.200 median=1.376 %>0=100.0% %>1.5=25.0% first5=[1.375732183456421, 1.31196928024292, 1.4713233709335327, 1.3438799381256104, 1.0451050996780396]
# sup_step_2 | mean=1.396 std=0.202 median=1.421 %>0=100.0% %>1.5=31.2% first5=[1.36638343334198, 1.3312541246414185, 1.4911446571350098, 1.421484112739563, 1.050156831741333]
# sup_step_3 | mean=1.398 std=0.193 median=1.414 %>0=100.0% %>1.5=28.1% first5=[1.3655084371566772, 1.3250185251235962, 1.4966219663619995, 1.3794043064117432, 1.0468696355819702]
# sup_step_4 | mean=1.393 std=0.196 median=1.400 %>0=100.0% %>1.5=28.1% first5=[1.3678253889083862, 1.324652075767517, 1.4985507726669312, 1.3789879083633423, 1.0466495752334595]
# sup_step_5 | mean=1.395 std=0.193 median=1.403 %>0=100.0% %>1.5=28.1% first5=[1.368035912513733, 1.3248538970947266, 1.4948816299438477, 1.3811256885528564, 1.046866536140442]
#
# Validation Accuracy: 12.44%
# validation halt steps: mean=3.77 median=5 %step1=25.8% %never=67.5% dist={5: 3374, 1: 1291, 2: 304, 3: 27, 4: 4}
# Training processed epoch 31
# Training processed epoch 32
# Training processed epoch 33
# Training processed epoch 34
# Training processed epoch 35
# Training processed epoch 36
# Training processed epoch 37
# Training processed epoch 38
# Training processed epoch 39
# Training processed epoch 40
#  Training epoch 40 | CE: 0.2061 | Q-Loss: 0.2070 | Avg Steps: 1.9836531627576404
# halt logit: mean=2.557 std=1.009 max=6.048 %>0=100.0% %>1.5=86.4%
# halt steps: mean=1.20 median=1 %step1=94.0% %never=4.8% dist={1: 42308, 5: 2142, 3: 58, 2: 483, 4: 9}
#
# Validation Logs ------
#
# sup_step_1 | mean=2.189 std=0.495 median=2.108 %>0=100.0% %>1.5=93.8% first5=[2.326469898223877, 1.1032713651657104, 2.7338483333587646, 1.8962141275405884, 2.1449031829833984]
# sup_step_2 | mean=2.207 std=0.490 median=2.273 %>0=100.0% %>1.5=87.5% first5=[2.3082025051116943, 1.170125126838684, 2.657970905303955, 1.8700438737869263, 2.3174452781677246]
# sup_step_3 | mean=2.210 std=0.497 median=2.287 %>0=100.0% %>1.5=87.5% first5=[2.3079748153686523, 1.158170461654663, 2.6591622829437256, 1.8653024435043335, 2.305732250213623]
# sup_step_4 | mean=2.208 std=0.496 median=2.284 %>0=100.0% %>1.5=87.5% first5=[2.302945137023926, 1.1608811616897583, 2.66098690032959, 1.8683902025222778, 2.3012940883636475]
# sup_step_5 | mean=2.207 std=0.496 median=2.284 %>0=100.0% %>1.5=87.5% first5=[2.3038740158081055, 1.161352276802063, 2.660949945449829, 1.8665032386779785, 2.302539587020874]
#
# Validation Accuracy: 53.28%
# validation halt steps: mean=1.19 median=1 %step1=94.2% %never=4.3% dist={1: 4709, 5: 214, 2: 71, 3: 5, 4: 1}
# Training processed epoch 41
# Training processed epoch 42
# Training processed epoch 43
# Training processed epoch 44
# Training processed epoch 45
# Training processed epoch 46
# Training processed epoch 47
# Training processed epoch 48
# Training processed epoch 49
# Training processed epoch 50
#  Training epoch 50 | CE: 0.0435 | Q-Loss: 0.0550 | Avg Steps: 1.091684434968017
# halt logit: mean=5.029 std=1.470 max=10.176 %>0=100.0% %>1.5=99.6%
# halt steps: mean=1.00 median=1 %step1=99.9% %never=0.1% dist={1: 44951, 2: 13, 5: 35, 4: 1}
#
# Validation Logs ------
#
# sup_step_1 | mean=6.183 std=1.048 median=6.150 %>0=100.0% %>1.5=100.0% first5=[5.40472412109375, 5.972384452819824, 5.905740737915039, 6.678865432739258, 3.5956637859344482]
#
# Validation Accuracy: 98.14%
# validation halt steps: mean=1.00 median=1 %step1=100.0% %never=0.0% dist={1: 5000}
# Training processed epoch 51
# Training processed epoch 52
# Training processed epoch 53
# Training processed epoch 54
# Training processed epoch 55
# Training processed epoch 56
# Training processed epoch 57
# Training processed epoch 58
# Training processed epoch 59
# Training processed epoch 60
#  Training epoch 60 | CE: 0.0119 | Q-Loss: 0.0136 | Avg Steps: 1.0
# halt logit: mean=6.797 std=1.210 max=11.364 %>0=100.0% %>1.5=100.0%
# halt steps: mean=1.00 median=1 %step1=100.0% %never=0.0% dist={1: 45000}
#
# Validation Logs ------
#
# sup_step_1 | mean=7.232 std=1.185 median=7.225 %>0=100.0% %>1.5=100.0% first5=[6.967413902282715, 7.040010929107666, 7.067489147186279, 7.134910583496094, 5.00627326965332]
#
# Validation Accuracy: 98.72%
# validation halt steps: mean=1.00 median=1 %step1=100.0% %never=0.0% dist={1: 5000}
# Training processed epoch 61
# Training processed epoch 62
# Training processed epoch 63
# Training processed epoch 64
# Training processed epoch 65
# Training processed epoch 66
# Training processed epoch 67
# Training processed epoch 68
# Training processed epoch 69
# Training processed epoch 70
#  Training epoch 70 | CE: 0.1709 | Q-Loss: 0.1366 | Avg Steps: 2.031272210376688
# halt logit: mean=3.466 std=2.140 max=11.125 %>0=99.7% %>1.5=88.8%
# halt steps: mean=1.17 median=1 %step1=95.2% %never=4.2% dist={1: 42851, 2: 245, 5: 1877, 4: 2, 3: 25}
#
# Validation Logs ------
#
# sup_step_1 | mean=5.171 std=1.049 median=5.272 %>0=100.0% %>1.5=100.0% first5=[5.347535610198975, 5.1633100509643555, 5.514925003051758, 5.507579803466797, 3.7768754959106445]
#
# Validation Accuracy: 96.82%
# validation halt steps: mean=1.00 median=1 %step1=100.0% %never=0.0% dist={1: 5000}
# Training processed epoch 71
# Training processed epoch 72
# Training processed epoch 73
# Training processed epoch 74
# Training processed epoch 75
# Training processed epoch 76
# Training processed epoch 77
# Training processed epoch 78
# Training processed epoch 79
# Training processed epoch 80
#  Training epoch 80 | CE: 0.0540 | Q-Loss: 0.0371 | Avg Steps: 1.1620469083155651
# halt logit: mean=6.224 std=2.277 max=12.019 %>0=99.6% %>1.5=94.8%
# halt steps: mean=1.05 median=1 %step1=98.7% %never=1.1% dist={1: 44431, 2: 50, 5: 510, 3: 6, 4: 3}
#
# Validation Logs ------
#
# sup_step_1 | mean=1.457 std=0.564 median=1.447 %>0=100.0% %>1.5=43.8% first5=[1.960465431213379, 1.4947943687438965, 1.0948359966278076, 2.3031108379364014, 1.2873616218566895]
# sup_step_2 | mean=1.463 std=0.562 median=1.477 %>0=100.0% %>1.5=50.0% first5=[1.857367992401123, 1.5108896493911743, 1.082566738128662, 2.1586530208587646, 1.3229930400848389]
# sup_step_3 | mean=1.457 std=0.564 median=1.481 %>0=100.0% %>1.5=46.9% first5=[1.8450257778167725, 1.499616026878357, 1.0811331272125244, 2.1477677822113037, 1.3051273822784424]
# sup_step_4 | mean=1.458 std=0.563 median=1.479 %>0=100.0% %>1.5=50.0% first5=[1.8517512083053589, 1.502626657485962, 1.0810232162475586, 2.1477572917938232, 1.3001346588134766]
# sup_step_5 | mean=1.458 std=0.563 median=1.479 %>0=100.0% %>1.5=50.0% first5=[1.8518931865692139, 1.5022759437561035, 1.0810176134109497, 2.1481587886810303, 1.3010218143463135]
#
# Validation Accuracy: 42.82%
# validation halt steps: mean=3.16 median=5 %step1=43.9% %never=53.2% dist={1: 2193, 2: 134, 5: 2662, 4: 1, 3: 10}
# Training processed epoch 81
# Training processed epoch 82
# Training processed epoch 83
# Training processed epoch 84
# Training processed epoch 85
# Training processed epoch 86
# Training processed epoch 87
# Training processed epoch 88
# Training processed epoch 89
# Training processed epoch 90
#  Training epoch 90 | CE: 0.0080 | Q-Loss: 0.0171 | Avg Steps: 1.0
# halt logit: mean=7.213 std=1.807 max=14.270 %>0=100.0% %>1.5=100.0%
# halt steps: mean=1.00 median=1 %step1=100.0% %never=0.0% dist={1: 45000}
#
# Validation Logs ------
#
# sup_step_1 | mean=5.924 std=0.912 median=5.953 %>0=100.0% %>1.5=100.0% first5=[4.738382339477539, 6.478415489196777, 6.008732795715332, 6.567409515380859, 4.25697135925293]
#
# Validation Accuracy: 98.12%
# validation halt steps: mean=1.00 median=1 %step1=100.0% %never=0.0% dist={1: 5000}
# Training processed epoch 91
# Training processed epoch 92
# Training processed epoch 93
# Training processed epoch 94
# Training processed epoch 95
# Training processed epoch 96
# Training processed epoch 97
# Training processed epoch 98
# Training processed epoch 99

# %%
## s-1

# Config: n_sup=1, halt > 0, c=0.1, T=3, 100 epochs
# Supervision sweep: no-recursion baseline under the binary-EM target.
# Log: training-logs/binary-em-nsup-1.txt

HALT_THRESHOLD = 0
model_training_and_validation_with_mask(c=0.1, T=3, n_sup=1, HALT_THRESHOLD = HALT_THRESHOLD)
# Out:
# PAD_TOKEN:  11
# Training Logs ------
#
# Training processed epoch 0
#  Training epoch 0 | CE: 1.6129 | Q-Loss: 0.6244 | Avg Steps: 1.0
# halt logit: mean=-0.724 std=0.383 max=0.196 %>0=0.3% %>1.5=0.0%
# halt steps: mean=1.00 median=1 %step1=100.0% %never=100.0% dist={1: 45000}
#
# Validation Logs ------
#
# sup_step_1 | mean=-0.624 std=0.326 median=-0.564 %>0=0.0% %>1.5=0.0% first5=[-0.28647851943969727, -0.6892470717430115, -0.2782977521419525, -1.0226608514785767, -1.0046120882034302]
#
# Validation Accuracy: 0.10%
# validation halt steps: mean=1.00 median=1 %step1=100.0% %never=100.0% dist={1: 5000}
# Training processed epoch 1
# Training processed epoch 2
# Training processed epoch 3
# Training processed epoch 4
# Training processed epoch 5
# Training processed epoch 6
# Training processed epoch 7
# Training processed epoch 8
# Training processed epoch 9
# Training processed epoch 10
#  Training epoch 10 | CE: 0.6493 | Q-Loss: 0.5857 | Avg Steps: 1.0
# halt logit: mean=0.991 std=0.257 max=1.977 %>0=100.0% %>1.5=2.5%
# halt steps: mean=1.00 median=1 %step1=100.0% %never=100.0% dist={1: 45000}
#
# Validation Logs ------
#
# sup_step_1 | mean=1.130 std=0.262 median=1.185 %>0=100.0% %>1.5=3.1% first5=[1.2530536651611328, 0.8015326261520386, 1.4729400873184204, 1.1033395528793335, 0.8601069450378418]
#
# Validation Accuracy: 7.92%
# validation halt steps: mean=1.00 median=1 %step1=100.0% %never=100.0% dist={1: 5000}
# Training processed epoch 11
# Training processed epoch 12
# Training processed epoch 13
# Training processed epoch 14
# Training processed epoch 15
# Training processed epoch 16
# Training processed epoch 17
# Training processed epoch 18
# Training processed epoch 19
# Training processed epoch 20
#  Training epoch 20 | CE: 0.5414 | Q-Loss: 0.5338 | Avg Steps: 1.0
# halt logit: mean=1.237 std=0.193 max=1.955 %>0=100.0% %>1.5=9.0%
# halt steps: mean=1.00 median=1 %step1=100.0% %never=100.0% dist={1: 45000}
#
# Validation Logs ------
#
# sup_step_1 | mean=1.279 std=0.190 median=1.249 %>0=100.0% %>1.5=3.1% first5=[1.249166488647461, 1.2384352684020996, 1.4722567796707153, 1.1518409252166748, 1.073094129562378]
#
# Validation Accuracy: 8.60%
# validation halt steps: mean=1.00 median=1 %step1=100.0% %never=100.0% dist={1: 5000}
# Training processed epoch 21
# Training processed epoch 22
# Training processed epoch 23
# Training processed epoch 24
# Training processed epoch 25
# Training processed epoch 26
# Training processed epoch 27
# Training processed epoch 28
# Training processed epoch 29
# Training processed epoch 30
#  Training epoch 30 | CE: 0.0982 | Q-Loss: 0.1373 | Avg Steps: 1.0
# halt logit: mean=3.598 std=0.631 max=6.535 %>0=100.0% %>1.5=99.9%
# halt steps: mean=1.00 median=1 %step1=100.0% %never=100.0% dist={1: 45000}
#
# Validation Logs ------
#
# sup_step_1 | mean=3.527 std=0.556 median=3.524 %>0=100.0% %>1.5=100.0% first5=[4.575873851776123, 2.8919973373413086, 2.6982944011688232, 3.1269562244415283, 3.436331272125244]
#
# Validation Accuracy: 86.60%
# validation halt steps: mean=1.00 median=1 %step1=100.0% %never=100.0% dist={1: 5000}
# Training processed epoch 31
# Training processed epoch 32
# Training processed epoch 33
# Training processed epoch 34
# Training processed epoch 35
# Training processed epoch 36
# Training processed epoch 37
# Training processed epoch 38
# Training processed epoch 39
# Training processed epoch 40
#  Training epoch 40 | CE: 0.0402 | Q-Loss: 0.0688 | Avg Steps: 1.0
# halt logit: mean=4.677 std=0.954 max=8.324 %>0=100.0% %>1.5=100.0%
# halt steps: mean=1.00 median=1 %step1=100.0% %never=100.0% dist={1: 45000}
#
# Validation Logs ------
#
# sup_step_1 | mean=4.839 std=0.609 median=4.753 %>0=100.0% %>1.5=100.0% first5=[4.523324489593506, 4.156932353973389, 4.971569538116455, 5.193406581878662, 4.598785400390625]
#
# Validation Accuracy: 94.26%
# validation halt steps: mean=1.00 median=1 %step1=100.0% %never=100.0% dist={1: 5000}
# Training processed epoch 41
# Training processed epoch 42
# Training processed epoch 43
# Training processed epoch 44
# Training processed epoch 45
# Training processed epoch 46
# Training processed epoch 47
# Training processed epoch 48
# Training processed epoch 49
# Training processed epoch 50
#  Training epoch 50 | CE: 0.0356 | Q-Loss: 0.0545 | Avg Steps: 1.0
# halt logit: mean=5.104 std=1.093 max=9.834 %>0=100.0% %>1.5=99.9%
# halt steps: mean=1.00 median=1 %step1=100.0% %never=100.0% dist={1: 45000}
#
# Validation Logs ------
#
# sup_step_1 | mean=4.553 std=0.653 median=4.605 %>0=100.0% %>1.5=100.0% first5=[5.563175678253174, 4.432739734649658, 4.430285453796387, 4.716577529907227, 4.815544128417969]
#
# Validation Accuracy: 94.06%
# validation halt steps: mean=1.00 median=1 %step1=100.0% %never=100.0% dist={1: 5000}
# Training processed epoch 51
# Training processed epoch 52
# Training processed epoch 53
# Training processed epoch 54
# Training processed epoch 55
# Training processed epoch 56
# Training processed epoch 57
# Training processed epoch 58
# Training processed epoch 59
# Training processed epoch 60
#  Training epoch 60 | CE: 0.0264 | Q-Loss: 0.0441 | Avg Steps: 1.0
# halt logit: mean=5.289 std=0.995 max=9.408 %>0=100.0% %>1.5=100.0%
# halt steps: mean=1.00 median=1 %step1=100.0% %never=100.0% dist={1: 45000}
#
# Validation Logs ------
#
# sup_step_1 | mean=5.535 std=0.814 median=5.698 %>0=100.0% %>1.5=100.0% first5=[5.973883628845215, 5.351870059967041, 5.1083855628967285, 4.909145832061768, 5.429605007171631]
#
# Validation Accuracy: 97.56%
# validation halt steps: mean=1.00 median=1 %step1=100.0% %never=100.0% dist={1: 5000}
# Training processed epoch 61
# Training processed epoch 62
# Training processed epoch 63
# Training processed epoch 64
# Training processed epoch 65
# Training processed epoch 66
# Training processed epoch 67
# Training processed epoch 68
# Training processed epoch 69
# Training processed epoch 70
#  Training epoch 70 | CE: 0.0185 | Q-Loss: 0.0351 | Avg Steps: 1.0
# halt logit: mean=5.561 std=1.004 max=9.983 %>0=100.0% %>1.5=100.0%
# halt steps: mean=1.00 median=1 %step1=100.0% %never=100.0% dist={1: 45000}
#
# Validation Logs ------
#
# sup_step_1 | mean=6.275 std=0.772 median=6.375 %>0=100.0% %>1.5=100.0% first5=[6.7350897789001465, 5.8918609619140625, 5.06126594543457, 5.943432331085205, 5.592068195343018]
#
# Validation Accuracy: 98.74%
# validation halt steps: mean=1.00 median=1 %step1=100.0% %never=100.0% dist={1: 5000}
# Training processed epoch 71
# Training processed epoch 72
# Training processed epoch 73
# Training processed epoch 74
# Training processed epoch 75
# Training processed epoch 76
# Training processed epoch 77
# Training processed epoch 78
# Training processed epoch 79
# Training processed epoch 80
#  Training epoch 80 | CE: 0.0233 | Q-Loss: 0.0315 | Avg Steps: 1.0
# halt logit: mean=6.096 std=1.253 max=10.487 %>0=100.0% %>1.5=99.8%
# halt steps: mean=1.00 median=1 %step1=100.0% %never=100.0% dist={1: 45000}
#
# Validation Logs ------
#
# sup_step_1 | mean=2.709 std=0.874 median=2.755 %>0=100.0% %>1.5=87.5% first5=[4.227146148681641, 1.6944953203201294, 2.5624101161956787, 2.4356305599212646, 2.623807191848755]
#
# Validation Accuracy: 76.86%
# validation halt steps: mean=1.00 median=1 %step1=100.0% %never=100.0% dist={1: 5000}
# Training processed epoch 81
# Training processed epoch 82
# Training processed epoch 83
# Training processed epoch 84
# Training processed epoch 85
# Training processed epoch 86
# Training processed epoch 87
# Training processed epoch 88
# Training processed epoch 89
# Training processed epoch 90
#  Training epoch 90 | CE: 0.0142 | Q-Loss: 0.0261 | Avg Steps: 1.0
# halt logit: mean=6.226 std=1.311 max=11.740 %>0=100.0% %>1.5=100.0%
# halt steps: mean=1.00 median=1 %step1=100.0% %never=100.0% dist={1: 45000}
#
# Validation Logs ------
#
# sup_step_1 | mean=6.524 std=0.627 median=6.633 %>0=100.0% %>1.5=100.0% first5=[7.0050859451293945, 6.3706464767456055, 6.014139175415039, 6.6328535079956055, 5.622099876403809]
#
# Validation Accuracy: 98.90%
# validation halt steps: mean=1.00 median=1 %step1=100.0% %never=100.0% dist={1: 5000}
# Training processed epoch 91
# Training processed epoch 92
# Training processed epoch 93
# Training processed epoch 94
# Training processed epoch 95
# Training processed epoch 96
# Training processed epoch 97
# Training processed epoch 98
# Training processed epoch 99

# %%
## t-3.0

# Config: n_sup=5, halt > 3.0, c=0.1, T=3, 100 epochs
# Threshold sweep: halt > 3.0 fires at sigmoid(3.0) ~ 0.95, i.e. ~95% token accuracy.
# Prediction: collapse later than halt > 1.5, but still collapses (target saturates near 1).
# Log: training-logs/softmean-halt-3.0.txt

HALT_THRESHOLD = 3.0
model_training_and_validation_with_mask(c=0.1, T=3, n_sup=5, HALT_THRESHOLD = HALT_THRESHOLD)
# Out:
# PAD_TOKEN:  11
# Training Logs ------
#
# Training processed epoch 0
#  Training epoch 0 | CE: 1.6237 | Q-Loss: 0.6191 | Avg Steps: 5.0
# halt logit: mean=-0.751 std=0.416 max=0.109 %>0=0.3% %>1.5=0.0%
# halt steps: mean=5.00 median=5 %step1=0.0% %never=100.0% dist={5: 45000}
#
# Validation Logs ------
#
# sup_step_1 | mean=-0.699 std=0.438 median=-0.444 %>0=0.0% %>1.5=0.0% first5=[-0.38466110825538635, -1.1007777452468872, -0.3131813108921051, -1.2583942413330078, -1.1179763078689575]
# sup_step_2 | mean=-0.665 std=0.374 median=-0.679 %>0=0.0% %>1.5=0.0% first5=[-0.2511100471019745, -0.9563161134719849, -0.3908167779445648, -1.1026442050933838, -1.080012321472168]
# sup_step_3 | mean=-0.654 std=0.380 median=-0.504 %>0=0.0% %>1.5=0.0% first5=[-0.2698526084423065, -1.0026929378509521, -0.3748795688152313, -1.0833712816238403, -1.1145395040512085]
# sup_step_4 | mean=-0.662 std=0.376 median=-0.581 %>0=0.0% %>1.5=0.0% first5=[-0.26999661326408386, -0.9758542776107788, -0.3764881193637848, -1.0843814611434937, -1.1177054643630981]
# sup_step_5 | mean=-0.658 std=0.377 median=-0.553 %>0=0.0% %>1.5=0.0% first5=[-0.2702374756336212, -0.989479660987854, -0.3761950433254242, -1.0853215456008911, -1.118281602859497]
#
# Validation Accuracy: 0.08%
# validation halt steps: mean=5.00 median=5 %step1=0.0% %never=100.0% dist={5: 5000}
# Training processed epoch 1
# Training processed epoch 2
# Training processed epoch 3
# Training processed epoch 4
# Training processed epoch 5
# Training processed epoch 6
# Training processed epoch 7
# Training processed epoch 8
# Training processed epoch 9
# Training processed epoch 10
#  Training epoch 10 | CE: 0.6891 | Q-Loss: 0.6004 | Avg Steps: 5.0
# halt logit: mean=0.913 std=0.256 max=1.837 %>0=99.9% %>1.5=0.7%
# halt steps: mean=5.00 median=5 %step1=0.0% %never=100.0% dist={5: 45000}
#
# Validation Logs ------
#
# sup_step_1 | mean=0.854 std=0.264 median=0.903 %>0=100.0% %>1.5=0.0% first5=[0.9030377268791199, 0.9685091376304626, 1.1259527206420898, 0.9844387769699097, 0.49916964769363403]
# sup_step_2 | mean=0.954 std=0.240 median=0.957 %>0=100.0% %>1.5=0.0% first5=[0.9301483035087585, 0.9429579377174377, 1.2490047216415405, 1.0519464015960693, 0.5480177998542786]
# sup_step_3 | mean=0.930 std=0.207 median=0.947 %>0=100.0% %>1.5=0.0% first5=[0.9516980051994324, 0.9513835310935974, 1.113937258720398, 1.0445319414138794, 0.5175398588180542]
# sup_step_4 | mean=0.947 std=0.215 median=0.954 %>0=100.0% %>1.5=0.0% first5=[0.9368526339530945, 0.9500524401664734, 1.2180594205856323, 1.043022632598877, 0.5249478220939636]
# sup_step_5 | mean=0.931 std=0.209 median=0.948 %>0=100.0% %>1.5=0.0% first5=[0.9041320085525513, 0.9503306746482849, 1.1040148735046387, 1.0434362888336182, 0.5297629237174988]
#
# Validation Accuracy: 6.62%
# validation halt steps: mean=5.00 median=5 %step1=0.0% %never=100.0% dist={5: 5000}
# Training processed epoch 11
# Training processed epoch 12
# Training processed epoch 13
# Training processed epoch 14
# Training processed epoch 15
# Training processed epoch 16
# Training processed epoch 17
# Training processed epoch 18
# Training processed epoch 19
# Training processed epoch 20
#  Training epoch 20 | CE: 0.5531 | Q-Loss: 0.5397 | Avg Steps: 5.0
# halt logit: mean=1.210 std=0.201 max=2.054 %>0=100.0% %>1.5=6.9%
# halt steps: mean=5.00 median=5 %step1=0.0% %never=100.0% dist={5: 45000}
#
# Validation Logs ------
#
# sup_step_1 | mean=1.285 std=0.196 median=1.247 %>0=100.0% %>1.5=12.5% first5=[1.4876418113708496, 1.2240650653839111, 1.6804165840148926, 1.2131304740905762, 1.1246669292449951]
# sup_step_2 | mean=1.302 std=0.184 median=1.304 %>0=100.0% %>1.5=15.6% first5=[1.3484551906585693, 1.185413122177124, 1.659268856048584, 1.2794363498687744, 1.1491219997406006]
# sup_step_3 | mean=1.302 std=0.183 median=1.314 %>0=100.0% %>1.5=15.6% first5=[1.377359390258789, 1.1833443641662598, 1.6547162532806396, 1.2587308883666992, 1.1546180248260498]
# sup_step_4 | mean=1.303 std=0.181 median=1.305 %>0=100.0% %>1.5=15.6% first5=[1.377549171447754, 1.1830918788909912, 1.6537320613861084, 1.262798547744751, 1.154146432876587]
# sup_step_5 | mean=1.300 std=0.184 median=1.307 %>0=100.0% %>1.5=15.6% first5=[1.3773009777069092, 1.1832408905029297, 1.6536178588867188, 1.2624974250793457, 1.1539819240570068]
#
# Validation Accuracy: 9.00%
# validation halt steps: mean=5.00 median=5 %step1=0.0% %never=100.0% dist={5: 5000}
# Training processed epoch 21
# Training processed epoch 22
# Training processed epoch 23
# Training processed epoch 24
# Training processed epoch 25
# Training processed epoch 26
# Training processed epoch 27
# Training processed epoch 28
# Training processed epoch 29
# Training processed epoch 30
#  Training epoch 30 | CE: 0.5112 | Q-Loss: 0.5138 | Avg Steps: 5.0
# halt logit: mean=1.328 std=0.184 max=2.128 %>0=100.0% %>1.5=18.2%
# halt steps: mean=5.00 median=5 %step1=0.0% %never=100.0% dist={5: 45000}
#
# Validation Logs ------
#
# sup_step_1 | mean=1.401 std=0.179 median=1.336 %>0=100.0% %>1.5=28.1% first5=[1.626464605331421, 1.142061710357666, 1.7081060409545898, 1.2374951839447021, 1.33573317527771]
# sup_step_2 | mean=1.396 std=0.160 median=1.386 %>0=100.0% %>1.5=21.9% first5=[1.4395580291748047, 1.1107335090637207, 1.697303295135498, 1.1994915008544922, 1.3397886753082275]
# sup_step_3 | mean=1.407 std=0.171 median=1.375 %>0=100.0% %>1.5=21.9% first5=[1.5742993354797363, 1.1174683570861816, 1.7010464668273926, 1.1894643306732178, 1.34206223487854]
# sup_step_4 | mean=1.405 std=0.172 median=1.371 %>0=100.0% %>1.5=25.0% first5=[1.4791440963745117, 1.1171317100524902, 1.70180082321167, 1.1901769638061523, 1.3479719161987305]
# sup_step_5 | mean=1.404 std=0.170 median=1.371 %>0=100.0% %>1.5=25.0% first5=[1.6306955814361572, 1.1171233654022217, 1.7031302452087402, 1.1898057460784912, 1.3487300872802734]
#
# Validation Accuracy: 13.52%
# validation halt steps: mean=5.00 median=5 %step1=0.0% %never=100.0% dist={5: 5000}
# Training processed epoch 31
# Training processed epoch 32
# Training processed epoch 33
# Training processed epoch 34
# Training processed epoch 35
# Training processed epoch 36
# Training processed epoch 37
# Training processed epoch 38
# Training processed epoch 39
# Training processed epoch 40
#  Training epoch 40 | CE: 0.1689 | Q-Loss: 0.1936 | Avg Steps: 4.9815209665955935
# halt logit: mean=3.094 std=0.558 max=5.465 %>0=100.0% %>1.5=99.3%
# halt steps: mean=2.51 median=1 %step1=52.6% %never=33.8% dist={5: 15210, 1: 23686, 2: 5147, 3: 755, 4: 202}
#
# Validation Logs ------
#
# sup_step_1 | mean=3.346 std=0.364 median=3.336 %>0=100.0% %>1.5=100.0% first5=[4.175831317901611, 3.2406513690948486, 3.909303903579712, 2.8576207160949707, 2.8027868270874023]
# sup_step_2 | mean=3.441 std=0.325 median=3.428 %>0=100.0% %>1.5=100.0% first5=[4.2959370613098145, 3.4277849197387695, 3.682143449783325, 3.093893051147461, 2.748544454574585]
# sup_step_3 | mean=3.469 std=0.327 median=3.413 %>0=100.0% %>1.5=100.0% first5=[4.28652811050415, 3.4118943214416504, 3.7521157264709473, 3.061814069747925, 2.810507297515869]
# sup_step_4 | mean=3.482 std=0.337 median=3.462 %>0=100.0% %>1.5=100.0% first5=[4.290987491607666, 3.4156997203826904, 3.7580132484436035, 3.0532326698303223, 2.8134148120880127]
# sup_step_5 | mean=3.480 std=0.337 median=3.449 %>0=100.0% %>1.5=100.0% first5=[4.291512966156006, 3.414283037185669, 3.746758460998535, 3.058211088180542, 2.8125598430633545]
#
# Validation Accuracy: 75.54%
# validation halt steps: mean=2.04 median=1 %step1=65.2% %never=22.2% dist={1: 3259, 2: 540, 5: 1112, 3: 71, 4: 18}
# Training processed epoch 41
# Training processed epoch 42
# Training processed epoch 43
# Training processed epoch 44
# Training processed epoch 45
# Training processed epoch 46
# Training processed epoch 47
# Training processed epoch 48
# Training processed epoch 49
# Training processed epoch 50
#  Training epoch 50 | CE: 0.1362 | Q-Loss: 0.1518 | Avg Steps: 4.844349680170576
# halt logit: mean=3.464 std=0.604 max=5.870 %>0=100.0% %>1.5=99.7%
# halt steps: mean=1.75 median=1 %step1=74.4% %never=16.2% dist={1: 33484, 2: 3850, 3: 307, 5: 7295, 4: 64}
#
# Validation Logs ------
#
# sup_step_1 | mean=3.189 std=0.488 median=3.189 %>0=100.0% %>1.5=100.0% first5=[3.3295578956604004, 3.2834396362304688, 3.2881016731262207, 3.801644802093506, 2.565460205078125]
# sup_step_2 | mean=3.253 std=0.535 median=3.203 %>0=100.0% %>1.5=100.0% first5=[3.41092586517334, 3.4683070182800293, 3.1018247604370117, 4.0747575759887695, 2.6669955253601074]
# sup_step_3 | mean=3.222 std=0.511 median=3.097 %>0=100.0% %>1.5=100.0% first5=[3.3363704681396484, 3.366330146789551, 3.0576744079589844, 3.949225902557373, 2.7202792167663574]
# sup_step_4 | mean=3.245 std=0.491 median=3.077 %>0=100.0% %>1.5=100.0% first5=[3.3286080360412598, 3.4024887084960938, 3.0611343383789062, 3.989560127258301, 2.7110748291015625]
# sup_step_5 | mean=3.241 std=0.501 median=3.081 %>0=100.0% %>1.5=100.0% first5=[3.3301568031311035, 3.4017810821533203, 3.062044620513916, 3.9986824989318848, 2.7091593742370605]
#
# Validation Accuracy: 77.50%
# validation halt steps: mean=2.59 median=1 %step1=51.4% %never=36.5% dist={1: 2572, 5: 1826, 2: 553, 3: 39, 4: 10}
# Training processed epoch 51
# Training processed epoch 52
# Training processed epoch 53
# Training processed epoch 54
# Training processed epoch 55
# Training processed epoch 56
# Training processed epoch 57
# Training processed epoch 58
# Training processed epoch 59
# Training processed epoch 60
#  Training epoch 60 | CE: 0.1672 | Q-Loss: 0.1510 | Avg Steps: 4.7690120824449185
# halt logit: mean=3.489 std=0.693 max=5.912 %>0=100.0% %>1.5=99.2%
# halt steps: mean=1.79 median=1 %step1=73.1% %never=17.0% dist={1: 32878, 5: 7663, 2: 4064, 3: 332, 4: 63}
#
# Validation Logs ------
#
# sup_step_1 | mean=3.217 std=0.628 median=3.197 %>0=100.0% %>1.5=100.0% first5=[3.1005213260650635, 3.9362356662750244, 3.3390464782714844, 3.3257734775543213, 2.814176082611084]
# sup_step_2 | mean=3.334 std=0.633 median=3.218 %>0=100.0% %>1.5=100.0% first5=[3.217832088470459, 3.8335514068603516, 3.178058624267578, 3.828629732131958, 3.103508234024048]
# sup_step_3 | mean=3.335 std=0.635 median=3.195 %>0=100.0% %>1.5=100.0% first5=[3.194509267807007, 3.832111358642578, 3.1671886444091797, 3.6101300716400146, 3.1121320724487305]
# sup_step_4 | mean=3.320 std=0.612 median=3.190 %>0=100.0% %>1.5=100.0% first5=[3.189699411392212, 3.859076738357544, 3.160975933074951, 3.6618542671203613, 3.092349052429199]
# sup_step_5 | mean=3.316 std=0.612 median=3.190 %>0=100.0% %>1.5=100.0% first5=[3.18980073928833, 3.841257095336914, 3.1602816581726074, 3.6855545043945312, 3.0882301330566406]
#
# Validation Accuracy: 85.78%
# validation halt steps: mean=2.61 median=1 %step1=53.4% %never=37.7% dist={1: 2668, 2: 394, 5: 1886, 3: 43, 4: 9}
# Training processed epoch 61
# Training processed epoch 62
# Training processed epoch 63
# Training processed epoch 64
# Training processed epoch 65
# Training processed epoch 66
# Training processed epoch 67
# Training processed epoch 68
# Training processed epoch 69
# Training processed epoch 70
#  Training epoch 70 | CE: 0.1166 | Q-Loss: 0.1158 | Avg Steps: 4.550817341862118
# halt logit: mean=3.853 std=0.734 max=6.773 %>0=100.0% %>1.5=99.9%
# halt steps: mean=1.42 median=1 %step1=85.9% %never=9.2% dist={1: 38647, 2: 2004, 5: 4127, 3: 188, 4: 34}
#
# Validation Logs ------
#
# sup_step_1 | mean=3.955 std=0.728 median=3.967 %>0=100.0% %>1.5=100.0% first5=[5.0753493309021, 3.830829620361328, 4.353199481964111, 3.0713188648223877, 2.562012195587158]
# sup_step_2 | mean=3.955 std=0.668 median=3.946 %>0=100.0% %>1.5=100.0% first5=[5.041628360748291, 3.7481775283813477, 4.30775260925293, 3.406843900680542, 2.51979923248291]
# sup_step_3 | mean=3.973 std=0.671 median=4.014 %>0=100.0% %>1.5=100.0% first5=[4.993533134460449, 3.7581522464752197, 4.273331165313721, 3.323608636856079, 2.5709969997406006]
# sup_step_4 | mean=3.971 std=0.665 median=4.035 %>0=100.0% %>1.5=100.0% first5=[5.001707077026367, 3.7546136379241943, 4.266546249389648, 3.3330469131469727, 2.5902600288391113]
# sup_step_5 | mean=3.976 std=0.668 median=4.021 %>0=100.0% %>1.5=100.0% first5=[5.005614757537842, 3.7549352645874023, 4.264008522033691, 3.3368961811065674, 2.6072473526000977]
#
# Validation Accuracy: 90.04%
# validation halt steps: mean=1.25 median=1 %step1=90.3% %never=4.8% dist={1: 4514, 5: 241, 2: 225, 3: 19, 4: 1}
# Training processed epoch 71
# Training processed epoch 72
# Training processed epoch 73
# Training processed epoch 74
# Training processed epoch 75
# Training processed epoch 76
# Training processed epoch 77
# Training processed epoch 78
# Training processed epoch 79
# Training processed epoch 80
#  Training epoch 80 | CE: 0.0963 | Q-Loss: 0.0996 | Avg Steps: 3.616915422885572
# halt logit: mean=4.012 std=0.802 max=7.344 %>0=100.0% %>1.5=99.9%
# halt steps: mean=1.27 median=1 %step1=90.9% %never=6.0% dist={1: 40885, 3: 116, 2: 1279, 5: 2704, 4: 16}
#
# Validation Logs ------
#
# sup_step_1 | mean=3.618 std=0.513 median=3.651 %>0=100.0% %>1.5=100.0% first5=[3.6865506172180176, 3.650794267654419, 4.420289993286133, 3.3335001468658447, 2.906022071838379]
# sup_step_2 | mean=3.681 std=0.457 median=3.700 %>0=100.0% %>1.5=100.0% first5=[3.7866907119750977, 3.6429505348205566, 4.2168684005737305, 3.3655495643615723, 2.9604299068450928]
# sup_step_3 | mean=3.699 std=0.467 median=3.676 %>0=100.0% %>1.5=100.0% first5=[3.784738302230835, 3.639059066772461, 4.173288345336914, 3.3860270977020264, 2.991468667984009]
# sup_step_4 | mean=3.690 std=0.463 median=3.666 %>0=100.0% %>1.5=100.0% first5=[3.7875003814697266, 3.639317274093628, 4.1803083419799805, 3.3865010738372803, 2.9907262325286865]
# sup_step_5 | mean=3.684 std=0.457 median=3.675 %>0=100.0% %>1.5=100.0% first5=[3.787688970565796, 3.6414520740509033, 4.187406063079834, 3.3857080936431885, 2.988992691040039]
#
# Validation Accuracy: 87.28%
# validation halt steps: mean=1.72 median=1 %step1=77.6% %never=16.3% dist={1: 3878, 5: 816, 2: 290, 3: 14, 4: 2}
# Training processed epoch 81
# Training processed epoch 82
# Training processed epoch 83
# Training processed epoch 84
# Training processed epoch 85
# Training processed epoch 86
# Training processed epoch 87
# Training processed epoch 88
# Training processed epoch 89
# Training processed epoch 90
#  Training epoch 90 | CE: 0.0923 | Q-Loss: 0.0924 | Avg Steps: 3.8272921108742004
# halt logit: mean=4.162 std=0.853 max=7.324 %>0=100.0% %>1.5=99.9%
# halt steps: mean=1.24 median=1 %step1=91.8% %never=5.1% dist={1: 41291, 3: 112, 5: 2290, 2: 1281, 4: 26}
#
# Validation Logs ------
#
# sup_step_1 | mean=3.956 std=0.737 median=4.089 %>0=100.0% %>1.5=100.0% first5=[4.236548900604248, 3.8423116207122803, 4.544626712799072, 4.145973205566406, 2.874715566635132]
# sup_step_2 | mean=4.026 std=0.574 median=3.911 %>0=100.0% %>1.5=100.0% first5=[4.212317943572998, 3.9756884574890137, 4.245131015777588, 4.107558727264404, 3.0967938899993896]
#
# Validation Accuracy: 86.60%
# validation halt steps: mean=1.35 median=1 %step1=88.3% %never=7.6% dist={1: 4413, 2: 190, 5: 381, 3: 14, 4: 2}
# Training processed epoch 91
# Training processed epoch 92
# Training processed epoch 93
# Training processed epoch 94
# Training processed epoch 95
# Training processed epoch 96
# Training processed epoch 97
# Training processed epoch 98
# Training processed epoch 99

# %%
## s-16

# Config: n_sup=16, halt > 0, c=0.1, T=3, 100 epochs
# Supervision sweep at the paper's N_sup = 16: does more recursion room change anything
# once halting collapses to step 1?
# Log: training-logs/softmean-nsup-16.txt

HALT_THRESHOLD = 0
model_training_and_validation_with_mask(c=0.1, T=3, n_sup=16, HALT_THRESHOLD = HALT_THRESHOLD)
# Out:
# PAD_TOKEN:  11
# Training Logs ------
#
# Training processed epoch 0
#  Training epoch 0 | CE: 1.6392 | Q-Loss: 0.6163 | Avg Steps: 16.0
# halt logit: mean=-0.779 std=0.436 max=0.233 %>0=0.5% %>1.5=0.0%
# halt steps: mean=15.79 median=16 %step1=1.3% %never=98.6% dist={1: 597, 16: 44374, 2: 22, 3: 6, 4: 1}
#
# Validation Logs ------
#
# sup_step_1 | mean=-0.666 std=0.371 median=-0.504 %>0=0.0% %>1.5=0.0% first5=[-0.3135093152523041, -0.9378157258033752, -0.3153935670852661, -1.110496997833252, -0.9781010150909424]
# sup_step_2 | mean=-0.695 std=0.359 median=-0.579 %>0=0.0% %>1.5=0.0% first5=[-0.31549376249313354, -0.9571908712387085, -0.3644023537635803, -1.145429015159607, -0.9870710372924805]
# sup_step_3 | mean=-0.703 std=0.376 median=-0.573 %>0=0.0% %>1.5=0.0% first5=[-0.3011770248413086, -0.9682823419570923, -0.3605133295059204, -1.1764041185379028, -0.9605855345726013]
# sup_step_4 | mean=-0.704 std=0.369 median=-0.574 %>0=0.0% %>1.5=0.0% first5=[-0.3094678223133087, -0.9585202932357788, -0.3632509112358093, -1.18169367313385, -0.9537487030029297]
# sup_step_5 | mean=-0.706 std=0.371 median=-0.576 %>0=0.0% %>1.5=0.0% first5=[-0.30940312147140503, -0.9693981409072876, -0.36339569091796875, -1.1839911937713623, -0.9532306790351868]
# sup_step_6 | mean=-0.705 std=0.371 median=-0.576 %>0=0.0% %>1.5=0.0% first5=[-0.30893003940582275, -0.9607410430908203, -0.3635726571083069, -1.184580683708191, -0.9533990621566772]
# sup_step_7 | mean=-0.706 std=0.371 median=-0.576 %>0=0.0% %>1.5=0.0% first5=[-0.308855801820755, -0.9677410125732422, -0.3636266589164734, -1.1847788095474243, -0.9534505605697632]
# sup_step_8 | mean=-0.705 std=0.371 median=-0.576 %>0=0.0% %>1.5=0.0% first5=[-0.30887001752853394, -0.962716817855835, -0.36365246772766113, -1.184836745262146, -0.9534554481506348]
# sup_step_9 | mean=-0.705 std=0.371 median=-0.576 %>0=0.0% %>1.5=0.0% first5=[-0.3088763952255249, -0.9663380980491638, -0.36366236209869385, -1.1848548650741577, -0.9534552693367004]
# sup_step_10 | mean=-0.705 std=0.371 median=-0.576 %>0=0.0% %>1.5=0.0% first5=[-0.308876633644104, -0.9639327526092529, -0.3636665344238281, -1.184860348701477, -0.9534552097320557]
# sup_step_11 | mean=-0.705 std=0.371 median=-0.576 %>0=0.0% %>1.5=0.0% first5=[-0.30887600779533386, -0.9655483365058899, -0.3636683225631714, -1.1848621368408203, -0.9534550905227661]
# sup_step_12 | mean=-0.705 std=0.371 median=-0.576 %>0=0.0% %>1.5=0.0% first5=[-0.3088756203651428, -0.9644922614097595, -0.3636690378189087, -1.1848623752593994, -0.9534549117088318]
# sup_step_13 | mean=-0.705 std=0.371 median=-0.576 %>0=0.0% %>1.5=0.0% first5=[-0.3088759779930115, -0.9651670455932617, -0.3636692762374878, -1.1848626136779785, -0.9534549713134766]
# sup_step_14 | mean=-0.705 std=0.371 median=-0.576 %>0=0.0% %>1.5=0.0% first5=[-0.3088759779930115, -0.9647464156150818, -0.36366939544677734, -1.184862494468689, -0.9534547328948975]
# sup_step_15 | mean=-0.705 std=0.371 median=-0.576 %>0=0.0% %>1.5=0.0% first5=[-0.3088759779930115, -0.965001106262207, -0.36366939544677734, -1.184862732887268, -0.953454852104187]
# sup_step_16 | mean=-0.705 std=0.371 median=-0.576 %>0=0.0% %>1.5=0.0% first5=[-0.30887606739997864, -0.9648513793945312, -0.36366933584213257, -1.184862732887268, -0.9534547328948975]
#
# Validation Accuracy: 0.06%
# validation halt steps: mean=16.00 median=16 %step1=0.0% %never=100.0% dist={16: 5000}
# Training processed epoch 1
# Training processed epoch 2
# Training processed epoch 3
# Training processed epoch 4
# Training processed epoch 5
# Training processed epoch 6
# Training processed epoch 7
# Training processed epoch 8
# Training processed epoch 9
# Training processed epoch 10
#  Training epoch 10 | CE: 1.0739 | Q-Loss: 0.6898 | Avg Steps: 12.73134328358209
# halt logit: mean=0.153 std=0.153 max=0.875 %>0=83.7% %>1.5=0.0%
# halt steps: mean=2.57 median=1 %step1=87.3% %never=10.3% dist={1: 39277, 16: 4639, 2: 956, 3: 114, 4: 10, 5: 1, 7: 1, 6: 2}
#
# Validation Logs ------
#
# sup_step_1 | mean=0.247 std=0.156 median=0.255 %>0=93.8% %>1.5=0.0% first5=[0.14391979575157166, 0.16708356142044067, 0.42729413509368896, 0.3265354633331299, -0.026694610714912415]
# sup_step_2 | mean=0.247 std=0.153 median=0.260 %>0=90.6% %>1.5=0.0% first5=[0.12898775935173035, 0.20866847038269043, 0.4773157238960266, 0.34743472933769226, -0.03629187494516373]
# sup_step_3 | mean=0.257 std=0.153 median=0.275 %>0=90.6% %>1.5=0.0% first5=[0.1507481038570404, 0.2132829874753952, 0.4418180584907532, 0.3487027883529663, -0.033224523067474365]
# sup_step_4 | mean=0.249 std=0.155 median=0.254 %>0=90.6% %>1.5=0.0% first5=[0.13951027393341064, 0.2107122540473938, 0.4486924409866333, 0.34834930300712585, -0.033854857087135315]
# sup_step_5 | mean=0.254 std=0.154 median=0.272 %>0=90.6% %>1.5=0.0% first5=[0.14043721556663513, 0.21182462573051453, 0.4514148235321045, 0.3483799993991852, -0.033909015357494354]
# sup_step_6 | mean=0.251 std=0.154 median=0.253 %>0=90.6% %>1.5=0.0% first5=[0.14441505074501038, 0.21157637238502502, 0.45005491375923157, 0.3483864367008209, -0.033892497420310974]
# sup_step_7 | mean=0.252 std=0.154 median=0.253 %>0=90.6% %>1.5=0.0% first5=[0.14178243279457092, 0.21158546209335327, 0.4501362442970276, 0.34838467836380005, -0.03389070928096771]
# sup_step_8 | mean=0.252 std=0.153 median=0.253 %>0=90.6% %>1.5=0.0% first5=[0.14225104451179504, 0.2116033434867859, 0.4502411484718323, 0.348384290933609, -0.03389179706573486]
# sup_step_9 | mean=0.251 std=0.155 median=0.253 %>0=90.6% %>1.5=0.0% first5=[0.1427249014377594, 0.21159465610980988, 0.45020776987075806, 0.3483842611312866, -0.03389167785644531]
# sup_step_10 | mean=0.252 std=0.154 median=0.253 %>0=90.6% %>1.5=0.0% first5=[0.14229866862297058, 0.2115969955921173, 0.4502063989639282, 0.34838446974754333, -0.03389158099889755]
# sup_step_11 | mean=0.251 std=0.154 median=0.253 %>0=90.6% %>1.5=0.0% first5=[0.14242389798164368, 0.21159672737121582, 0.45020970702171326, 0.3483845293521881, -0.03389175236225128]
# sup_step_12 | mean=0.252 std=0.154 median=0.253 %>0=90.6% %>1.5=0.0% first5=[0.14246997237205505, 0.21159648895263672, 0.45020925998687744, 0.34838446974754333, -0.03389177471399307]
# sup_step_13 | mean=0.250 std=0.155 median=0.253 %>0=90.6% %>1.5=0.0% first5=[0.14240553975105286, 0.21159663796424866, 0.45020899176597595, 0.3483845889568329, -0.03389161080121994]
# sup_step_14 | mean=0.253 std=0.153 median=0.253 %>0=90.6% %>1.5=0.0% first5=[0.14243176579475403, 0.2115965336561203, 0.4502091705799103, 0.3483843505382538, -0.03389166295528412]
# sup_step_15 | mean=0.250 std=0.155 median=0.253 %>0=90.6% %>1.5=0.0% first5=[0.14243432879447937, 0.21159663796424866, 0.4502090513706207, 0.34838446974754333, -0.033891625702381134]
# sup_step_16 | mean=0.255 std=0.154 median=0.273 %>0=90.6% %>1.5=0.0% first5=[0.14242520928382874, 0.21159672737121582, 0.45020902156829834, 0.34838441014289856, -0.03389163315296173]
#
# Validation Accuracy: 2.00%
# validation halt steps: mean=1.50 median=1 %step1=95.5% %never=3.2% dist={1: 4773, 16: 159, 3: 11, 6: 3, 13: 1, 4: 2, 2: 50, 5: 1}
# Training processed epoch 11
# Training processed epoch 12
# Training processed epoch 13
# Training processed epoch 14
# Training processed epoch 15
# Training processed epoch 16
# Training processed epoch 17
# Training processed epoch 18
# Training processed epoch 19
# Training processed epoch 20
#  Training epoch 20 | CE: 0.5612 | Q-Loss: 0.5443 | Avg Steps: 1.0
# halt logit: mean=1.190 std=0.203 max=2.077 %>0=100.0% %>1.5=6.7%
# halt steps: mean=1.00 median=1 %step1=100.0% %never=0.0% dist={1: 45000}
#
# Validation Logs ------
#
# sup_step_1 | mean=1.143 std=0.146 median=1.120 %>0=100.0% %>1.5=0.0% first5=[1.3503010272979736, 1.0986088514328003, 1.067166805267334, 1.1195636987686157, 0.8057572245597839]
#
# Validation Accuracy: 8.46%
# validation halt steps: mean=1.00 median=1 %step1=100.0% %never=0.0% dist={1: 5000}
# Training processed epoch 21
# Training processed epoch 22
# Training processed epoch 23
# Training processed epoch 24
# Training processed epoch 25
# Training processed epoch 26
# Training processed epoch 27
# Training processed epoch 28
# Training processed epoch 29
# Training processed epoch 30
#  Training epoch 30 | CE: 0.5203 | Q-Loss: 0.5216 | Avg Steps: 1.0
# halt logit: mean=1.292 std=0.186 max=2.006 %>0=100.0% %>1.5=14.3%
# halt steps: mean=1.00 median=1 %step1=100.0% %never=0.0% dist={1: 45000}
#
# Validation Logs ------
#
# sup_step_1 | mean=1.321 std=0.242 median=1.316 %>0=100.0% %>1.5=25.0% first5=[1.3724827766418457, 1.0195000171661377, 1.6407712697982788, 1.0827794075012207, 0.9268566966056824]
#
# Validation Accuracy: 9.72%
# validation halt steps: mean=1.00 median=1 %step1=100.0% %never=0.0% dist={1: 5000}
# Training processed epoch 31
# Training processed epoch 32
# Training processed epoch 33
# Training processed epoch 34
# Training processed epoch 35
# Training processed epoch 36
# Training processed epoch 37
# Training processed epoch 38
# Training processed epoch 39
# Training processed epoch 40
#  Training epoch 40 | CE: 0.0663 | Q-Loss: 0.1007 | Avg Steps: 1.0
# halt logit: mean=4.097 std=0.786 max=7.246 %>0=100.0% %>1.5=99.9%
# halt steps: mean=1.00 median=1 %step1=100.0% %never=0.0% dist={1: 45000}
#
# Validation Logs ------
#
# sup_step_1 | mean=4.415 std=0.781 median=4.409 %>0=100.0% %>1.5=100.0% first5=[3.500574827194214, 4.6102399826049805, 5.051478385925293, 4.11749267578125, 2.391026258468628]
#
# Validation Accuracy: 89.48%
# validation halt steps: mean=1.00 median=1 %step1=100.0% %never=0.0% dist={1: 5000}
# Training processed epoch 41
# Training processed epoch 42
# Training processed epoch 43
# Training processed epoch 44
# Training processed epoch 45
# Training processed epoch 46
# Training processed epoch 47
# Training processed epoch 48
# Training processed epoch 49
# Training processed epoch 50
#  Training epoch 50 | CE: 0.0459 | Q-Loss: 0.0641 | Avg Steps: 1.0
# halt logit: mean=4.862 std=1.056 max=8.540 %>0=100.0% %>1.5=99.8%
# halt steps: mean=1.00 median=1 %step1=100.0% %never=0.0% dist={1: 45000}
#
# Validation Logs ------
#
# sup_step_1 | mean=5.094 std=0.864 median=4.885 %>0=100.0% %>1.5=100.0% first5=[4.4249677658081055, 4.59941291809082, 5.577154159545898, 4.846619129180908, 3.303753614425659]
#
# Validation Accuracy: 96.94%
# validation halt steps: mean=1.00 median=1 %step1=100.0% %never=0.0% dist={1: 5000}
# Training processed epoch 51
# Training processed epoch 52
# Training processed epoch 53
# Training processed epoch 54
# Training processed epoch 55
# Training processed epoch 56
# Training processed epoch 57
# Training processed epoch 58
# Training processed epoch 59
# Training processed epoch 60
#  Training epoch 60 | CE: 0.0196 | Q-Loss: 0.0388 | Avg Steps: 1.0
# halt logit: mean=5.384 std=0.914 max=8.632 %>0=100.0% %>1.5=100.0%
# halt steps: mean=1.00 median=1 %step1=100.0% %never=0.0% dist={1: 45000}
#
# Validation Logs ------
#
# sup_step_1 | mean=5.847 std=0.754 median=5.759 %>0=100.0% %>1.5=100.0% first5=[5.270733833312988, 5.021571159362793, 5.77754020690918, 6.504358768463135, 4.293936252593994]
#
# Validation Accuracy: 98.66%
# validation halt steps: mean=1.00 median=1 %step1=100.0% %never=0.0% dist={1: 5000}
# Training processed epoch 61
# Training processed epoch 62
# Training processed epoch 63
# Training processed epoch 64
# Training processed epoch 65
# Training processed epoch 66
# Training processed epoch 67
# Training processed epoch 68
# Training processed epoch 69
# Training processed epoch 70
#  Training epoch 70 | CE: 0.0200 | Q-Loss: 0.0395 | Avg Steps: 1.0
# halt logit: mean=5.426 std=1.017 max=8.865 %>0=100.0% %>1.5=100.0%
# halt steps: mean=1.00 median=1 %step1=100.0% %never=0.0% dist={1: 45000}
#
# Validation Logs ------
#
# sup_step_1 | mean=6.711 std=0.780 median=6.720 %>0=100.0% %>1.5=100.0% first5=[6.052252769470215, 7.201272964477539, 6.3592753410339355, 6.392094612121582, 4.85361385345459]
#
# Validation Accuracy: 98.58%
# validation halt steps: mean=1.00 median=1 %step1=100.0% %never=0.0% dist={1: 5000}
# Training processed epoch 71
# Training processed epoch 72
# Training processed epoch 73
# Training processed epoch 74
# Training processed epoch 75
# Training processed epoch 76
# Training processed epoch 77
# Training processed epoch 78
# Training processed epoch 79
# Training processed epoch 80
#  Training epoch 80 | CE: 0.0217 | Q-Loss: 0.0369 | Avg Steps: 1.0
# halt logit: mean=5.720 std=1.186 max=10.384 %>0=100.0% %>1.5=100.0%
# halt steps: mean=1.00 median=1 %step1=100.0% %never=0.0% dist={1: 45000}
#
# Validation Logs ------
#
# sup_step_1 | mean=4.523 std=0.725 median=4.570 %>0=100.0% %>1.5=100.0% first5=[4.6941022872924805, 4.260364532470703, 4.832320690155029, 3.774883985519409, 3.8939177989959717]
#
# Validation Accuracy: 94.26%
# validation halt steps: mean=1.00 median=1 %step1=100.0% %never=0.0% dist={1: 5000}
# Training processed epoch 81
# Training processed epoch 82
# Training processed epoch 83
# Training processed epoch 84
# Training processed epoch 85
# Training processed epoch 86
# Training processed epoch 87
# Training processed epoch 88
# Training processed epoch 89
# Training processed epoch 90
#  Training epoch 90 | CE: 0.0132 | Q-Loss: 0.0241 | Avg Steps: 1.0
# halt logit: mean=6.272 std=1.210 max=9.874 %>0=100.0% %>1.5=100.0%
# halt steps: mean=1.00 median=1 %step1=100.0% %never=0.0% dist={1: 45000}
#
# Validation Logs ------
#
# sup_step_1 | mean=4.507 std=0.695 median=4.531 %>0=100.0% %>1.5=100.0% first5=[4.531190395355225, 4.6239495277404785, 4.622840881347656, 4.377862930297852, 3.813722610473633]
#
# Validation Accuracy: 94.72%
# validation halt steps: mean=1.00 median=1 %step1=100.0% %never=0.0% dist={1: 5000}
# Training processed epoch 91
# Training processed epoch 92
# Training processed epoch 93
# Training processed epoch 94
# Training processed epoch 95
# Training processed epoch 96
# Training processed epoch 97
# Training processed epoch 98
# Training processed epoch 99

# %% [markdown]
# ## Key Observations
#
# - Using mean loss across steps harms per-example optimization
# - If q_halt becomes negative early, future optimization is skipped
# - Masking improves stability by preserving active samples

# %% [markdown]
# ### Key Observation: Effect of Halting Coefficient (c)
#
# - c controls the trade-off between prediction and halting behavior
# - With small c (0.01), model halts after 1 step (n_taken = 1)
# - This reduces effective reasoning depth despite high accuracy
# - Indicates that halting must be carefully balanced to enable multi-step reasoning
