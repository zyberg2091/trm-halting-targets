# %%
# define Meta data

# rec_loops = 3

# %% [markdown]
# ### Paper : Less is More: Recursive Reasoning with Tiny Networks, Oct 2025
# (https://arxiv.org/pdf/2510.04871)

# %% [markdown]
# ## Problem Overview
#
# We study Recursive Reasoning using Tiny Networks (TRM).
#
# Goal:
# Instead of increasing model size, we improve reasoning by:
# - reusing the same network multiple times
# - learning when to halt (q_halt)
#
# Key Idea:
# Compute multiple reasoning steps and decide dynamically when to stop.

# %%
import torch
from torch import nn

# %% [markdown]
# ## Model Architecture
#
# Components:
# - f: prediction head
# - q_halt: halting probability
#
# At each step t:
# 1. Model updates hidden state
# 2. Predicts output
# 3. Predicts whether to stop
#
# Final output depends on halting decision.

# %% [markdown]
# - Latent layers are not directly tracked in gradients.
# - They are used to refine the internal states.
# - This helps y and z move toward a stable representation before reasoning begins.

# %%
class TinyRModel(nn.Module):
  def __init__(self, hidden_size, vocab_size, inp_seq_len, out_seq_len):
    super().__init__()
    self.net = nn.Sequential(nn.Linear(hidden_size, hidden_size),
                              nn.ReLU(),
                              nn.Linear(hidden_size, hidden_size))

    self.embedding = nn.Embedding(vocab_size, hidden_size)
    self.input_proj = nn.Linear(inp_seq_len * hidden_size, hidden_size)


    self.out = nn.Linear(hidden_size, out_seq_len * vocab_size)
    self.halt = nn.Linear(hidden_size, 1)



  def latent(self, x, y, z, n=6):
      # Phase 1: update z (n times), x included
      for i in range(n):
          z = self.net(x + y + z)   # element-wise add → D-dim input

      # Phase 2: update y once, WITHOUT x
      y = self.net(y + z)           # same net, different input mix

      return y, z



  def forward(self, x, y, z, T, n=6):

    x = self.embedding(x)          # (B, L, H)
    x = x.view(x.size(0), -1)              # flatten
    x = self.input_proj(x)                 # (B, H)

    with torch.no_grad():
      for j in range(T-1):
        y, z= self.latent(x,y,z,n)

    y, z = self.latent(x, y, z, n)

    f_out = self.out(y)

    halt= self.halt(y) #calculate halt from y

    return f_out, halt, y, z

# %% [markdown]
# ### Dataset Description: Majority Task
# The dataset consists of fixed-length binary sequences ($0$s and $1$s). The goal is to classify the sequence based on the majority bit:
# - **Label 1**: If the count of $1$s is greater than the count of $0$s.
# - **Label 0**: If the count of $0$s is greater than the count of $1$s.
#
# Ties are excluded to ensure unambiguous labeling. This serves as a simple reasoning task for the recursive model.

# %%
# Simple dataset

# import torch
# import random
# from torch.utils.data import Dataset, DataLoader, random_split

# # ── config ───────────────────────────────────────────────────────────────
# hidden_size = 64
# batch_size  = 32
# device      = 'cuda' if torch.cuda.is_available() else 'cpu'
# vocab_size  = 2    # only real tokens: 0 and 1
# num_classes = 2    # label 0 or 1
# seq_len     = 15   # fixed length — no padding needed

# # ── dataset ──────────────────────────────────────────────────────────────
# class MajorityDataset(Dataset):
#     """
#     Fixed-length binary sequences, no padding, no masking.
#     Label = 1 if 1s are majority, 0 if 0s are majority.
#     Ties skipped to avoid ambiguous labels.
#     """
#     def __init__(self, num_samples=10000, seq_len=seq_len):
#         self.samples = self._generate(num_samples, seq_len)

#     def _generate(self, n, seq_len):
#         samples = []
#         while len(samples) < n:
#             seq   = [random.randint(0, 1) for _ in range(seq_len)]
#             ones  = sum(seq)
#             zeros = seq_len - ones
#             if ones == zeros:       # skip ties
#                 continue
#             label = 1 if ones > zeros else 0
#             samples.append((seq, label))
#         return samples

#     def __len__(self):
#         return len(self.samples)

#     def __getitem__(self, idx):
#         seq, label = self.samples[idx]
#         return {
#             "input_ids": torch.tensor(seq,   dtype=torch.long),
#             "labels":    torch.tensor(label, dtype=torch.long),
#         }

# # ── dataloaders ──────────────────────────────────────────────────────────
# dataset  = MajorityDataset(num_samples=10000)
# val_size = 1000
# train_set, val_set = random_split(dataset, [len(dataset) - val_size, val_size])

# train_loader = DataLoader(train_set, batch_size=batch_size, shuffle=True)
# val_loader   = DataLoader(val_set,   batch_size=batch_size, shuffle=False)

# %% [markdown]
# ## Addition Dataset

# %%
import torch
import random
from torch.utils.data import Dataset, DataLoader, random_split

def generate_pair(num_digits):
    a = random.randint(10**(num_digits-1), 10**num_digits - 1)
    b = random.randint(10**(num_digits-1), 10**num_digits - 1)
    return str(a), str(b)


operands_a, operands_b = [], []

for sample_idx in range(50000):
    num_a, num_b = generate_pair(num_digits=4)

    operands_a.append(num_a)
    operands_b.append(num_b)

# %%
dataset = []

for num_a, num_b in zip(operands_a, operands_b):

    input_sequence = list(num_a) + ['+'] + list(num_b)

    rev_a = list(reversed(num_a))
    rev_b = list(reversed(num_b))

    num_digits = len(num_a)

    result_digits = []
    carry_sequence = []

    carry = 0
    current_chain_length = 0
    max_carry_chain = 0

    for digit_a, digit_b in zip(rev_a, rev_b):

        digit_sum = int(digit_a) + int(digit_b) + carry

        output_digit = digit_sum % 10
        new_carry = digit_sum // 10

        result_digits.append(output_digit)
        carry_sequence.append(new_carry)

        if new_carry == 1:
            current_chain_length += 1
            max_carry_chain = max(max_carry_chain, current_chain_length)
        else:
            current_chain_length = 0

        carry = new_carry

    if carry > 0:
        result_digits.append(carry)

    final_output = list(reversed(result_digits))

    data = {
        'input': input_sequence,
        'output': final_output,
        'num_digits': num_digits,
        'carry_sequence': carry_sequence,
        'max_carry_chain': max_carry_chain
    }

    dataset.append(data)

print(dataset[0], len(dataset))
# Out:
# {'input': ['6', '7', '0', '9', '+', '2', '7', '3', '8'], 'output': [9, 4, 4, 7], 'num_digits': 4, 'carry_sequence': [1, 0, 1, 0], 'max_carry_chain': 1} 50000

# %%
import torch
from torch.utils.data import Dataset

device = 'cuda' if torch.cuda.is_available() else 'cpu'

PAD_TOKEN = 11
PLUS_TOKEN = 10

inp_seq_len = 9
out_seq_len = 5


class AdditionDataset(Dataset):
    def __init__(self, dataset_list, max_input_len=inp_seq_len, max_output_len=out_seq_len):
        self.data = dataset_list
        self.max_input_len = max_input_len
        self.max_output_len = max_output_len

    def pad(self, seq, max_len, pad_value=PAD_TOKEN):
        return seq + [pad_value] * (max_len - len(seq))

    def encode_input(self, input_seq):
        return [
            int(x) if x != '+' else PLUS_TOKEN
            for x in input_seq
        ]

    def __len__(self):
        return len(self.data)

    def __getitem__(self, idx):
        sample = self.data[idx]

        input_ids = self.encode_input(sample['input'])
        labels    = sample['output']

        input_ids = self.pad(input_ids, self.max_input_len)
        labels    = self.pad(labels, self.max_output_len)

        return {
            "input_ids": torch.tensor(input_ids, dtype=torch.long),
            "labels": torch.tensor(labels, dtype=torch.long)
        }



hidden_size = 256

batch_size  = 32

vocab_size = 12

dataset = AdditionDataset(dataset)

val_size = 5000
train_size = len(dataset) - val_size

train_set, val_set = random_split(dataset, [train_size, val_size])

train_loader = DataLoader(train_set, batch_size=batch_size, shuffle=True)
val_loader   = DataLoader(val_set,   batch_size=batch_size)

# %% [markdown]
# ## Loss Function
#
# We use two losses:
#
# 1. Prediction Loss:
#    Cross entropy between prediction and label
#
# 2. Halting Loss:
#    Binary classification:
#    - 1 if prediction correct
#    - 0 otherwise
#
# This encourages:
# → stop when correct
# → continue when wrong

# %%
# def model_training_and_validation_with_mask(c, T, n_sup):
#     model = TinyRModel(hidden_size, vocab_size, inp_seq_len=12, out_seq_len=6).to(device)
#     optimizer = torch.optim.Adam(model.parameters(), lr=1e-4)

#     print('PAD_TOKEN: ', PAD_TOKEN)
#     criterion = nn.CrossEntropyLoss(reduction='none', ignore_index=PAD_TOKEN)

#     running_loss = 0
#     running_q = 0

#     print('Training Logs ------ \n')
#     model.train()
#     for step, batch in enumerate(train_loader):
#         input_ids = batch['input_ids'].to(device)
#         labels = batch['labels'].to(device)
#         batch_size_curr = input_ids.size(0)
#         seq_len = labels.size(1)

#         active_mask = torch.ones(batch_size_curr, dtype=torch.bool, device=device)

#         x = input_ids
#         y = torch.zeros(batch_size_curr, hidden_size, device=device)
#         z = torch.zeros(batch_size_curr, hidden_size, device=device)

#         step_loss = step_q = 0
#         overall_loss = torch.tensor(0.0, device=device)

#         for i in range(n_sup):
#             y_new, z_new, halt, out = model(x, y, z, halt, out)


#             y = torch.where(active_mask.unsqueeze(1), y_new.detach(), y)
#             z = torch.where(active_mask.unsqueeze(1), z_new.detach(), y)

#             loss_per_token = crossntropy(f_out.view(-1, vocab_size), labels.view(-1))

# %%
import torch.nn.functional as F

def Q_LOSS(q_halt, f_out, y_true, pad_token=PAD_TOKEN):
    preds = f_out.argmax(dim=-1)                                               # (B, L)
    non_pad = (y_true != pad_token)                                            # (B, L)
    target = ((preds == y_true) | ~non_pad).all(dim=-1, keepdim=True).float()  # (B, 1): 1 iff every real token correct
    return F.binary_cross_entropy_with_logits(q_halt, target)

# %%
### claude generate this diagnostic script but i guided it what to do


from torch.utils.data import Subset


def diagnostic_per_sup_step(c=0.1, T=3, n_sup=16, num_epochs=100):
    model = TinyRModel(hidden_size, vocab_size, inp_seq_len = inp_seq_len, out_seq_len = out_seq_len).to(device)
    optimizer = torch.optim.Adam(model.parameters(), lr=1e-4)
    criterion_noreduce = nn.CrossEntropyLoss(reduction='none', ignore_index=PAD_TOKEN)
    criterion = nn.CrossEntropyLoss(ignore_index=PAD_TOKEN)

    diag_subset = Subset(train_set, range(max(10000, len(train_set))))
    diag_loader = DataLoader(diag_subset, batch_size=64, shuffle=True)

    model.train()

    for epoch in range(num_epochs):
        print(f'processing epoch {epoch} \n')
        for batch in diag_loader:
            input_ids = batch['input_ids'].to(device)
            labels = batch['labels'].to(device)
            batch_size_curr = input_ids.size(0)
            seq_len = labels.size(1)

            x = input_ids
            y = torch.zeros(batch_size_curr, hidden_size, device=device)
            z = torch.zeros(batch_size_curr, hidden_size, device=device)

            total_loss = torch.tensor(0.0, device=device)

            for i in range(n_sup):
                f_out, halt, y_new, z_new = model(x, y, z, T, n=6)
                y = y_new.detach()
                z = z_new.detach()

                loss = criterion(f_out.view(-1, vocab_size), labels.view(-1))

                # Add Q-loss with the SAME formula as masked run
                seq_len = labels.size(1)
                q_loss = Q_LOSS(halt, f_out.view(-1, seq_len, vocab_size), labels)

                total_loss += (loss + c * q_loss.squeeze())  # same coefficient as masked run

            total_loss /= n_sup

            optimizer.zero_grad()
            total_loss.backward()
            optimizer.step()

        # --- Detailed per-step evaluation every 10 epochs ---
        if epoch % 10 == 0:
            model.eval()
            with torch.no_grad():
                test_batch = next(iter(diag_loader))
                input_ids = test_batch['input_ids'].to(device)
                labels = test_batch['labels'].to(device)
                batch_size_curr = input_ids.size(0)
                seq_len = labels.size(1)

                x = input_ids
                y_state = torch.zeros(batch_size_curr, hidden_size, device=device)
                z_state = torch.zeros(batch_size_curr, hidden_size, device=device)

                print(f"Epoch {epoch:3d} | CE per supervision step (same batch):")

                prev_ce = None
                for i in range(n_sup):
                    f_out, halt, y_new, z_new = model(x, y_state, z_state, T, n=6)
                    y_state = y_new.detach()
                    z_state = z_new.detach()

                    print(f"sup_step_{i+1} | mean={halt.mean().item():.3f} "
                          f"std={halt.std().item():.3f} "
                          f"median={halt.median().item():.3f} "
                          f"%>0={(halt > 0).float().mean().item():.1%} "
                          f"first5={halt[:5].squeeze().tolist()}")

                    # Per-token CE (ignoring padding)
                    loss_per_token = criterion_noreduce(f_out.view(-1, vocab_size), labels.view(-1))
                    # Reshape to (Batch, Seq)
                    loss_grid = loss_per_token.view(batch_size_curr, seq_len)
                    non_pad = (labels != PAD_TOKEN)
                    # Per-sample CE on real tokens only
                    ce_per_sample = (loss_grid * non_pad.float()).sum(dim=1) / non_pad.float().sum(dim=1).clamp(min=1)
                    avg_ce = ce_per_sample.mean().item()

                    # Token accuracy EXCLUDING padding
                    preds = f_out.view(-1, seq_len, vocab_size).argmax(dim=-1)
                    correct = (preds == labels) & non_pad
                    token_acc = correct.sum().item() / non_pad.sum().item()

                    # Exact match: all NON-PAD positions correct
                    per_sample_correct = ((preds == labels) | ~non_pad).all(dim=-1).float()
                    exact = per_sample_correct.mean().item()

                    # CE change from previous step
                    delta = ""
                    if prev_ce is not None:
                        diff = prev_ce - avg_ce
                        delta = f"| Delta: {diff:+.4f} {'IMPROVED' if diff > 0.01 else 'FLAT' if diff > -0.01 else 'WORSE'}"
                    prev_ce = avg_ce

                    # Prediction diversity
                    pred_strings = [tuple(p.cpu().tolist()) for p in preds]
                    unique_preds = len(set(pred_strings))

                    print(f"  Sup {i:2d} | CE: {avg_ce:.4f} | TokAcc: {token_acc:.4f} | Exact: {exact:.4f} | Unique: {unique_preds}/{batch_size_curr} {delta}")

                print()

                # Show sample predictions at LAST sup step (non-pad only)
                if epoch % 50 == 0:
                    print(f"--- Sample Predictions at Epoch {epoch}, Last Sup Step ---")
                    for j in range(min(10, batch_size_curr)):
                        mask = non_pad[j]
                        pred_real = preds[j][mask].cpu().tolist()
                        true_real = labels[j][mask].cpu().tolist()
                        inp = input_ids[j].cpu().tolist()
                        # Decode input nicely
                        inp_str = ''.join([str(t) if t < 10 else '+' if t == 10 else '' for t in inp])
                        match = "MATCH" if pred_real == true_real else "WRONG"
                        print(f"  {inp_str} | Pred: {pred_real} True: {true_real} {match}")
                    print()

            model.train()

    # --- Final comprehensive breakdown ---
    print("=" * 70)
    print("FINAL BREAKDOWN: All Supervision Steps (Last Epoch)")
    print("=" * 70)

    model.eval()
    with torch.no_grad():
        test_batch = next(iter(diag_loader))
        input_ids = test_batch['input_ids'].to(device)
        labels = test_batch['labels'].to(device)
        batch_size_curr = input_ids.size(0)
        seq_len = labels.size(1)

        x = input_ids
        y_state = torch.zeros(batch_size_curr, hidden_size, device=device)
        z_state = torch.zeros(batch_size_curr, hidden_size, device=device)

        non_pad = (labels != PAD_TOKEN)

        for i in range(n_sup):
            f_out, halt, y_new, z_new = model(x, y_state, z_state, T, n=6)
            y_state = y_new.detach()
            z_state = z_new.detach()

            loss_per_token = criterion_noreduce(f_out.view(-1, vocab_size), labels.view(-1))
            loss_grid = loss_per_token.view(batch_size_curr, seq_len)
            ce_per_sample = (loss_grid * non_pad.float()).sum(dim=1) / non_pad.float().sum(dim=1).clamp(min=1)
            avg_ce = ce_per_sample.mean().item()

            preds = f_out.view(-1, seq_len, vocab_size).argmax(dim=-1)
            correct = (preds == labels) & non_pad
            token_acc = correct.sum().item() / non_pad.sum().item()

            per_sample_correct = ((preds == labels) | ~non_pad).all(dim=-1).float()
            exact = per_sample_correct.mean().item()

            pred_strings = [tuple(p.cpu().tolist()) for p in preds]
            unique_preds = len(set(pred_strings))

            q_mean = halt.mean().item()

            print(f"  Sup {i:2d} | CE: {avg_ce:.4f} | TokAcc: {token_acc:.4f} | Exact: {exact:.4f} | Unique: {unique_preds}/{batch_size_curr} | Q: {q_mean:.4f}")

        # Final sample predictions
        print(f"\n--- Final Sample Predictions ---")
        for j in range(min(10, batch_size_curr)):
            mask = non_pad[j]
            pred_real = preds[j][mask].cpu().tolist()
            true_real = labels[j][mask].cpu().tolist()
            inp = input_ids[j].cpu().tolist()
            inp_str = ''.join([str(t) if t < 10 else '+' if t == 10 else '' for t in inp])
            match = "MATCH" if pred_real == true_real else "WRONG"
            print(f"  {inp_str} | Pred: {pred_real} True: {true_real} {match}")

    return model

model = diagnostic_per_sup_step(c=0.1, T=3, n_sup=16, num_epochs=100)
# Out:
# processing epoch 0
#
# Epoch   0 | CE per supervision step (same batch):
# sup_step_1 | mean=-8.768 std=2.081 median=-8.999 %>0=0.0% first5=[-5.808785915374756, -5.921865463256836, -10.072855949401855, -8.99056625366211, -9.125009536743164]
#   Sup  0 | CE: 1.8375 | TokAcc: 0.3048 | Exact: 0.0000 | Unique: 36/64
# sup_step_2 | mean=-8.530 std=2.087 median=-8.381 %>0=0.0% first5=[-6.097226142883301, -6.283647537231445, -10.972183227539062, -10.234622955322266, -6.362849712371826]
#   Sup  1 | CE: 1.6927 | TokAcc: 0.3493 | Exact: 0.0156 | Unique: 32/64 | Delta: +0.1448 IMPROVED
# sup_step_3 | mean=-8.402 std=2.194 median=-8.408 %>0=0.0% first5=[-5.967779159545898, -6.254700660705566, -11.162483215332031, -10.269218444824219, -5.775259017944336]
#   Sup  2 | CE: 1.6690 | TokAcc: 0.3664 | Exact: 0.0156 | Unique: 33/64 | Delta: +0.0237 IMPROVED
# sup_step_4 | mean=-8.399 std=2.233 median=-8.533 %>0=0.0% first5=[-5.869362831115723, -6.200441360473633, -11.295207977294922, -10.246099472045898, -5.71353816986084]
#   Sup  3 | CE: 1.6663 | TokAcc: 0.3664 | Exact: 0.0156 | Unique: 33/64 | Delta: +0.0027 FLAT
# sup_step_5 | mean=-8.393 std=2.228 median=-8.501 %>0=0.0% first5=[-5.837699890136719, -6.175946235656738, -11.29669189453125, -10.24374771118164, -5.792747497558594]
#   Sup  4 | CE: 1.6665 | TokAcc: 0.3630 | Exact: 0.0156 | Unique: 32/64 | Delta: -0.0002 FLAT
# sup_step_6 | mean=-8.390 std=2.231 median=-8.491 %>0=0.0% first5=[-5.833377838134766, -6.165188789367676, -11.2947998046875, -10.245626449584961, -5.799384117126465]
#   Sup  5 | CE: 1.6667 | TokAcc: 0.3596 | Exact: 0.0156 | Unique: 32/64 | Delta: -0.0001 FLAT
# sup_step_7 | mean=-8.388 std=2.233 median=-8.485 %>0=0.0% first5=[-5.833747863769531, -6.160691738128662, -11.295098304748535, -10.24636459350586, -5.783853530883789]
#   Sup  6 | CE: 1.6669 | TokAcc: 0.3630 | Exact: 0.0156 | Unique: 33/64 | Delta: -0.0002 FLAT
# sup_step_8 | mean=-8.388 std=2.234 median=-8.482 %>0=0.0% first5=[-5.833967208862305, -6.15882682800293, -11.295051574707031, -10.246430397033691, -5.784160137176514]
#   Sup  7 | CE: 1.6670 | TokAcc: 0.3630 | Exact: 0.0156 | Unique: 33/64 | Delta: -0.0001 FLAT
# sup_step_9 | mean=-8.388 std=2.234 median=-8.481 %>0=0.0% first5=[-5.833987236022949, -6.158029556274414, -11.295026779174805, -10.246399879455566, -5.786798000335693]
#   Sup  8 | CE: 1.6671 | TokAcc: 0.3630 | Exact: 0.0156 | Unique: 33/64 | Delta: -0.0001 FLAT
# sup_step_10 | mean=-8.388 std=2.235 median=-8.480 %>0=0.0% first5=[-5.833980560302734, -6.157630920410156, -11.295028686523438, -10.246390342712402, -5.786500930786133]
#   Sup  9 | CE: 1.6671 | TokAcc: 0.3630 | Exact: 0.0156 | Unique: 33/64 | Delta: -0.0000 FLAT
# sup_step_11 | mean=-8.388 std=2.235 median=-8.480 %>0=0.0% first5=[-5.83397912979126, -6.157425403594971, -11.295026779174805, -10.246389389038086, -5.7860236167907715]
#   Sup 10 | CE: 1.6671 | TokAcc: 0.3630 | Exact: 0.0156 | Unique: 33/64 | Delta: -0.0000 FLAT
# sup_step_12 | mean=-8.388 std=2.235 median=-8.480 %>0=0.0% first5=[-5.833978652954102, -6.157317161560059, -11.295026779174805, -10.246390342712402, -5.786136627197266]
#   Sup 11 | CE: 1.6672 | TokAcc: 0.3630 | Exact: 0.0156 | Unique: 33/64 | Delta: -0.0000 FLAT
# sup_step_13 | mean=-8.388 std=2.235 median=-8.480 %>0=0.0% first5=[-5.833978652954102, -6.157260894775391, -11.295026779174805, -10.246390342712402, -5.7862114906311035]
#   Sup 12 | CE: 1.6672 | TokAcc: 0.3630 | Exact: 0.0156 | Unique: 33/64 | Delta: -0.0000 FLAT
# sup_step_14 | mean=-8.388 std=2.235 median=-8.480 %>0=0.0% first5=[-5.833978652954102, -6.157232284545898, -11.295027732849121, -10.246390342712402, -5.786181449890137]
#   Sup 13 | CE: 1.6672 | TokAcc: 0.3630 | Exact: 0.0156 | Unique: 33/64 | Delta: -0.0000 FLAT
# sup_step_15 | mean=-8.388 std=2.235 median=-8.480 %>0=0.0% first5=[-5.833978652954102, -6.157215595245361, -11.295026779174805, -10.246389389038086, -5.786170959472656]
#   Sup 14 | CE: 1.6672 | TokAcc: 0.3630 | Exact: 0.0156 | Unique: 33/64 | Delta: -0.0000 FLAT
# sup_step_16 | mean=-8.388 std=2.235 median=-8.480 %>0=0.0% first5=[-5.833978652954102, -6.157207489013672, -11.295028686523438, -10.246389389038086, -5.786177635192871]
#   Sup 15 | CE: 1.6672 | TokAcc: 0.3630 | Exact: 0.0156 | Unique: 33/64 | Delta: -0.0000 FLAT
#
# --- Sample Predictions at Epoch 0, Last Sup Step ---
#   3292+1522 | Pred: [4, 9, 8, 1] True: [4, 8, 1, 4] WRONG
#   1560+4089 | Pred: [5, 9, 8, 1] True: [5, 6, 4, 9] WRONG
#   8037+3260 | Pred: [1, 1, 1, 0, 3] True: [1, 1, 2, 9, 7] WRONG
#   5957+3320 | Pred: [9, 0, 0, 1] True: [9, 2, 7, 7] WRONG
#   9474+7686 | Pred: [1, 6, 5, 2, 6] True: [1, 7, 1, 6, 0] WRONG
#   3269+4398 | Pred: [7, 2, 9, 1] True: [7, 6, 6, 7] WRONG
#   5081+8623 | Pred: [1, 3, 1, 0, 0] True: [1, 3, 7, 0, 4] WRONG
#   7038+6778 | Pred: [1, 3, 1, 0, 3] True: [1, 3, 8, 1, 6] WRONG
#   2908+1553 | Pred: [4, 9, 8, 1] True: [4, 4, 6, 1] WRONG
#   7276+3676 | Pred: [1, 0, 1, 1, 3] True: [1, 0, 9, 5, 2] WRONG
#
# processing epoch 1
#
# processing epoch 2
#
# processing epoch 3
#
# processing epoch 4
#
# processing epoch 5
#
# processing epoch 6
#
# processing epoch 7
#
# processing epoch 8
#
# processing epoch 9
#
# processing epoch 10
#
# Epoch  10 | CE per supervision step (same batch):
# sup_step_1 | mean=-4.397 std=0.629 median=-4.312 %>0=0.0% first5=[-5.279340744018555, -4.1919145584106445, -7.004194736480713, -4.022883415222168, -4.230530738830566]
#   Sup  0 | CE: 1.1738 | TokAcc: 0.5316 | Exact: 0.0000 | Unique: 61/64
# sup_step_2 | mean=-4.556 std=0.649 median=-4.478 %>0=0.0% first5=[-5.127503395080566, -4.597545623779297, -5.993420124053955, -3.7911179065704346, -5.075943470001221]
#   Sup  1 | CE: 1.0684 | TokAcc: 0.5748 | Exact: 0.0000 | Unique: 60/64 | Delta: +0.1054 IMPROVED
# sup_step_3 | mean=-4.590 std=0.644 median=-4.506 %>0=0.0% first5=[-5.11542272567749, -4.616558074951172, -6.538364887237549, -3.925618886947632, -5.099002361297607]
#   Sup  2 | CE: 1.0573 | TokAcc: 0.5947 | Exact: 0.0000 | Unique: 59/64 | Delta: +0.0111 IMPROVED
# sup_step_4 | mean=-4.587 std=0.649 median=-4.508 %>0=0.0% first5=[-5.128911018371582, -4.649918079376221, -6.497517108917236, -3.9358811378479004, -5.064788818359375]
#   Sup  3 | CE: 1.0539 | TokAcc: 0.5914 | Exact: 0.0000 | Unique: 57/64 | Delta: +0.0033 FLAT
# sup_step_5 | mean=-4.593 std=0.647 median=-4.506 %>0=0.0% first5=[-5.126554489135742, -4.650061130523682, -6.410220146179199, -3.980663776397705, -5.059170246124268]
#   Sup  4 | CE: 1.0570 | TokAcc: 0.5947 | Exact: 0.0000 | Unique: 58/64 | Delta: -0.0031 FLAT
# sup_step_6 | mean=-4.595 std=0.644 median=-4.505 %>0=0.0% first5=[-5.126236438751221, -4.649720668792725, -6.40639066696167, -3.9852871894836426, -5.060673713684082]
#   Sup  5 | CE: 1.0548 | TokAcc: 0.5914 | Exact: 0.0000 | Unique: 58/64 | Delta: +0.0022 FLAT
# sup_step_7 | mean=-4.598 std=0.646 median=-4.505 %>0=0.0% first5=[-5.126518249511719, -4.649582862854004, -6.425880432128906, -4.007188320159912, -5.061668395996094]
#   Sup  6 | CE: 1.0559 | TokAcc: 0.5914 | Exact: 0.0000 | Unique: 58/64 | Delta: -0.0011 FLAT
# sup_step_8 | mean=-4.596 std=0.648 median=-4.505 %>0=0.0% first5=[-5.126563549041748, -4.649561405181885, -6.421850204467773, -4.010053634643555, -5.061817169189453]
#   Sup  7 | CE: 1.0548 | TokAcc: 0.5880 | Exact: 0.0000 | Unique: 57/64 | Delta: +0.0011 FLAT
# sup_step_9 | mean=-4.596 std=0.648 median=-4.505 %>0=0.0% first5=[-5.126541614532471, -4.649567127227783, -6.4191694259643555, -4.017697811126709, -5.061761856079102]
#   Sup  8 | CE: 1.0551 | TokAcc: 0.5880 | Exact: 0.0000 | Unique: 57/64 | Delta: -0.0002 FLAT
# sup_step_10 | mean=-4.595 std=0.650 median=-4.505 %>0=0.0% first5=[-5.126539707183838, -4.649569034576416, -6.4198899269104, -4.01950216293335, -5.061730861663818]
#   Sup  9 | CE: 1.0553 | TokAcc: 0.5914 | Exact: 0.0000 | Unique: 58/64 | Delta: -0.0003 FLAT
# sup_step_11 | mean=-4.597 std=0.648 median=-4.505 %>0=0.0% first5=[-5.126540660858154, -4.649569988250732, -6.420339107513428, -4.0224151611328125, -5.061726093292236]
#   Sup 10 | CE: 1.0551 | TokAcc: 0.5914 | Exact: 0.0000 | Unique: 58/64 | Delta: +0.0002 FLAT
# sup_step_12 | mean=-4.598 std=0.648 median=-4.505 %>0=0.0% first5=[-5.126540660858154, -4.649569988250732, -6.42018461227417, -4.023656368255615, -5.061728000640869]
#   Sup 11 | CE: 1.0548 | TokAcc: 0.5914 | Exact: 0.0000 | Unique: 58/64 | Delta: +0.0002 FLAT
# sup_step_13 | mean=-4.599 std=0.648 median=-4.505 %>0=0.0% first5=[-5.1265411376953125, -4.649569988250732, -6.420125961303711, -4.024823188781738, -5.06173038482666]
#   Sup 12 | CE: 1.0543 | TokAcc: 0.5914 | Exact: 0.0000 | Unique: 58/64 | Delta: +0.0006 FLAT
# sup_step_14 | mean=-4.597 std=0.650 median=-4.505 %>0=0.0% first5=[-5.126540660858154, -4.649569988250732, -6.4201555252075195, -4.025553226470947, -5.061729431152344]
#   Sup 13 | CE: 1.0546 | TokAcc: 0.5914 | Exact: 0.0000 | Unique: 58/64 | Delta: -0.0003 FLAT
# sup_step_15 | mean=-4.596 std=0.650 median=-4.505 %>0=0.0% first5=[-5.126540660858154, -4.649569988250732, -6.420162200927734, -4.026103496551514, -5.0617289543151855]
#   Sup 14 | CE: 1.0547 | TokAcc: 0.5914 | Exact: 0.0000 | Unique: 58/64 | Delta: -0.0001 FLAT
# sup_step_16 | mean=-4.597 std=0.650 median=-4.505 %>0=0.0% first5=[-5.126540660858154, -4.649569511413574, -6.420156955718994, -4.026514053344727, -5.0617289543151855]
#   Sup 15 | CE: 1.0551 | TokAcc: 0.5914 | Exact: 0.0000 | Unique: 58/64 | Delta: -0.0004 FLAT
#
# processing epoch 11
#
# processing epoch 12
#
# processing epoch 13
#
# processing epoch 14
#
# processing epoch 15
#
# processing epoch 16
#
# processing epoch 17
#
# processing epoch 18
#
# processing epoch 19
#
# processing epoch 20
#
# Epoch  20 | CE per supervision step (same batch):
# sup_step_1 | mean=-2.762 std=0.569 median=-2.764 %>0=0.0% first5=[-2.841709852218628, -2.6836965084075928, -3.891824960708618, -2.856184244155884, -2.3616926670074463]
#   Sup  0 | CE: 0.9544 | TokAcc: 0.6040 | Exact: 0.0312 | Unique: 64/64
# sup_step_2 | mean=-2.878 std=0.534 median=-2.873 %>0=0.0% first5=[-2.7481868267059326, -3.147390604019165, -2.5599441528320312, -2.4532887935638428, -2.0597620010375977]
#   Sup  1 | CE: 0.7660 | TokAcc: 0.6980 | Exact: 0.0781 | Unique: 63/64 | Delta: +0.1884 IMPROVED
# sup_step_3 | mean=-2.864 std=0.535 median=-2.859 %>0=0.0% first5=[-2.662449598312378, -3.066802740097046, -3.160336971282959, -2.4869439601898193, -2.1526966094970703]
#   Sup  2 | CE: 0.7778 | TokAcc: 0.7013 | Exact: 0.0938 | Unique: 63/64 | Delta: -0.0117 WORSE
# sup_step_4 | mean=-2.855 std=0.542 median=-2.847 %>0=0.0% first5=[-2.6963608264923096, -3.0836939811706543, -2.8567984104156494, -2.447044610977173, -2.191134214401245]
#   Sup  3 | CE: 0.7501 | TokAcc: 0.7013 | Exact: 0.0625 | Unique: 62/64 | Delta: +0.0276 IMPROVED
# sup_step_5 | mean=-2.854 std=0.532 median=-2.855 %>0=0.0% first5=[-2.7246272563934326, -3.0771408081054688, -2.959660053253174, -2.459432363510132, -2.1805570125579834]
#   Sup  4 | CE: 0.7483 | TokAcc: 0.7114 | Exact: 0.0781 | Unique: 62/64 | Delta: +0.0018 FLAT
# sup_step_6 | mean=-2.854 std=0.531 median=-2.856 %>0=0.0% first5=[-2.7157907485961914, -3.0797197818756104, -2.919485569000244, -2.4366745948791504, -2.1770501136779785]
#   Sup  5 | CE: 0.7646 | TokAcc: 0.6913 | Exact: 0.0781 | Unique: 63/64 | Delta: -0.0162 WORSE
# sup_step_7 | mean=-2.859 std=0.543 median=-2.855 %>0=0.0% first5=[-2.7026331424713135, -3.0794050693511963, -2.9375460147857666, -2.4152793884277344, -2.1780056953430176]
#   Sup  6 | CE: 0.7518 | TokAcc: 0.7047 | Exact: 0.0781 | Unique: 62/64 | Delta: +0.0127 IMPROVED
# sup_step_8 | mean=-2.856 std=0.539 median=-2.855 %>0=0.0% first5=[-2.7076916694641113, -3.0788774490356445, -2.9294991493225098, -2.4071764945983887, -2.1783483028411865]
#   Sup  7 | CE: 0.7526 | TokAcc: 0.7047 | Exact: 0.0781 | Unique: 62/64 | Delta: -0.0008 FLAT
# sup_step_9 | mean=-2.856 std=0.535 median=-2.855 %>0=0.0% first5=[-2.711972236633301, -3.0792667865753174, -2.932777166366577, -2.400954008102417, -2.17820405960083]
#   Sup  8 | CE: 0.7638 | TokAcc: 0.6980 | Exact: 0.0625 | Unique: 63/64 | Delta: -0.0111 WORSE
# sup_step_10 | mean=-2.855 std=0.536 median=-2.855 %>0=0.0% first5=[-2.710343360900879, -3.0791008472442627, -2.9313971996307373, -2.3984665870666504, -2.178178071975708]
#   Sup  9 | CE: 0.7562 | TokAcc: 0.7013 | Exact: 0.0781 | Unique: 62/64 | Delta: +0.0076 FLAT
# sup_step_11 | mean=-2.855 std=0.536 median=-2.855 %>0=0.0% first5=[-2.7084641456604004, -3.0791454315185547, -2.931997537612915, -2.4195070266723633, -2.178194761276245]
#   Sup 10 | CE: 0.7514 | TokAcc: 0.7081 | Exact: 0.0781 | Unique: 63/64 | Delta: +0.0048 FLAT
# sup_step_12 | mean=-2.854 std=0.534 median=-2.855 %>0=0.0% first5=[-2.709143877029419, -3.079143524169922, -2.9317522048950195, -2.452507734298706, -2.1781957149505615]
#   Sup 11 | CE: 0.7582 | TokAcc: 0.6980 | Exact: 0.0781 | Unique: 62/64 | Delta: -0.0068 FLAT
# sup_step_13 | mean=-2.863 std=0.543 median=-2.855 %>0=0.0% first5=[-2.709876537322998, -3.079137086868286, -2.9318478107452393, -2.474473714828491, -2.178194761276245]
#   Sup 12 | CE: 0.7616 | TokAcc: 0.6980 | Exact: 0.0625 | Unique: 63/64 | Delta: -0.0035 FLAT
# sup_step_14 | mean=-2.856 std=0.535 median=-2.855 %>0=0.0% first5=[-2.709601402282715, -3.079141855239868, -2.931809663772583, -2.476447820663452, -2.178194522857666]
#   Sup 13 | CE: 0.7523 | TokAcc: 0.7013 | Exact: 0.0625 | Unique: 62/64 | Delta: +0.0093 FLAT
# sup_step_15 | mean=-2.852 std=0.530 median=-2.855 %>0=0.0% first5=[-2.7093074321746826, -3.0791399478912354, -2.9318253993988037, -2.4632132053375244, -2.1781933307647705]
#   Sup 14 | CE: 0.7562 | TokAcc: 0.6980 | Exact: 0.0781 | Unique: 63/64 | Delta: -0.0039 FLAT
# sup_step_16 | mean=-2.858 std=0.537 median=-2.855 %>0=0.0% first5=[-2.7094216346740723, -3.0791401863098145, -2.931819200515747, -2.4421396255493164, -2.1781952381134033]
#   Sup 15 | CE: 0.7589 | TokAcc: 0.7013 | Exact: 0.0781 | Unique: 63/64 | Delta: -0.0026 FLAT
#
# processing epoch 21
#
# processing epoch 22
#
# processing epoch 23
#
# processing epoch 24
#
# processing epoch 25
#
# processing epoch 26
#
# processing epoch 27
#
# processing epoch 28
#
# processing epoch 29
#
# processing epoch 30
#
# Epoch  30 | CE per supervision step (same batch):
# sup_step_1 | mean=-2.437 std=0.423 median=-2.514 %>0=0.0% first5=[-2.460631847381592, -2.654332160949707, -2.7769055366516113, -2.3301374912261963, -2.7032864093780518]
#   Sup  0 | CE: 0.7515 | TokAcc: 0.7235 | Exact: 0.0938 | Unique: 64/64
# sup_step_2 | mean=-2.362 std=0.371 median=-2.387 %>0=0.0% first5=[-2.4264416694641113, -2.451960325241089, -2.126840829849243, -2.4929094314575195, -2.6706039905548096]
#   Sup  1 | CE: 0.6641 | TokAcc: 0.7509 | Exact: 0.1094 | Unique: 64/64 | Delta: +0.0873 IMPROVED
# sup_step_3 | mean=-2.357 std=0.351 median=-2.388 %>0=0.0% first5=[-2.424372673034668, -2.5145463943481445, -2.409944534301758, -2.4472782611846924, -2.4646682739257812]
#   Sup  2 | CE: 0.6948 | TokAcc: 0.7406 | Exact: 0.1094 | Unique: 64/64 | Delta: -0.0306 WORSE
# sup_step_4 | mean=-2.356 std=0.351 median=-2.397 %>0=0.0% first5=[-2.410681962966919, -2.509930372238159, -2.405059337615967, -2.422187566757202, -2.4941749572753906]
#   Sup  3 | CE: 0.6880 | TokAcc: 0.7474 | Exact: 0.1250 | Unique: 64/64 | Delta: +0.0068 FLAT
# sup_step_5 | mean=-2.353 std=0.346 median=-2.393 %>0=0.0% first5=[-2.4268088340759277, -2.5125465393066406, -2.301886558532715, -2.423398971557617, -2.5010440349578857]
#   Sup  4 | CE: 0.6891 | TokAcc: 0.7509 | Exact: 0.1250 | Unique: 64/64 | Delta: -0.0012 FLAT
# sup_step_6 | mean=-2.356 std=0.346 median=-2.394 %>0=0.0% first5=[-2.419760227203369, -2.512657880783081, -2.3707640171051025, -2.427455425262451, -2.498183250427246]
#   Sup  5 | CE: 0.6892 | TokAcc: 0.7474 | Exact: 0.1250 | Unique: 64/64 | Delta: -0.0001 FLAT
# sup_step_7 | mean=-2.357 std=0.347 median=-2.396 %>0=0.0% first5=[-2.4217419624328613, -2.512427806854248, -2.3070738315582275, -2.4284307956695557, -2.4985008239746094]
#   Sup  6 | CE: 0.6892 | TokAcc: 0.7543 | Exact: 0.1406 | Unique: 64/64 | Delta: +0.0001 FLAT
# sup_step_8 | mean=-2.354 std=0.346 median=-2.395 %>0=0.0% first5=[-2.4215497970581055, -2.5124683380126953, -2.375926971435547, -2.4272847175598145, -2.4985313415527344]
#   Sup  7 | CE: 0.6896 | TokAcc: 0.7509 | Exact: 0.1250 | Unique: 64/64 | Delta: -0.0004 FLAT
# sup_step_9 | mean=-2.355 std=0.350 median=-2.394 %>0=0.0% first5=[-2.421333074569702, -2.5124893188476562, -2.32716703414917, -2.4267420768737793, -2.498504161834717]
#   Sup  8 | CE: 0.6887 | TokAcc: 0.7474 | Exact: 0.1250 | Unique: 64/64 | Delta: +0.0009 FLAT
# sup_step_10 | mean=-2.356 std=0.351 median=-2.395 %>0=0.0% first5=[-2.42160701751709, -2.5124878883361816, -2.3629350662231445, -2.4271538257598877, -2.498516321182251]
#   Sup  9 | CE: 0.6909 | TokAcc: 0.7543 | Exact: 0.1406 | Unique: 64/64 | Delta: -0.0022 FLAT
# sup_step_11 | mean=-2.352 std=0.351 median=-2.395 %>0=0.0% first5=[-2.4214658737182617, -2.5124855041503906, -2.3420145511627197, -2.4275283813476562, -2.498513698577881]
#   Sup 10 | CE: 0.6888 | TokAcc: 0.7509 | Exact: 0.1250 | Unique: 64/64 | Delta: +0.0021 FLAT
# sup_step_12 | mean=-2.354 std=0.353 median=-2.395 %>0=0.0% first5=[-2.421520233154297, -2.5124850273132324, -2.3398823738098145, -2.427337408065796, -2.498514175415039]
#   Sup 11 | CE: 0.6913 | TokAcc: 0.7509 | Exact: 0.1250 | Unique: 64/64 | Delta: -0.0025 FLAT
# sup_step_13 | mean=-2.355 std=0.350 median=-2.395 %>0=0.0% first5=[-2.4215078353881836, -2.512486457824707, -2.3552019596099854, -2.4270753860473633, -2.498513698577881]
#   Sup 12 | CE: 0.6888 | TokAcc: 0.7543 | Exact: 0.1406 | Unique: 64/64 | Delta: +0.0026 FLAT
# sup_step_14 | mean=-2.354 std=0.348 median=-2.395 %>0=0.0% first5=[-2.421505928039551, -2.5124852657318115, -2.3257877826690674, -2.427157163619995, -2.498513698577881]
#   Sup 13 | CE: 0.6902 | TokAcc: 0.7509 | Exact: 0.1250 | Unique: 64/64 | Delta: -0.0015 FLAT
# sup_step_15 | mean=-2.357 std=0.348 median=-2.395 %>0=0.0% first5=[-2.4215102195739746, -2.512486696243286, -2.3602523803710938, -2.4273416996002197, -2.49851393699646]
#   Sup 14 | CE: 0.6898 | TokAcc: 0.7509 | Exact: 0.1250 | Unique: 64/64 | Delta: +0.0004 FLAT
# sup_step_16 | mean=-2.357 std=0.344 median=-2.395 %>0=0.0% first5=[-2.421506643295288, -2.5124855041503906, -2.3285677433013916, -2.4273152351379395, -2.4985132217407227]
#   Sup 15 | CE: 0.6889 | TokAcc: 0.7509 | Exact: 0.1250 | Unique: 64/64 | Delta: +0.0009 FLAT
#
# processing epoch 31
#
# processing epoch 32
#
# processing epoch 33
#
# processing epoch 34
#
# processing epoch 35
#
# processing epoch 36
#
# processing epoch 37
#
# processing epoch 38
#
# processing epoch 39
#
# processing epoch 40
#
# Epoch  40 | CE per supervision step (same batch):
# sup_step_1 | mean=-2.170 std=0.319 median=-2.203 %>0=0.0% first5=[-2.0211520195007324, -2.3105709552764893, -2.7047629356384277, -2.0158681869506836, -2.0198140144348145]
#   Sup  0 | CE: 0.6515 | TokAcc: 0.7595 | Exact: 0.1250 | Unique: 63/64
# sup_step_2 | mean=-2.165 std=0.292 median=-2.216 %>0=0.0% first5=[-2.0101795196533203, -2.288733959197998, -2.7829689979553223, -2.2765979766845703, -1.8620691299438477]
#   Sup  1 | CE: 0.5722 | TokAcc: 0.7835 | Exact: 0.1719 | Unique: 63/64 | Delta: +0.0793 IMPROVED
# sup_step_3 | mean=-2.140 std=0.301 median=-2.158 %>0=0.0% first5=[-2.027672529220581, -2.286344528198242, -2.749865770339966, -2.2408316135406494, -1.8330148458480835]
#   Sup  2 | CE: 0.5642 | TokAcc: 0.7835 | Exact: 0.1719 | Unique: 63/64 | Delta: +0.0080 FLAT
# sup_step_4 | mean=-2.144 std=0.292 median=-2.179 %>0=0.0% first5=[-2.020939826965332, -2.2851948738098145, -2.7107369899749756, -2.2424066066741943, -1.8464330434799194]
#   Sup  3 | CE: 0.5691 | TokAcc: 0.7869 | Exact: 0.2031 | Unique: 63/64 | Delta: -0.0049 FLAT
# sup_step_5 | mean=-2.143 std=0.293 median=-2.184 %>0=0.0% first5=[-2.019207715988159, -2.285017728805542, -2.719137191772461, -2.2426204681396484, -1.8383386135101318]
#   Sup  4 | CE: 0.5645 | TokAcc: 0.7904 | Exact: 0.2031 | Unique: 63/64 | Delta: +0.0045 FLAT
# sup_step_6 | mean=-2.145 std=0.291 median=-2.169 %>0=0.0% first5=[-2.020278215408325, -2.285057306289673, -2.7207589149475098, -2.2425312995910645, -1.8409297466278076]
#   Sup  5 | CE: 0.5640 | TokAcc: 0.7869 | Exact: 0.2031 | Unique: 63/64 | Delta: +0.0005 FLAT
# sup_step_7 | mean=-2.147 std=0.291 median=-2.186 %>0=0.0% first5=[-2.019771099090576, -2.2850539684295654, -2.7210166454315186, -2.242549180984497, -1.8401914834976196]
#   Sup  6 | CE: 0.5643 | TokAcc: 0.7835 | Exact: 0.1875 | Unique: 63/64 | Delta: -0.0003 FLAT
# sup_step_8 | mean=-2.141 std=0.293 median=-2.167 %>0=0.0% first5=[-2.0200514793395996, -2.2850594520568848, -2.720787525177002, -2.2425429821014404, -1.8403791189193726]
#   Sup  7 | CE: 0.5646 | TokAcc: 0.7835 | Exact: 0.1875 | Unique: 63/64 | Delta: -0.0003 FLAT
# sup_step_9 | mean=-2.148 std=0.292 median=-2.186 %>0=0.0% first5=[-2.0199451446533203, -2.2850615978240967, -2.7206010818481445, -2.2425456047058105, -1.840349793434143]
#   Sup  8 | CE: 0.5651 | TokAcc: 0.7835 | Exact: 0.1875 | Unique: 63/64 | Delta: -0.0005 FLAT
# sup_step_10 | mean=-2.141 std=0.294 median=-2.167 %>0=0.0% first5=[-2.019993782043457, -2.2850615978240967, -2.720728635787964, -2.2425456047058105, -1.840344786643982]
#   Sup  9 | CE: 0.5644 | TokAcc: 0.7869 | Exact: 0.2031 | Unique: 63/64 | Delta: +0.0007 FLAT
# sup_step_11 | mean=-2.146 std=0.291 median=-2.167 %>0=0.0% first5=[-2.019974708557129, -2.285062551498413, -2.720693349838257, -2.242544651031494, -1.8403513431549072]
#   Sup 10 | CE: 0.5651 | TokAcc: 0.7835 | Exact: 0.1875 | Unique: 63/64 | Delta: -0.0007 FLAT
# sup_step_12 | mean=-2.143 std=0.292 median=-2.167 %>0=0.0% first5=[-2.0199813842773438, -2.285061836242676, -2.7207047939300537, -2.242544651031494, -1.8403468132019043]
#   Sup 11 | CE: 0.5639 | TokAcc: 0.7835 | Exact: 0.1875 | Unique: 63/64 | Delta: +0.0012 FLAT
# sup_step_13 | mean=-2.145 std=0.291 median=-2.167 %>0=0.0% first5=[-2.0199780464172363, -2.285061836242676, -2.7207014560699463, -2.242544651031494, -1.8403494358062744]
#   Sup 12 | CE: 0.5649 | TokAcc: 0.7835 | Exact: 0.1875 | Unique: 63/64 | Delta: -0.0010 FLAT
# sup_step_14 | mean=-2.147 std=0.292 median=-2.186 %>0=0.0% first5=[-2.019979953765869, -2.285062313079834, -2.720700979232788, -2.2425448894500732, -1.8403483629226685]
#   Sup 13 | CE: 0.5643 | TokAcc: 0.7835 | Exact: 0.1875 | Unique: 63/64 | Delta: +0.0005 FLAT
# sup_step_15 | mean=-2.141 std=0.294 median=-2.167 %>0=0.0% first5=[-2.0199782848358154, -2.285061836242676, -2.7207024097442627, -2.2425453662872314, -1.8403489589691162]
#   Sup 14 | CE: 0.5645 | TokAcc: 0.7835 | Exact: 0.1875 | Unique: 63/64 | Delta: -0.0002 FLAT
# sup_step_16 | mean=-2.148 std=0.292 median=-2.186 %>0=0.0% first5=[-2.0199787616729736, -2.2850615978240967, -2.720700740814209, -2.2425448894500732, -1.8403489589691162]
#   Sup 15 | CE: 0.5651 | TokAcc: 0.7835 | Exact: 0.1875 | Unique: 63/64 | Delta: -0.0006 FLAT
#
# processing epoch 41
#
# processing epoch 42
#
# processing epoch 43
#
# processing epoch 44
#
# processing epoch 45
#
# processing epoch 46
#
# processing epoch 47
#
# processing epoch 48
#
# processing epoch 49
#
# processing epoch 50
#
# Epoch  50 | CE per supervision step (same batch):
# sup_step_1 | mean=0.683 std=0.597 median=0.718 %>0=85.9% first5=[0.42970722913742065, 0.5483404397964478, 0.34775692224502563, 1.077987551689148, -0.594118595123291]
#   Sup  0 | CE: 0.5201 | TokAcc: 0.8215 | Exact: 0.3750 | Unique: 63/64
# sup_step_2 | mean=0.709 std=0.612 median=0.716 %>0=90.6% first5=[0.8317669034004211, 0.7137980461120605, 0.5854800343513489, 1.5068339109420776, -0.5773739814758301]
#   Sup  1 | CE: 0.2839 | TokAcc: 0.8923 | Exact: 0.5781 | Unique: 64/64 | Delta: +0.2362 IMPROVED
# sup_step_3 | mean=0.736 std=0.576 median=0.758 %>0=92.2% first5=[0.8538235425949097, 0.757876992225647, 0.5660488605499268, 1.4113584756851196, -0.5534236431121826]
#   Sup  2 | CE: 0.2773 | TokAcc: 0.8923 | Exact: 0.6250 | Unique: 64/64 | Delta: +0.0066 FLAT
# sup_step_4 | mean=0.741 std=0.576 median=0.772 %>0=92.2% first5=[0.8370358943939209, 0.7317890524864197, 0.5622934699058533, 1.3727694749832153, -0.5533547401428223]
#   Sup  3 | CE: 0.2393 | TokAcc: 0.9057 | Exact: 0.5938 | Unique: 64/64 | Delta: +0.0380 IMPROVED
# sup_step_5 | mean=0.739 std=0.563 median=0.734 %>0=93.8% first5=[0.8333914279937744, 0.7340320348739624, 0.5662332773208618, 1.3948408365249634, -0.5520739555358887]
#   Sup  4 | CE: 0.2627 | TokAcc: 0.8822 | Exact: 0.5469 | Unique: 64/64 | Delta: -0.0233 WORSE
# sup_step_6 | mean=0.737 std=0.574 median=0.765 %>0=92.2% first5=[0.8325539827346802, 0.7463853359222412, 0.5681845545768738, 1.396597981452942, -0.5523939728736877]
#   Sup  5 | CE: 0.2428 | TokAcc: 0.8923 | Exact: 0.5625 | Unique: 64/64 | Delta: +0.0199 IMPROVED
# sup_step_7 | mean=0.738 std=0.567 median=0.753 %>0=92.2% first5=[0.8325470089912415, 0.7363764047622681, 0.5701618790626526, 1.3937660455703735, -0.5527739524841309]
#   Sup  6 | CE: 0.2375 | TokAcc: 0.8990 | Exact: 0.5781 | Unique: 64/64 | Delta: +0.0053 FLAT
# sup_step_8 | mean=0.726 std=0.582 median=0.751 %>0=90.6% first5=[0.8325556516647339, 0.735281229019165, 0.5714890956878662, 1.3938101530075073, -0.5527499318122864]
#   Sup  7 | CE: 0.2348 | TokAcc: 0.8990 | Exact: 0.5938 | Unique: 64/64 | Delta: +0.0027 FLAT
# sup_step_9 | mean=0.739 std=0.573 median=0.763 %>0=92.2% first5=[0.8325672745704651, 0.7403020858764648, 0.5725549459457397, 1.3941212892532349, -0.5526689291000366]
#   Sup  8 | CE: 0.2318 | TokAcc: 0.9057 | Exact: 0.6094 | Unique: 64/64 | Delta: +0.0029 FLAT
# sup_step_10 | mean=0.733 std=0.578 median=0.750 %>0=90.6% first5=[0.8325692415237427, 0.7385081648826599, 0.5733016133308411, 1.394114375114441, -0.5526584386825562]
#   Sup  9 | CE: 0.2352 | TokAcc: 0.9024 | Exact: 0.6094 | Unique: 64/64 | Delta: -0.0033 FLAT
# sup_step_11 | mean=0.740 std=0.572 median=0.758 %>0=92.2% first5=[0.8325707912445068, 0.7373471856117249, 0.5737377405166626, 1.3940783739089966, -0.5526707172393799]
#   Sup 10 | CE: 0.2329 | TokAcc: 0.9024 | Exact: 0.6094 | Unique: 64/64 | Delta: +0.0022 FLAT
# sup_step_12 | mean=0.739 std=0.571 median=0.757 %>0=93.8% first5=[0.8325701951980591, 0.7385953664779663, 0.5739370584487915, 1.394077181816101, -0.5526750087738037]
#   Sup 11 | CE: 0.2393 | TokAcc: 0.9024 | Exact: 0.5938 | Unique: 64/64 | Delta: -0.0063 FLAT
# sup_step_13 | mean=0.741 std=0.569 median=0.754 %>0=93.8% first5=[0.8325710296630859, 0.7385107278823853, 0.5739753842353821, 1.3940826654434204, -0.5526741147041321]
#   Sup 12 | CE: 0.2400 | TokAcc: 0.8990 | Exact: 0.5938 | Unique: 64/64 | Delta: -0.0007 FLAT
# sup_step_14 | mean=0.738 std=0.571 median=0.758 %>0=92.2% first5=[0.8325694799423218, 0.7380512952804565, 0.573919951915741, 1.394081950187683, -0.5526729822158813]
#   Sup 13 | CE: 0.2383 | TokAcc: 0.9024 | Exact: 0.6094 | Unique: 64/64 | Delta: +0.0017 FLAT
# sup_step_15 | mean=0.733 std=0.574 median=0.755 %>0=90.6% first5=[0.8325707316398621, 0.7382774949073792, 0.5738213062286377, 1.3940824270248413, -0.552672266960144]
#   Sup 14 | CE: 0.2437 | TokAcc: 0.8956 | Exact: 0.5781 | Unique: 64/64 | Delta: -0.0054 FLAT
# sup_step_16 | mean=0.741 std=0.571 median=0.756 %>0=92.2% first5=[0.8325694799423218, 0.7383759021759033, 0.5737113356590271, 1.3940821886062622, -0.5526725649833679]
#   Sup 15 | CE: 0.2398 | TokAcc: 0.8990 | Exact: 0.5938 | Unique: 64/64 | Delta: +0.0039 FLAT
#
# --- Sample Predictions at Epoch 50, Last Sup Step ---
#   4566+9540 | Pred: [1, 4, 1, 0, 5] True: [1, 4, 1, 0, 6] WRONG
#   6605+6162 | Pred: [1, 2, 7, 6, 7] True: [1, 2, 7, 6, 7] MATCH
#   7190+7425 | Pred: [1, 4, 6, 1, 9] True: [1, 4, 6, 1, 5] WRONG
#   6682+4961 | Pred: [1, 1, 6, 4, 3] True: [1, 1, 6, 4, 3] MATCH
#   9307+9110 | Pred: [1, 8, 4, 1, 7] True: [1, 8, 4, 1, 7] MATCH
#   5864+4971 | Pred: [1, 0, 8, 3, 5] True: [1, 0, 8, 3, 5] MATCH
#   2720+7265 | Pred: [9, 9, 8, 5] True: [9, 9, 8, 5] MATCH
#   5709+4400 | Pred: [1, 0, 1, 0, 9] True: [1, 0, 1, 0, 9] MATCH
#   3931+8873 | Pred: [1, 2, 8, 0, 3] True: [1, 2, 8, 0, 4] WRONG
#   7473+4102 | Pred: [1, 1, 5, 7, 4] True: [1, 1, 5, 7, 5] WRONG
#
# processing epoch 51
#
# processing epoch 52
#
# processing epoch 53
#
# processing epoch 54
#
# processing epoch 55
#
# processing epoch 56
#
# processing epoch 57
#
# processing epoch 58
#
# processing epoch 59
#
# processing epoch 60
#
# Epoch  60 | CE per supervision step (same batch):
# sup_step_1 | mean=1.600 std=0.834 median=1.626 %>0=96.9% first5=[-0.05599239841103554, 2.748579740524292, 2.4801735877990723, 0.9240686297416687, 2.776444911956787]
#   Sup  0 | CE: 0.4661 | TokAcc: 0.8712 | Exact: 0.4531 | Unique: 63/64
# sup_step_2 | mean=2.318 std=0.761 median=2.356 %>0=98.4% first5=[-0.03559759631752968, 3.6255972385406494, 2.2767813205718994, 1.3575544357299805, 2.346593141555786]
#   Sup  1 | CE: 0.0493 | TokAcc: 0.9831 | Exact: 0.9219 | Unique: 64/64 | Delta: +0.4167 IMPROVED
# sup_step_3 | mean=2.360 std=0.740 median=2.426 %>0=100.0% first5=[0.14849206805229187, 3.824037790298462, 2.355785608291626, 1.4984934329986572, 2.780930519104004]
#   Sup  2 | CE: 0.1125 | TokAcc: 0.9729 | Exact: 0.8906 | Unique: 64/64 | Delta: -0.0632 WORSE
# sup_step_4 | mean=2.348 std=0.741 median=2.392 %>0=100.0% first5=[0.09066393226385117, 3.784348249435425, 2.4007787704467773, 1.427905797958374, 2.8341805934906006]
#   Sup  3 | CE: 0.0433 | TokAcc: 0.9898 | Exact: 0.9531 | Unique: 64/64 | Delta: +0.0692 IMPROVED
# sup_step_5 | mean=2.340 std=0.734 median=2.333 %>0=100.0% first5=[0.12879225611686707, 3.800642251968384, 2.3958706855773926, 1.4465570449829102, 2.330803871154785]
#   Sup  4 | CE: 0.0433 | TokAcc: 0.9898 | Exact: 0.9531 | Unique: 64/64 | Delta: +0.0000 FLAT
# sup_step_6 | mean=2.350 std=0.745 median=2.364 %>0=100.0% first5=[0.11941137164831161, 3.8015706539154053, 2.38655424118042, 1.4421296119689941, 2.7123544216156006]
#   Sup  5 | CE: 0.0732 | TokAcc: 0.9797 | Exact: 0.9219 | Unique: 64/64 | Delta: -0.0299 WORSE
# sup_step_7 | mean=2.347 std=0.741 median=2.368 %>0=100.0% first5=[0.11973550170660019, 3.799781560897827, 2.3864362239837646, 1.4432687759399414, 2.689485549926758]
#   Sup  6 | CE: 0.0443 | TokAcc: 0.9898 | Exact: 0.9531 | Unique: 64/64 | Delta: +0.0288 IMPROVED
# sup_step_8 | mean=2.344 std=0.741 median=2.363 %>0=100.0% first5=[0.12003042548894882, 3.802833318710327, 2.388087749481201, 1.443145990371704, 2.4511334896087646]
#   Sup  7 | CE: 0.0428 | TokAcc: 0.9864 | Exact: 0.9375 | Unique: 64/64 | Delta: +0.0015 FLAT
# sup_step_9 | mean=2.344 std=0.739 median=2.357 %>0=100.0% first5=[0.11996450275182724, 3.8031013011932373, 2.3882553577423096, 1.4430911540985107, 2.669072151184082]
#   Sup  8 | CE: 0.0465 | TokAcc: 0.9864 | Exact: 0.9375 | Unique: 64/64 | Delta: -0.0037 FLAT
# sup_step_10 | mean=2.346 std=0.740 median=2.357 %>0=100.0% first5=[0.11999418586492538, 3.8025596141815186, 2.387974500656128, 1.4431025981903076, 2.6458823680877686]
#   Sup  9 | CE: 0.0500 | TokAcc: 0.9831 | Exact: 0.9375 | Unique: 64/64 | Delta: -0.0035 FLAT
# sup_step_11 | mean=2.342 std=0.745 median=2.365 %>0=100.0% first5=[0.1199665293097496, 3.80188250541687, 2.387921094894409, 1.4431054592132568, 2.5199224948883057]
#   Sup 10 | CE: 0.0420 | TokAcc: 0.9898 | Exact: 0.9531 | Unique: 64/64 | Delta: +0.0080 FLAT
# sup_step_12 | mean=2.348 std=0.739 median=2.365 %>0=100.0% first5=[0.11997862905263901, 3.8008816242218018, 2.3879644870758057, 1.4431006908416748, 2.647977113723755]
#   Sup 11 | CE: 0.0418 | TokAcc: 0.9898 | Exact: 0.9531 | Unique: 64/64 | Delta: +0.0002 FLAT
# sup_step_13 | mean=2.348 std=0.741 median=2.357 %>0=100.0% first5=[0.1199767217040062, 3.799381971359253, 2.3879785537719727, 1.4431028366088867, 2.623216390609741]
#   Sup 12 | CE: 0.0577 | TokAcc: 0.9831 | Exact: 0.9375 | Unique: 64/64 | Delta: -0.0159 WORSE
# sup_step_14 | mean=2.336 std=0.746 median=2.357 %>0=100.0% first5=[0.11997541040182114, 3.7975494861602783, 2.387971878051758, 1.4431045055389404, 2.5583460330963135]
#   Sup 13 | CE: 0.0415 | TokAcc: 0.9898 | Exact: 0.9531 | Unique: 64/64 | Delta: +0.0162 IMPROVED
# sup_step_15 | mean=2.353 std=0.742 median=2.388 %>0=100.0% first5=[0.11997690051794052, 3.7960164546966553, 2.3879683017730713, 1.4431023597717285, 2.6334331035614014]
#   Sup 14 | CE: 0.0425 | TokAcc: 0.9898 | Exact: 0.9531 | Unique: 64/64 | Delta: -0.0010 FLAT
# sup_step_16 | mean=2.349 std=0.738 median=2.364 %>0=100.0% first5=[0.11997761577367783, 3.795574903488159, 2.3879709243774414, 1.4431025981903076, 2.61332631111145]
#   Sup 15 | CE: 0.0676 | TokAcc: 0.9831 | Exact: 0.9375 | Unique: 64/64 | Delta: -0.0251 WORSE
#
# processing epoch 61
#
# processing epoch 62
#
# processing epoch 63
#
# processing epoch 64
#
# processing epoch 65
#
# processing epoch 66
#
# processing epoch 67
#
# processing epoch 68
#
# processing epoch 69
#
# processing epoch 70
#
# Epoch  70 | CE per supervision step (same batch):
# sup_step_1 | mean=1.858 std=0.865 median=1.901 %>0=100.0% first5=[1.3078703880310059, 0.005070109851658344, 2.2612268924713135, 2.462458372116089, 2.5536129474639893]
#   Sup  0 | CE: 0.6344 | TokAcc: 0.8724 | Exact: 0.5938 | Unique: 64/64
# sup_step_2 | mean=2.605 std=0.750 median=2.643 %>0=100.0% first5=[2.304109811782837, 2.798657178878784, 2.2726285457611084, 3.317094087600708, 2.893265724182129]
#   Sup  1 | CE: 0.1054 | TokAcc: 0.9586 | Exact: 0.8125 | Unique: 64/64 | Delta: +0.5290 IMPROVED
# sup_step_3 | mean=2.571 std=0.755 median=2.638 %>0=100.0% first5=[2.687791585922241, 1.9117732048034668, 2.4835376739501953, 3.517461061477661, 2.906280994415283]
#   Sup  2 | CE: 0.1534 | TokAcc: 0.9621 | Exact: 0.8281 | Unique: 64/64 | Delta: -0.0480 WORSE
# sup_step_4 | mean=2.547 std=0.740 median=2.618 %>0=100.0% first5=[2.7099459171295166, 1.8706854581832886, 2.6179261207580566, 3.337388515472412, 2.9069371223449707]
#   Sup  3 | CE: 0.0792 | TokAcc: 0.9759 | Exact: 0.8906 | Unique: 64/64 | Delta: +0.0742 IMPROVED
# sup_step_5 | mean=2.579 std=0.726 median=2.670 %>0=100.0% first5=[2.699152708053589, 1.874375343322754, 2.646486282348633, 3.1845955848693848, 2.909966468811035]
#   Sup  4 | CE: 0.0725 | TokAcc: 0.9793 | Exact: 0.9062 | Unique: 64/64 | Delta: +0.0067 FLAT
# sup_step_6 | mean=2.583 std=0.721 median=2.644 %>0=100.0% first5=[2.6141984462738037, 2.081408977508545, 2.643800735473633, 3.302753210067749, 2.909538507461548]
#   Sup  5 | CE: 0.0717 | TokAcc: 0.9828 | Exact: 0.9219 | Unique: 64/64 | Delta: +0.0007 FLAT
# sup_step_7 | mean=2.568 std=0.721 median=2.637 %>0=100.0% first5=[2.616966962814331, 2.092275619506836, 2.645872116088867, 3.445009469985962, 2.9091639518737793]
#   Sup  6 | CE: 0.0756 | TokAcc: 0.9828 | Exact: 0.9219 | Unique: 64/64 | Delta: -0.0039 FLAT
# sup_step_8 | mean=2.563 std=0.723 median=2.657 %>0=100.0% first5=[2.6593782901763916, 1.83307945728302, 2.646188497543335, 3.368192434310913, 2.909478187561035]
#   Sup  7 | CE: 0.0755 | TokAcc: 0.9828 | Exact: 0.9219 | Unique: 64/64 | Delta: +0.0001 FLAT
# sup_step_9 | mean=2.580 std=0.721 median=2.661 %>0=100.0% first5=[2.6681206226348877, 1.9396244287490845, 2.6454293727874756, 3.2848784923553467, 2.909433126449585]
#   Sup  8 | CE: 0.0683 | TokAcc: 0.9828 | Exact: 0.9219 | Unique: 64/64 | Delta: +0.0073 FLAT
# sup_step_10 | mean=2.583 std=0.719 median=2.659 %>0=100.0% first5=[2.651770830154419, 2.028756618499756, 2.6455745697021484, 3.2612311840057373, 2.9094345569610596]
#   Sup  9 | CE: 0.0736 | TokAcc: 0.9828 | Exact: 0.9219 | Unique: 64/64 | Delta: -0.0053 FLAT
# sup_step_11 | mean=2.580 std=0.727 median=2.650 %>0=100.0% first5=[2.6427485942840576, 1.9771368503570557, 2.6456124782562256, 3.32452130317688, 2.9094464778900146]
#   Sup 10 | CE: 0.0736 | TokAcc: 0.9828 | Exact: 0.9219 | Unique: 64/64 | Delta: -0.0001 FLAT
# sup_step_12 | mean=2.576 std=0.726 median=2.650 %>0=100.0% first5=[2.649818181991577, 1.9608665704727173, 2.6455719470977783, 3.4402248859405518, 2.909442186355591]
#   Sup 11 | CE: 0.0747 | TokAcc: 0.9828 | Exact: 0.9219 | Unique: 64/64 | Delta: -0.0011 FLAT
# sup_step_13 | mean=2.591 std=0.729 median=2.656 %>0=100.0% first5=[2.6556832790374756, 1.9659864902496338, 2.6455819606781006, 3.365940809249878, 2.909442901611328]
#   Sup 12 | CE: 0.0711 | TokAcc: 0.9828 | Exact: 0.9219 | Unique: 64/64 | Delta: +0.0037 FLAT
# sup_step_14 | mean=2.582 std=0.721 median=2.653 %>0=100.0% first5=[2.6530134677886963, 1.9733227491378784, 2.645585298538208, 3.2656333446502686, 2.909442901611328]
#   Sup 13 | CE: 0.0700 | TokAcc: 0.9828 | Exact: 0.9219 | Unique: 64/64 | Delta: +0.0011 FLAT
# sup_step_15 | mean=2.571 std=0.722 median=2.650 %>0=100.0% first5=[2.6497695446014404, 1.9703949689865112, 2.6455800533294678, 3.276545286178589, 2.9094398021698]
#   Sup 14 | CE: 0.0764 | TokAcc: 0.9828 | Exact: 0.9219 | Unique: 64/64 | Delta: -0.0064 FLAT
# sup_step_16 | mean=2.565 std=0.718 median=2.650 %>0=100.0% first5=[2.65044903755188, 1.9688897132873535, 2.6455819606781006, 3.3408420085906982, 2.909442663192749]
#   Sup 15 | CE: 0.0756 | TokAcc: 0.9828 | Exact: 0.9219 | Unique: 64/64 | Delta: +0.0007 FLAT
#
# processing epoch 71
#
# processing epoch 72
#
# processing epoch 73
#
# processing epoch 74
#
# processing epoch 75
#
# processing epoch 76
#
# processing epoch 77
#
# processing epoch 78
#
# processing epoch 79
#
# processing epoch 80
#
# Epoch  80 | CE per supervision step (same batch):
# sup_step_1 | mean=2.918 std=0.991 median=2.818 %>0=100.0% first5=[1.7073142528533936, 4.046464443206787, 2.907984972000122, 4.528769016265869, 2.2440426349639893]
#   Sup  0 | CE: 0.3713 | TokAcc: 0.9147 | Exact: 0.7188 | Unique: 64/64
# sup_step_2 | mean=3.777 std=0.908 median=3.845 %>0=100.0% first5=[2.1047379970550537, 4.5783610343933105, 4.477135181427002, 4.959311485290527, 3.8751518726348877]
#   Sup  1 | CE: 0.0548 | TokAcc: 0.9829 | Exact: 0.9531 | Unique: 64/64 | Delta: +0.3165 IMPROVED
# sup_step_3 | mean=3.806 std=0.910 median=3.750 %>0=100.0% first5=[1.9651501178741455, 4.586223125457764, 4.684141635894775, 4.898578643798828, 3.4916718006134033]
#   Sup  2 | CE: 0.0557 | TokAcc: 0.9863 | Exact: 0.9688 | Unique: 64/64 | Delta: -0.0010 FLAT
# sup_step_4 | mean=3.760 std=0.882 median=3.716 %>0=100.0% first5=[1.9620764255523682, 4.605739116668701, 4.665470123291016, 4.686878681182861, 3.521456003189087]
#   Sup  3 | CE: 0.0935 | TokAcc: 0.9863 | Exact: 0.9688 | Unique: 64/64 | Delta: -0.0378 WORSE
# sup_step_5 | mean=3.757 std=0.883 median=3.784 %>0=100.0% first5=[1.9702789783477783, 4.599730014801025, 4.659964561462402, 4.7402496337890625, 3.5950052738189697]
#   Sup  4 | CE: 0.1697 | TokAcc: 0.9863 | Exact: 0.9688 | Unique: 64/64 | Delta: -0.0762 WORSE
# sup_step_6 | mean=3.780 std=0.905 median=3.809 %>0=100.0% first5=[1.9701683521270752, 4.598543643951416, 4.657686710357666, 4.794651508331299, 3.5636088848114014]
#   Sup  5 | CE: 0.2249 | TokAcc: 0.9863 | Exact: 0.9688 | Unique: 64/64 | Delta: -0.0552 WORSE
# sup_step_7 | mean=3.763 std=0.889 median=3.800 %>0=100.0% first5=[1.9701154232025146, 4.604297637939453, 4.656544208526611, 4.777493000030518, 3.559868574142456]
#   Sup  6 | CE: 0.2443 | TokAcc: 0.9863 | Exact: 0.9688 | Unique: 64/64 | Delta: -0.0194 WORSE
# sup_step_8 | mean=3.762 std=0.885 median=3.795 %>0=100.0% first5=[1.9702770709991455, 4.60594367980957, 4.656421184539795, 4.764833927154541, 3.5691051483154297]
#   Sup  7 | CE: 0.2484 | TokAcc: 0.9863 | Exact: 0.9688 | Unique: 64/64 | Delta: -0.0041 FLAT
# sup_step_9 | mean=3.780 std=0.897 median=3.808 %>0=100.0% first5=[1.970287561416626, 4.604184150695801, 4.656360149383545, 4.767366886138916, 3.5656111240386963]
#   Sup  8 | CE: 0.2488 | TokAcc: 0.9863 | Exact: 0.9688 | Unique: 64/64 | Delta: -0.0003 FLAT
# sup_step_10 | mean=3.766 std=0.885 median=3.808 %>0=100.0% first5=[1.9702823162078857, 4.6030144691467285, 4.656350612640381, 4.771504878997803, 3.5644800662994385]
#   Sup  9 | CE: 0.2487 | TokAcc: 0.9863 | Exact: 0.9688 | Unique: 64/64 | Delta: +0.0000 FLAT
# sup_step_11 | mean=3.767 std=0.889 median=3.805 %>0=100.0% first5=[1.9702908992767334, 4.603240489959717, 4.656350135803223, 4.771092414855957, 3.5666074752807617]
#   Sup 10 | CE: 0.2486 | TokAcc: 0.9863 | Exact: 0.9688 | Unique: 64/64 | Delta: +0.0001 FLAT
# sup_step_12 | mean=3.775 std=0.895 median=3.807 %>0=100.0% first5=[1.9702918529510498, 4.603717803955078, 4.656351566314697, 4.769875526428223, 3.565272092819214]
#   Sup 11 | CE: 0.2489 | TokAcc: 0.9863 | Exact: 0.9688 | Unique: 64/64 | Delta: -0.0003 FLAT
# sup_step_13 | mean=3.764 std=0.884 median=3.808 %>0=100.0% first5=[1.9702937602996826, 4.603818416595459, 4.656352519989014, 4.769872188568115, 3.565702199935913]
#   Sup 12 | CE: 0.2488 | TokAcc: 0.9863 | Exact: 0.9688 | Unique: 64/64 | Delta: +0.0002 FLAT
# sup_step_14 | mean=3.771 std=0.893 median=3.807 %>0=100.0% first5=[1.9702904224395752, 4.603704929351807, 4.656351566314697, 4.7702317237854, 3.5657360553741455]
#   Sup 13 | CE: 0.2488 | TokAcc: 0.9863 | Exact: 0.9688 | Unique: 64/64 | Delta: -0.0001 FLAT
# sup_step_15 | mean=3.771 std=0.893 median=3.807 %>0=100.0% first5=[1.9702904224395752, 4.603635787963867, 4.656351089477539, 4.770263671875, 3.5655930042266846]
#   Sup 14 | CE: 0.2487 | TokAcc: 0.9863 | Exact: 0.9688 | Unique: 64/64 | Delta: +0.0002 FLAT
# sup_step_16 | mean=3.764 std=0.884 median=3.807 %>0=100.0% first5=[1.9702913761138916, 4.603646278381348, 4.656351089477539, 4.770161151885986, 3.5656983852386475]
#   Sup 15 | CE: 0.2486 | TokAcc: 0.9863 | Exact: 0.9688 | Unique: 64/64 | Delta: +0.0001 FLAT
#
# processing epoch 81
#
# processing epoch 82
#
# processing epoch 83
#
# processing epoch 84
#
# processing epoch 85
#
# processing epoch 86
#
# processing epoch 87
#
# processing epoch 88
#
# processing epoch 89
#
# processing epoch 90
#
# Epoch  90 | CE per supervision step (same batch):
# sup_step_1 | mean=4.547 std=1.155 median=4.655 %>0=100.0% first5=[3.3662874698638916, 4.711928844451904, 5.202947616577148, 4.530571937561035, 5.039999008178711]
#   Sup  0 | CE: 0.0289 | TokAcc: 0.9931 | Exact: 0.9688 | Unique: 64/64
# sup_step_2 | mean=5.431 std=0.928 median=5.489 %>0=100.0% first5=[4.9626359939575195, 5.780092239379883, 5.84848690032959, 5.419877052307129, 5.2819013595581055]
#   Sup  1 | CE: 0.0104 | TokAcc: 0.9966 | Exact: 0.9844 | Unique: 64/64 | Delta: +0.0185 IMPROVED
# sup_step_3 | mean=5.414 std=0.927 median=5.437 %>0=100.0% first5=[4.690812110900879, 5.7887115478515625, 5.76609468460083, 5.125143051147461, 5.250766277313232]
#   Sup  2 | CE: 0.0087 | TokAcc: 0.9966 | Exact: 0.9844 | Unique: 64/64 | Delta: +0.0017 FLAT
# sup_step_4 | mean=5.399 std=0.914 median=5.444 %>0=100.0% first5=[4.80032205581665, 5.740066051483154, 5.759875297546387, 5.550131320953369, 5.243703365325928]
#   Sup  3 | CE: 0.0059 | TokAcc: 0.9966 | Exact: 0.9844 | Unique: 64/64 | Delta: +0.0028 FLAT
# sup_step_5 | mean=5.396 std=0.920 median=5.441 %>0=100.0% first5=[4.742094993591309, 5.765205383300781, 5.759669303894043, 5.685022354125977, 5.248963832855225]
#   Sup  4 | CE: 0.0046 | TokAcc: 1.0000 | Exact: 1.0000 | Unique: 64/64 | Delta: +0.0013 FLAT
# sup_step_6 | mean=5.400 std=0.928 median=5.438 %>0=100.0% first5=[4.7332868576049805, 5.767136573791504, 5.762454509735107, 5.491225242614746, 5.249777793884277]
#   Sup  5 | CE: 0.0045 | TokAcc: 1.0000 | Exact: 1.0000 | Unique: 64/64 | Delta: +0.0001 FLAT
# sup_step_7 | mean=5.392 std=0.938 median=5.435 %>0=100.0% first5=[4.761641025543213, 5.764477252960205, 5.762159824371338, 5.461189270019531, 5.249972343444824]
#   Sup  6 | CE: 0.0039 | TokAcc: 1.0000 | Exact: 1.0000 | Unique: 64/64 | Delta: +0.0007 FLAT
# sup_step_8 | mean=5.386 std=0.946 median=5.435 %>0=100.0% first5=[4.75931453704834, 5.763023853302002, 5.761775016784668, 5.539830207824707, 5.250034332275391]
#   Sup  7 | CE: 0.0027 | TokAcc: 1.0000 | Exact: 1.0000 | Unique: 64/64 | Delta: +0.0011 FLAT
# sup_step_9 | mean=5.385 std=0.948 median=5.436 %>0=100.0% first5=[4.748715877532959, 5.763433933258057, 5.761840343475342, 5.534101963043213, 5.2499542236328125]
#   Sup  8 | CE: 0.0021 | TokAcc: 1.0000 | Exact: 1.0000 | Unique: 64/64 | Delta: +0.0006 FLAT
# sup_step_10 | mean=5.385 std=0.946 median=5.436 %>0=100.0% first5=[4.752651691436768, 5.763627052307129, 5.761880874633789, 5.522336006164551, 5.2498979568481445]
#   Sup  9 | CE: 0.0023 | TokAcc: 1.0000 | Exact: 1.0000 | Unique: 64/64 | Delta: -0.0002 FLAT
# sup_step_11 | mean=5.393 std=0.937 median=5.436 %>0=100.0% first5=[4.754820823669434, 5.763639450073242, 5.761875152587891, 5.519208908081055, 5.249905586242676]
#   Sup 10 | CE: 0.0022 | TokAcc: 1.0000 | Exact: 1.0000 | Unique: 64/64 | Delta: +0.0000 FLAT
# sup_step_12 | mean=5.393 std=0.934 median=5.436 %>0=100.0% first5=[4.753371238708496, 5.763601779937744, 5.76186990737915, 5.518880367279053, 5.249921798706055]
#   Sup 11 | CE: 0.0035 | TokAcc: 1.0000 | Exact: 1.0000 | Unique: 64/64 | Delta: -0.0013 FLAT
# sup_step_13 | mean=5.396 std=0.930 median=5.436 %>0=100.0% first5=[4.752708911895752, 5.763596534729004, 5.761869430541992, 5.517818450927734, 5.249922275543213]
#   Sup 12 | CE: 0.0064 | TokAcc: 0.9966 | Exact: 0.9844 | Unique: 64/64 | Delta: -0.0029 FLAT
# sup_step_14 | mean=5.400 std=0.927 median=5.436 %>0=100.0% first5=[4.753548622131348, 5.7636003494262695, 5.761870384216309, 5.51736307144165, 5.249919414520264]
#   Sup 13 | CE: 0.0052 | TokAcc: 0.9966 | Exact: 0.9844 | Unique: 64/64 | Delta: +0.0012 FLAT
# sup_step_15 | mean=5.391 std=0.933 median=5.436 %>0=100.0% first5=[4.753437042236328, 5.763602256774902, 5.761870384216309, 5.517113208770752, 5.2499189376831055]
#   Sup 14 | CE: 0.0045 | TokAcc: 1.0000 | Exact: 1.0000 | Unique: 64/64 | Delta: +0.0008 FLAT
# sup_step_16 | mean=5.391 std=0.936 median=5.436 %>0=100.0% first5=[4.753269672393799, 5.763601303100586, 5.761870384216309, 5.517005443572998, 5.249919891357422]
#   Sup 15 | CE: 0.0043 | TokAcc: 1.0000 | Exact: 1.0000 | Unique: 64/64 | Delta: +0.0001 FLAT
#
# processing epoch 91
#
# processing epoch 92
#
# processing epoch 93
#
# processing epoch 94
#
# processing epoch 95
#
# processing epoch 96
#
# processing epoch 97
#
# processing epoch 98
#
# processing epoch 99
#
# ======================================================================
# FINAL BREAKDOWN: All Supervision Steps (Last Epoch)
# ======================================================================
#   Sup  0 | CE: 0.0939 | TokAcc: 0.9729 | Exact: 0.8750 | Unique: 64/64 | Q: 3.7925
#   Sup  1 | CE: 0.0103 | TokAcc: 0.9966 | Exact: 0.9844 | Unique: 64/64 | Q: 4.2725
#   Sup  2 | CE: 0.0049 | TokAcc: 1.0000 | Exact: 1.0000 | Unique: 64/64 | Q: 4.2814
#   Sup  3 | CE: 0.0057 | TokAcc: 1.0000 | Exact: 1.0000 | Unique: 64/64 | Q: 4.2763
#   Sup  4 | CE: 0.0063 | TokAcc: 1.0000 | Exact: 1.0000 | Unique: 64/64 | Q: 4.2791
#   Sup  5 | CE: 0.0059 | TokAcc: 1.0000 | Exact: 1.0000 | Unique: 64/64 | Q: 4.2755
#   Sup  6 | CE: 0.0059 | TokAcc: 1.0000 | Exact: 1.0000 | Unique: 64/64 | Q: 4.2781
#   Sup  7 | CE: 0.0058 | TokAcc: 1.0000 | Exact: 1.0000 | Unique: 64/64 | Q: 4.2801
#   Sup  8 | CE: 0.0058 | TokAcc: 1.0000 | Exact: 1.0000 | Unique: 64/64 | Q: 4.2763
#   Sup  9 | CE: 0.0058 | TokAcc: 1.0000 | Exact: 1.0000 | Unique: 64/64 | Q: 4.2786
#   Sup 10 | CE: 0.0058 | TokAcc: 1.0000 | Exact: 1.0000 | Unique: 64/64 | Q: 4.2793
#   Sup 11 | CE: 0.0058 | TokAcc: 1.0000 | Exact: 1.0000 | Unique: 64/64 | Q: 4.2780
#   Sup 12 | CE: 0.0058 | TokAcc: 1.0000 | Exact: 1.0000 | Unique: 64/64 | Q: 4.2787
#   Sup 13 | CE: 0.0058 | TokAcc: 1.0000 | Exact: 1.0000 | Unique: 64/64 | Q: 4.2793
#   Sup 14 | CE: 0.0058 | TokAcc: 1.0000 | Exact: 1.0000 | Unique: 64/64 | Q: 4.2786
#   Sup 15 | CE: 0.0058 | TokAcc: 1.0000 | Exact: 1.0000 | Unique: 64/64 | Q: 4.2780
#
# --- Final Sample Predictions ---
#   7739+3116 | Pred: [1, 0, 8, 5, 5] True: [1, 0, 8, 5, 5] MATCH
#   4696+4215 | Pred: [8, 9, 1, 1] True: [8, 9, 1, 1] MATCH
#   4625+1698 | Pred: [6, 3, 2, 3] True: [6, 3, 2, 3] MATCH
#   5432+7268 | Pred: [1, 2, 7, 0, 0] True: [1, 2, 7, 0, 0] MATCH
#   4127+6367 | Pred: [1, 0, 4, 9, 4] True: [1, 0, 4, 9, 4] MATCH
#   9667+4290 | Pred: [1, 3, 9, 5, 7] True: [1, 3, 9, 5, 7] MATCH
#   4702+7803 | Pred: [1, 2, 5, 0, 5] True: [1, 2, 5, 0, 5] MATCH
#   4227+3514 | Pred: [7, 7, 4, 1] True: [7, 7, 4, 1] MATCH
#   8874+8949 | Pred: [1, 7, 8, 2, 3] True: [1, 7, 8, 2, 3] MATCH
#   5514+4271 | Pred: [9, 7, 8, 5] True: [9, 7, 8, 5] MATCH

# %%
# ============================================================================
# Q-LOSS AND HALT MECHANISM: STEP-BY-STEP DEBUGGING JOURNEY
# 4-digit addition with TRM, single-head soft-mean Q-loss
# ============================================================================


# ----------------------------------------------------------------------------
# STEP 1: THE INITIAL ILLUSION OF SUCCESS
# ----------------------------------------------------------------------------
# Trained masked run for 100 epochs. CE dropped to ~0.008, Q-loss to ~0.20,
# avg_steps went from 5 down to 1. On the surface this looked like the model
# was learning to halt early once it had the answer figured out.
#
# The framing was: "model got smart, learned it only needs one step,
# adaptive halting working as designed."


# ----------------------------------------------------------------------------
# STEP 2: avg_steps = 1.0 IS NOT EFFICIENT HALTING, IT IS COLLAPSE
# ----------------------------------------------------------------------------
# At epoch 10, val accuracy was only 2.5% but halt was already firing at
# step 1 for 100% of validation samples. By epoch 30, val accuracy was 18%.
# Step-1 halting was happening LONG before the model had learned anything.
#
# This means recursion across supervision steps was never actually used.
# The model learned 4-digit addition entirely through the depth of one
# forward pass (T*n + 1 = 19 net evaluations). The halt head became
# vestigial - always saying "stop now" regardless of correctness.


# ----------------------------------------------------------------------------
# STEP 3: METRIC FIX - avg_steps WAS PER-BATCH-MAX, NOT PER-SAMPLE-MEAN
# ----------------------------------------------------------------------------
# The avg_steps metric was computed using when the loop breaks (when ALL
# samples halt). That gives the per-batch maximum, not the per-sample mean.
#
# Fixed by tracking halt_step per sample, then computing distribution stats:
# mean, median, %step1, %never_halted, full distribution. This gave us the
# real picture - at epoch 10, %step1 was already 88.9%.


# ----------------------------------------------------------------------------
# STEP 4: BUG IN Q_LOSS - PAD TOKENS WERE INFLATING THE TARGET
# ----------------------------------------------------------------------------
# The soft-mean target was computed over ALL positions including pad.
# When the model learned to predict PAD at pad positions, those matches
# counted as "correct", artificially inflating the target value.
#
# Concretely: a 4-digit answer (5 positions, 1 pad) where 2 of 4 real
# digits are right has true token accuracy 2/4 = 0.5, but the soft-mean
# computed it as 3/5 = 0.6, pushing halt logit harder toward firing.
#
# Fixed by masking pad positions in the target computation. But this was
# not the root cause - it was a symptom of the deeper target-design issue.


# ----------------------------------------------------------------------------
# STEP 5: WORKED OUT THE GRADIENT DYNAMICS PRECISELY
# ----------------------------------------------------------------------------
# Q-loss is binary cross-entropy on halt logit h with target t.
# Even though we never call sigmoid in the code, BCE-with-logits applies
# it internally.
#
# The gradient on h is: dL/dh = sigmoid(h) - t
# The optimizer subtracts the gradient, so h moves toward logit(t).
#
# Initial state: h is near 0 (random init), so sigmoid(h) is near 0.5.
# Gradient direction depends on whether target is above or below 0.5:
#
#     t < 0.5: gradient is positive, h decreases, halt does not fire
#     t = 0.5: gradient is zero, h stays put
#     t > 0.5: gradient is negative, h increases, halt fires
#
# The decision rule "halt > 0" is equivalent to "sigmoid(halt) > 0.5"
# because sigmoid is monotonic and sigmoid(0) = 0.5.
#
# So halt fires when target crosses 0.5. With soft-mean target, this means
# halt fires when token accuracy crosses 0.5. But we want halt to fire when
# the WHOLE answer is right (EM = 1.0), not when half the tokens are right.
#
# The semantic mismatch: target measures partial correctness, decision rule
# expects full correctness. They were never aligned.


# ----------------------------------------------------------------------------
# STEP 6: TRIED A "BISTABILITY" FRAMEWORK - FALSIFIED BY DATA
# ----------------------------------------------------------------------------
# Hypothesis: same Q-loss might converge to opposite policies in different
# regimes. With masked training (loop breaks on halt), the Q-head sees
# gradient mostly from early supervision steps. With diagnostic training
# (full rollout), it sees gradient from all 16 steps. Maybe these produce
# opposite equilibria - "always halt" vs "never halt".
#
# Tested by directly logging halt logits at epoch 0 in both regimes:
#     Masked epoch 0:     mean halt = -0.65, %>0 = 0%
#     Diagnostic epoch 0: mean halt = -0.66, %>0 = 0%
#
# Identical starting points. By epoch 10 BOTH regimes had halt logits
# above 0 with 100% firing. No bistability. The driver is target value
# crossing 0.5, not regime-specific gradient distribution.
#
# The simpler story holds: as token accuracy crosses 0.5 across training,
# the equilibrium logit crosses 0, and halt fires regardless of regime.


# ----------------------------------------------------------------------------
# STEP 7: SETTLED ON HYPOTHESIS C (BOTH PROBLEMS, INDEPENDENT)
# ----------------------------------------------------------------------------
#
# A) TASK SIMPLICITY:
#    Diagnostic run (no halt, full rollout) showed Sup 0 -> Sup 1 buys
#    ~19 EM points, but Sup 1 -> Sup 15 is flat. Recursion plateaus
#    after one refinement step. 4-digit addition is a fixed-depth
#    computation - one deep pass plus optionally one refinement is enough.
#
# B) Q-LOSS BROKEN:
#    Halt fires when token accuracy crosses 0.5, far below sequence-level
#    correctness. Step 6 showed this happens regardless of training regime.
#
# C) BOTH ARE TRUE AND THEY ARE INDEPENDENT:
#    On this task, fixing Q-loss alone gets you at most the bounded
#    recursion benefit (~19 EM points from one refinement step).
#    The two failures don't compound - they live in separate parts of
#    the system.


# ----------------------------------------------------------------------------
# STEP 8: EARLY ATTEMPT - SIMPLY CHANGE TARGET TO BINARY EM (REJECTED)
# ----------------------------------------------------------------------------
# Suggested: replace soft-mean with binary EM (1 if all tokens right, else 0).
#
# User rightly pushed back: this target is too aggressive for sequence
# tasks. Until any sample achieves EM, target is always 0 and the Q-head
# has no learning signal at all. Gradient sparsity becomes the new failure.
#
# This pushed us toward needing a warmup phase OR a softer continuous
# target that still tracks EM more closely than soft-mean.


# ----------------------------------------------------------------------------
# STEP 9: TRIED OPTION 1 - THRESHOLD SHIFT (halt > 1.5 instead of halt > 0)
# ----------------------------------------------------------------------------
# Reasoning: if halt > 0 corresponds to sigmoid(h) > 0.5 (token accuracy
# 50%), then halt > 1.5 corresponds to sigmoid(h) > 0.82 (token accuracy
# 82%). Closer to EM. Should delay halt firing until model is much better.
#
# Result over 90 epochs:
#     Phase 1 (epochs 0-30): halt logits below 1.5, halt rarely fires,
#         model uses all 5 supervision steps, val accuracy slowly builds
#         (0.06% -> 13.9%).
#     Phase 2 (epochs 30-90): token accuracy gets high enough that target
#         saturates near 1, halt logits explode past 1.5, collapse re-emerges.
#         Val accuracy reaches 99.24% by epoch 90.
#
# Key observation: halt logits across supervision steps within ONE forward
# pass are nearly identical (e.g., 0.84, 0.86, 0.86, 0.86, 0.86). The Q-head
# is not discriminating by latent state - it outputs roughly the same logit
# regardless of where in the recursion we are. This confirms the latent
# state hits a fixed point fast on this task.


# ----------------------------------------------------------------------------
# STEP 10: WHY THRESHOLD SHIFT IS NOT A REAL FIX (ONLY A DELAY)
# ----------------------------------------------------------------------------
# As the model improves, token accuracy approaches 1.
# As token accuracy approaches 1, soft-mean target approaches 1.
# As target approaches 1, the equilibrium halt logit logit(t) approaches +infinity.
# Any fixed threshold gets crossed eventually.
#
# So threshold shift only buys time. The 30-epoch delay let us train with
# full recursion early on, and that produced a better final model than V1
# (99% vs ?, where V1 was last measured at 87% at epoch 40 - we never ran
# V1 to epoch 90 to get a fair comparison).
#
# The improvement might come from "early recursion as curriculum" rather
# than from the threshold shift directly. We cannot tell without running
# V1 to the same epoch count.


# ----------------------------------------------------------------------------
# STEP 11: TWO REAL FIXES STILL UNTESTED
# ----------------------------------------------------------------------------
#
# OPTION 2: GEOMETRIC MEAN OF PROBABILITIES
#     Target = product of per-token probabilities, then take L-th root.
#     Any low-probability token drags target down sharply. Closer to EM
#     in spirit but stays continuous, so gradient signal is preserved.
#     Note: geometric mean of binary indicators reduces to binary EM,
#     so the useful version uses the model's softmax probabilities.
#
# OPTION 3: BINARY EM WITH WARMUP
#     Target is 1 only when full sequence is correct, else 0. This matches
#     what halt > 0 should mean exactly.
#     Solves gradient sparsity by training CE only for the first N epochs,
#     then turning on Q-loss once train EM exceeds some threshold (e.g. 5%).
#     Use train EM (not val EM) because that determines whether Q-targets
#     are non-trivial during training.


# ----------------------------------------------------------------------------
# STEP 12: WHY WE DID NOT GO WITH PAPER'S TWO-HEAD BOOTSTRAP
# ----------------------------------------------------------------------------
# Paper uses Q_halt and Q_continue, where Q_continue is bootstrapped from
# next step's Q-values. This gives non-stationary targets that don't
# saturate as model improves.
#
# We rejected this because TRM's appeal is single-head simplicity.
# Adding a second head defeats the architectural premise. The interesting
# research question is: can we keep one head and find a target that works?


# ----------------------------------------------------------------------------
# CORE LESSON FROM ALL OF THIS
# ----------------------------------------------------------------------------
# The Q-loss bug is not "target value too lenient" or "stationary target"
# or "regime-dependent bistability". Those framings were tried and refined
# or falsified.
#
# The real bug is a SEMANTIC MISMATCH between target and decision rule:
#     Target (soft-mean)       = expected token accuracy
#     Decision rule (halt > 0) = "model has solved the problem"
# These two quantities are not the same thing.
#
# Any honest fix must either:
#     (a) Change target to match the rule (binary EM with warmup, or
#         geometric mean of probabilities)
#     (b) Change the decision rule to match the target (threshold shift,
#         which only delays the issue because the target saturates at 1)
#
# On 4-digit addition, the bug coexists with task simplicity, so even a
# perfect Q-loss only buys us bounded improvement. The fix needs to be
# tested on a task with real iterative depth (Sudoku, Maze) to show
# meaningful recursion utilization.


# ----------------------------------------------------------------------------
# QUICK MATH REFERENCE
# ----------------------------------------------------------------------------
# halt > 0  <=>  sigmoid(halt) > 0.5
# BCE-with-logits gradient: dL/dh = sigmoid(h) - t
# Optimizer pulls halt logit toward logit(t) = log(t / (1 - t))
# logit(0.5) = 0  -> this is the threshold-flipping point
# logit(0.95) = +2.94  -> halt > 3 fires only when target ~ 0.95
# As t -> 1, logit(t) -> +infinity, so any fixed threshold eventually crossed

# %%
import torch
import torch.nn.functional as F
from collections import Counter

# --- Training Loop ---

def model_training_and_validation_with_mask(c, T, n_sup, HALT_THRESHOLD):
  model = TinyRModel(hidden_size, vocab_size, inp_seq_len=inp_seq_len, out_seq_len=out_seq_len).to(device)
  optimizer = torch.optim.Adam(model.parameters(), lr=1e-4)

  print('PAD_TOKEN: ', PAD_TOKEN)
  criterion = nn.CrossEntropyLoss(reduction='none', ignore_index=PAD_TOKEN)

  epochs = 100


  print('Training Logs ------ \n')

  for epoch in range(epochs):
        model.train()

        running_loss = 0
        running_q = 0
        running_n_taken = 0

        all_halt_steps = []
        all_halt_logits = []

        for step, batch in enumerate(train_loader):
            input_ids = batch['input_ids'].to(device)
            labels = batch['labels'].to(device)
            batch_size_curr = input_ids.size(0)
            seq_len = labels.size(1)

            active_mask = torch.ones(batch_size_curr, dtype=torch.bool, device=device)

            x = input_ids
            y = torch.zeros(batch_size_curr, hidden_size, device=device)
            z = torch.zeros(batch_size_curr, hidden_size, device=device)

            step_loss = step_q = 0
            overall_loss = torch.tensor(0.0, device=device)

            # at the start of each batch
            halt_step = torch.full((batch_size_curr,), n_sup, dtype=torch.long, device=device)


            for i in range(n_sup):
                f_out, halt, y_new, z_new = model(x, y, z, T, n=6)

                all_halt_logits.append(halt.squeeze().detach().cpu())

                # Update hidden states only for active samples
                y = torch.where(active_mask.unsqueeze(1), y_new.detach(), y)
                z = torch.where(active_mask.unsqueeze(1), z_new.detach(), z)

                seq_len = labels.size(1)  #this is padded to length 6 for now

                # Prediction Loss (Per Token: Batch * SeqLen)
                loss_per_token = criterion(f_out.view(-1, vocab_size), labels.view(-1))

                # Halting Loss (Per Sample: Batch)
                q_loss_per_sample = Q_LOSS(halt, f_out.view(-1, seq_len, vocab_size), labels)

                # Expand active mask to token level for prediction loss
                # active_mask: (B) -> (B, Seq) -> (B*Seq)


                token_mask = active_mask.unsqueeze(1).expand(-1, seq_len).reshape(-1).float()
                sample_mask = active_mask.float()

                num_active_tokens = token_mask.sum() + 1e-8
                num_active_samples = sample_mask.sum() + 1e-8

                # Weighted sum of losses for active samples
                current_step_loss = (loss_per_token * token_mask).sum() / num_active_tokens
                current_step_q = (q_loss_per_sample.squeeze() * sample_mask).sum() / num_active_samples

                overall_loss += (current_step_loss + c * current_step_q)

                step_loss += current_step_loss.item()
                step_q += current_step_q.item()

                # Update halting decision
                halt_decision = (halt.squeeze() > HALT_THRESHOLD) & active_mask

                # inside the for i in range(n_sup): loop, after halt_decision is computed
                halt_step[halt_decision] = i + 1

                active_mask = active_mask & (~halt_decision)

                if active_mask.sum() == 0:
                  break

            # at the end of the batch, accumulate
            all_halt_steps.append(halt_step.cpu())

            n_taken = i + 1
            overall_loss /= n_taken
            # inside the step loop, after `n_taken = i + 1`:
            running_n_taken += n_taken

            optimizer.zero_grad()
            overall_loss.backward()
            optimizer.step()

            running_loss += step_loss / n_taken
            running_q += step_q / n_taken



        avg_loss = running_loss / len(train_loader)
        avg_q_loss = running_q / len(train_loader)

        avg_steps = running_n_taken / len(train_loader)

        print(f'Training processed epoch {epoch}')
        if epoch % 10 == 0:
            print(f" Training epoch {epoch} | CE: {avg_loss:.4f} | Q-Loss: {avg_q_loss:.4f} | Avg Steps: {avg_steps}")

            all_halt_steps = torch.cat(all_halt_steps)
            all_halt_logits = torch.cat(all_halt_logits)

            mean_h = all_halt_steps.float().mean().item()
            median_h = all_halt_steps.float().median().item()
            frac_1 = (all_halt_steps == 1).float().mean().item()
            frac_max = (all_halt_steps == n_sup).float().mean().item()
            dist = dict(Counter(all_halt_steps.tolist()))

            print(f"halt logit: mean={all_halt_logits.mean().item():.3f} "
                  f"std={all_halt_logits.std().item():.3f} "
                  f"max={all_halt_logits.max().item():.3f} "
                  f"%>0={(all_halt_logits > 0).float().mean().item():.1%} "
                  f"%>1.5={(all_halt_logits > 1.5).float().mean().item():.1%}")

            print(f"halt steps: mean={mean_h:.2f} median={median_h:.0f} "
                  f"%step1={frac_1:.1%} %never={frac_max:.1%} dist={dist}")

        running_loss = running_q = 0


        if epoch % 10 == 0:
            print('\nValidation Logs ------ \n')
            model.eval()
            correct = 0
            total = 0

            all_halt_steps_validation = []

            with torch.no_grad():
                for val_step, batch in enumerate(val_loader):
                    input_ids = batch['input_ids'].to(device)
                    labels = batch['labels'].to(device)
                    batch_size_curr = input_ids.size(0)

                    active_mask = torch.ones(batch_size_curr, dtype=torch.bool, device=device)

                    # at the start of each batch
                    val_halt_step = torch.full((batch_size_curr,), n_sup, dtype=torch.long, device=device)

                    x = input_ids
                    y = torch.zeros(input_ids.size(0), hidden_size, device=device)
                    z = torch.zeros(input_ids.size(0), hidden_size, device=device)

                    final_logits = torch.zeros(batch_size_curr, out_seq_len * vocab_size, device=device)

                    for i in range(n_sup):
                        f_out_val, val_halt, y_new, z_new = model(x, y, z, T, n=6)
                        y, z = y_new.detach(), z_new.detach()

                        # Update halting decision
                        if val_step == 0:
                            print(f"sup_step_{i+1} | mean={val_halt.mean().item():.3f} "
                                  f"std={val_halt.std().item():.3f} "
                                  f"median={val_halt.median().item():.3f} "
                                  f"%>0={(val_halt > 0).float().mean().item():.1%} "
                                  f"%>1.5={(val_halt > 1.5).float().mean().item():.1%} "
                                  f"first5={val_halt[:5].squeeze().tolist()}")

                        halt_decision = (val_halt.squeeze() > HALT_THRESHOLD) & active_mask
                               # inside the for i in range(n_sup): loop, after halt_decision is computed
                        val_halt_step[halt_decision] = i + 1

                        active_mask = active_mask & (~halt_decision)

                        final_logits[halt_decision] = f_out_val[halt_decision]

                        if active_mask.sum() == 0:
                           break

                    # at the end of the batch, accumulate
                    all_halt_steps_validation.append(val_halt_step.cpu())

                    final_logits[active_mask] = f_out_val[active_mask]

                    preds = final_logits.view(-1, seq_len, vocab_size).argmax(dim=-1)
                    non_pad = (labels != PAD_TOKEN)
                    matches_per_token = (preds == labels) | ~non_pad
                    exact = matches_per_token.all(dim=-1)

                    correct += exact.sum().item()
                    total   += labels.size(0)


            print(f"\nValidation Accuracy: {100 * correct / total:.2f}%")

            all_halt_steps_validation = torch.cat(all_halt_steps_validation)

            mean_h = all_halt_steps_validation.float().mean().item()
            median_h = all_halt_steps_validation.float().median().item()
            frac_1 = (all_halt_steps_validation == 1).float().mean().item()
            frac_max = (all_halt_steps_validation == n_sup).float().mean().item()
            dist = dict(Counter(all_halt_steps_validation.tolist()))

            print(f"validation halt steps: mean={mean_h:.2f} median={median_h:.0f} "
                  f"%step1={frac_1:.1%} %never={frac_max:.1%} dist={dist}")

# %%
import torch
import torch.nn.functional as F

def model_training_and_validation(c, T, n_sup):
    running_loss = 0
    running_q = 0

    # Use PAD_TOKEN for ignoring index in loss
    criterion = nn.CrossEntropyLoss(ignore_index=PAD_TOKEN)

    # Initialize model with correct sequence lengths
    model = TinyRModel(hidden_size, vocab_size, inp_seq_len, out_seq_len).to(device)
    optimizer = torch.optim.Adam(model.parameters(), lr=1e-4)

    epochs = 100

    print('Training Logs ------ \n')
    for _ in range(epochs):
        model.train()
        for step, batch in enumerate(train_loader):
            input_ids = batch['input_ids'].to(device)
            labels = batch['labels'].to(device)

            x = input_ids
            # Initial states must be (Batch, hidden_size)
            y = torch.zeros(input_ids.size(0), hidden_size, device=device)
            z = torch.zeros(input_ids.size(0), hidden_size, device=device)

            step_loss = step_q = 0
            overall_loss = 0
            n_taken = 0

            for i in range(n_sup):
                n_taken = i + 1
                f_out, halt, y_new, z_new = model(x, y, z, T, n=6)
                y, z = y_new.detach(), z_new.detach()

                # Map f_out (B, out_seq_len * vocab_size) to (B * out_seq_len, vocab_size)
                seq_len = labels.size(1)

                logits = f_out.view(-1, vocab_size)
                targets = labels.view(-1)

                # print(halt.shape, targets.shape, labels.shape, logits.shape)

                loss = criterion(logits, targets)

                # print(f_out.shape, labels.shape)
                q_loss_val = Q_LOSS(halt, f_out.view(-1, seq_len, vocab_size), labels)

                overall_loss += (loss + c * q_loss_val)
                step_loss += loss.item()
                step_q += q_loss_val.item()

                if (halt > 0).all():
                    break

            overall_loss = overall_loss / n_taken
            optimizer.zero_grad()
            overall_loss.backward()
            optimizer.step()

            running_loss += step_loss / n_taken
            running_q += step_q / n_taken

            if step % 50 == 0 and step > 0 and n_taken<n_sup:
                print(f"Step {step} | CE: {running_loss/50:.4f} | Q-Loss: {running_q/50:.4f} | Avg Steps: {n_taken}")
                running_loss = running_q = 0

        print('\nValidation Logs ------ \n')
        model.eval()
        correct = 0
        total = 0
        with torch.no_grad():
            for val_step, batch in enumerate(val_loader):
                input_ids = batch['input_ids'].to(device)
                labels = batch['labels'].to(device)
                x = input_ids
                y = torch.zeros(input_ids.size(0), hidden_size, device=device)
                z = torch.zeros(input_ids.size(0), hidden_size, device=device)

                for i in range(n_sup):
                    f_out_val, val_halt, y_new, z_new = model(x, y, z, T, n=6)
                    y, z = y_new.detach(), z_new.detach()
                    if (val_halt > 0).all(): break

                logits = f_out_val.view(-1, vocab_size)
                targets = labels.view(-1)
                predictions = logits.argmax(dim=1)

                mask = targets != PAD_TOKEN
                correct += (predictions[mask] == targets[mask]).sum().item()
                total += mask.sum().item()

        if epoch % 10 == 0:
            print(f"\nValidation Accuracy: {100 * correct / total:.2f}%")

# %%
# Accessing the underlying .data list from the AdditionDataset object
# Start with 2-digit additions with no carries
easy_dataset = [d for d in dataset.data if d['num_digits'] <= 2 and d['max_carry_chain'] == 0]
print(f"Easy examples: {len(easy_dataset)}")

# If that works, try with carries
medium_dataset = [d for d in dataset.data if d['num_digits'] <= 2]
print(f"Medium examples: {len(medium_dataset)}")

# Then scale up
hard_dataset = [d for d in dataset.data if d['num_digits'] == 4]
print(f"Hard examples: {len(hard_dataset)}")
# Out:
# Easy examples: 0
# Medium examples: 0
# Hard examples: 50000

# %%
## t-0

# Config: n_sup=5, halt > 0, c=0.1, T=3, 100 epochs
# Prediction: halt firing tracks train exact-match, not token accuracy.
# Early epochs: all-zero targets push halt negative -> %never = 100%, full recursion used, slower epochs.
# Log: training-logs/binary-em-halt-0.txt

HALT_THRESHOLD = 0
model_training_and_validation_with_mask(c=0.1, T=3, n_sup=5, HALT_THRESHOLD = HALT_THRESHOLD)
# Out:
# PAD_TOKEN:  11
# Training Logs ------
#
# Training processed epoch 0
#  Training epoch 0 | CE: 1.6411 | Q-Loss: 0.0155 | Avg Steps: 5.0
# halt logit: mean=-8.634 std=3.023 max=-0.030 %>0=0.0% %>1.5=0.0%
# halt steps: mean=5.00 median=5 %step1=0.0% %never=100.0% dist={5: 45000}
#
# Validation Logs ------
#
# sup_step_1 | mean=-7.166 std=0.751 median=-7.334 %>0=0.0% %>1.5=0.0% first5=[-7.806545257568359, -8.003120422363281, -7.812079429626465, -5.816499710083008, -7.597494125366211]
# sup_step_2 | mean=-6.851 std=0.966 median=-6.859 %>0=0.0% %>1.5=0.0% first5=[-7.710794925689697, -8.093259811401367, -7.964287757873535, -6.017339706420898, -6.685355186462402]
# sup_step_3 | mean=-6.982 std=0.912 median=-7.054 %>0=0.0% %>1.5=0.0% first5=[-7.918327331542969, -8.083850860595703, -7.782444953918457, -6.0844926834106445, -6.94343376159668]
# sup_step_4 | mean=-6.974 std=0.941 median=-7.079 %>0=0.0% %>1.5=0.0% first5=[-7.980896472930908, -8.10815715789795, -7.829668998718262, -6.120283126831055, -6.876355171203613]
# sup_step_5 | mean=-6.979 std=0.942 median=-7.070 %>0=0.0% %>1.5=0.0% first5=[-7.975693702697754, -8.097834587097168, -7.848263740539551, -6.11599063873291, -6.894837856292725]
#
# Validation Accuracy: 0.08%
# validation halt steps: mean=5.00 median=5 %step1=0.0% %never=100.0% dist={5: 5000}
# Training processed epoch 1
# Training processed epoch 2
# Training processed epoch 3
# Training processed epoch 4
# Training processed epoch 5
# Training processed epoch 6
# Training processed epoch 7
# Training processed epoch 8
# Training processed epoch 9
# Training processed epoch 10
#  Training epoch 10 | CE: 0.6647 | Q-Loss: 0.2695 | Avg Steps: 5.0
# halt logit: mean=-2.642 std=0.521 max=-0.657 %>0=0.0% %>1.5=0.0%
# halt steps: mean=5.00 median=5 %step1=0.0% %never=100.0% dist={5: 45000}
#
# Validation Logs ------
#
# sup_step_1 | mean=-2.712 std=0.632 median=-2.631 %>0=0.0% %>1.5=0.0% first5=[-2.084948778152466, -2.484365701675415, -2.6126224994659424, -2.9311342239379883, -1.9398735761642456]
# sup_step_2 | mean=-2.608 std=0.522 median=-2.472 %>0=0.0% %>1.5=0.0% first5=[-2.2831809520721436, -2.5767266750335693, -2.574516773223877, -2.6979103088378906, -1.877113699913025]
# sup_step_3 | mean=-2.579 std=0.525 median=-2.440 %>0=0.0% %>1.5=0.0% first5=[-2.2223424911499023, -2.5666990280151367, -2.446160078048706, -2.6741814613342285, -1.8692739009857178]
# sup_step_4 | mean=-2.574 std=0.510 median=-2.465 %>0=0.0% %>1.5=0.0% first5=[-2.21791672706604, -2.5691142082214355, -2.4745914936065674, -2.6709463596343994, -1.8909791707992554]
# sup_step_5 | mean=-2.572 std=0.512 median=-2.472 %>0=0.0% %>1.5=0.0% first5=[-2.223959445953369, -2.5694093704223633, -2.512847661972046, -2.669135093688965, -1.8898457288742065]
#
# Validation Accuracy: 6.82%
# validation halt steps: mean=5.00 median=5 %step1=0.0% %never=100.0% dist={5: 5000}
# Training processed epoch 11
# Training processed epoch 12
# Training processed epoch 13
# Training processed epoch 14
# Training processed epoch 15
# Training processed epoch 16
# Training processed epoch 17
# Training processed epoch 18
# Training processed epoch 19
# Training processed epoch 20
#  Training epoch 20 | CE: 0.5662 | Q-Loss: 0.3253 | Avg Steps: 5.0
# halt logit: mean=-2.263 std=0.365 max=-0.502 %>0=0.0% %>1.5=0.0%
# halt steps: mean=5.00 median=5 %step1=0.0% %never=100.0% dist={5: 45000}
#
# Validation Logs ------
#
# sup_step_1 | mean=-2.334 std=0.393 median=-2.337 %>0=0.0% %>1.5=0.0% first5=[-2.3366334438323975, -2.6635348796844482, -2.4567222595214844, -2.431147813796997, -2.0545506477355957]
# sup_step_2 | mean=-2.320 std=0.321 median=-2.265 %>0=0.0% %>1.5=0.0% first5=[-2.0378315448760986, -2.747044324874878, -2.435748338699341, -2.2271511554718018, -1.9756419658660889]
# sup_step_3 | mean=-2.331 std=0.345 median=-2.286 %>0=0.0% %>1.5=0.0% first5=[-2.095231771469116, -2.6597301959991455, -2.435297727584839, -2.2184250354766846, -1.9897558689117432]
# sup_step_4 | mean=-2.326 std=0.338 median=-2.286 %>0=0.0% %>1.5=0.0% first5=[-2.100750207901001, -2.6711277961730957, -2.4358808994293213, -2.218385696411133, -1.9923285245895386]
# sup_step_5 | mean=-2.331 std=0.331 median=-2.312 %>0=0.0% %>1.5=0.0% first5=[-2.098754405975342, -2.675020456314087, -2.4357848167419434, -2.2183339595794678, -1.9922659397125244]
#
# Validation Accuracy: 8.22%
# validation halt steps: mean=5.00 median=5 %step1=0.0% %never=100.0% dist={5: 5000}
# Training processed epoch 21
# Training processed epoch 22
# Training processed epoch 23
# Training processed epoch 24
# Training processed epoch 25
# Training processed epoch 26
# Training processed epoch 27
# Training processed epoch 28
# Training processed epoch 29
# Training processed epoch 30
#  Training epoch 30 | CE: 0.4710 | Q-Loss: 0.5020 | Avg Steps: 5.0
# halt logit: mean=-1.425 std=0.410 max=0.333 %>0=0.1% %>1.5=0.0%
# halt steps: mean=4.99 median=5 %step1=0.1% %never=99.8% dist={5: 44929, 2: 24, 1: 45, 3: 2}
#
# Validation Logs ------
#
# sup_step_1 | mean=-1.466 std=0.425 median=-1.528 %>0=0.0% %>1.5=0.0% first5=[-2.2060134410858154, -1.2328577041625977, -1.788801908493042, -2.108346462249756, -1.282228708267212]
# sup_step_2 | mean=-1.458 std=0.428 median=-1.552 %>0=0.0% %>1.5=0.0% first5=[-1.987518548965454, -1.2679060697555542, -1.7330636978149414, -2.0606844425201416, -1.102455496788025]
# sup_step_3 | mean=-1.461 std=0.431 median=-1.584 %>0=0.0% %>1.5=0.0% first5=[-1.8995270729064941, -1.250793218612671, -1.7316948175430298, -2.088495969772339, -1.1130589246749878]
# sup_step_4 | mean=-1.462 std=0.430 median=-1.587 %>0=0.0% %>1.5=0.0% first5=[-1.9056832790374756, -1.243654727935791, -1.733396053314209, -2.091613292694092, -1.1233241558074951]
# sup_step_5 | mean=-1.463 std=0.431 median=-1.587 %>0=0.0% %>1.5=0.0% first5=[-1.9182795286178589, -1.2387638092041016, -1.735036849975586, -2.088014841079712, -1.1233196258544922]
#
# Validation Accuracy: 23.06%
# validation halt steps: mean=5.00 median=5 %step1=0.1% %never=99.9% dist={5: 4994, 1: 3, 2: 3}
# Training processed epoch 31
# Training processed epoch 32
# Training processed epoch 33
# Training processed epoch 34
# Training processed epoch 35
# Training processed epoch 36
# Training processed epoch 37
# Training processed epoch 38
# Training processed epoch 39
# Training processed epoch 40
#  Training epoch 40 | CE: 0.1232 | Q-Loss: 0.3643 | Avg Steps: 1.6226012793176972
# halt logit: mean=1.380 std=1.378 max=5.234 %>0=82.3% %>1.5=49.2%
# halt steps: mean=1.22 median=1 %step1=93.7% %never=5.2% dist={1: 42177, 2: 407, 5: 2352, 3: 56, 4: 8}
#
# Validation Logs ------
#
# sup_step_1 | mean=0.360 std=0.507 median=0.198 %>0=75.0% %>1.5=3.1% first5=[-0.16507190465927124, 0.19827866554260254, 0.8434929847717285, 0.4446280598640442, 0.19794738292694092]
# sup_step_2 | mean=0.436 std=0.518 median=0.302 %>0=81.2% %>1.5=3.1% first5=[-0.03177541494369507, 0.2956538200378418, 0.932320773601532, 0.5374589562416077, 0.1109929084777832]
# sup_step_3 | mean=0.441 std=0.521 median=0.275 %>0=84.4% %>1.5=3.1% first5=[-0.014618635177612305, 0.2751479148864746, 0.9070509672164917, 0.5780212879180908, 0.12667465209960938]
# sup_step_4 | mean=0.441 std=0.519 median=0.282 %>0=87.5% %>1.5=3.1% first5=[0.0029820799827575684, 0.2722287178039551, 0.90631103515625, 0.5675814747810364, 0.1195758581161499]
# sup_step_5 | mean=0.441 std=0.520 median=0.284 %>0=84.4% %>1.5=3.1% first5=[-0.0016791224479675293, 0.2745025157928467, 0.9071885943412781, 0.5657962560653687, 0.1200607419013977]
#
# Validation Accuracy: 66.80%
# validation halt steps: mean=1.63 median=1 %step1=81.0% %never=14.3% dist={4: 6, 1: 4048, 5: 713, 2: 209, 3: 24}
# Training processed epoch 41
# Training processed epoch 42
# Training processed epoch 43
# Training processed epoch 44
# Training processed epoch 45
# Training processed epoch 46
# Training processed epoch 47
# Training processed epoch 48
# Training processed epoch 49
# Training processed epoch 50
#  Training epoch 50 | CE: 0.0176 | Q-Loss: 0.0915 | Avg Steps: 1.0007107320540156
# halt logit: mean=4.455 std=1.093 max=9.381 %>0=100.0% %>1.5=99.8%
# halt steps: mean=1.00 median=1 %step1=100.0% %never=0.0% dist={1: 44999, 2: 1}
#
# Validation Logs ------
#
# sup_step_1 | mean=3.877 std=0.786 median=3.769 %>0=100.0% %>1.5=100.0% first5=[4.754761695861816, 4.070260047912598, 4.41501522064209, 4.294322490692139, 5.796582221984863]
#
# Validation Accuracy: 96.86%
# validation halt steps: mean=1.00 median=1 %step1=100.0% %never=0.0% dist={1: 5000}
# Training processed epoch 51
# Training processed epoch 52
# Training processed epoch 53
# Training processed epoch 54
# Training processed epoch 55
# Training processed epoch 56
# Training processed epoch 57
# Training processed epoch 58
# Training processed epoch 59
# Training processed epoch 60
#  Training epoch 60 | CE: 0.0108 | Q-Loss: 0.0472 | Avg Steps: 1.0
# halt logit: mean=5.254 std=1.140 max=10.267 %>0=100.0% %>1.5=100.0%
# halt steps: mean=1.00 median=1 %step1=100.0% %never=0.0% dist={1: 45000}
#
# Validation Logs ------
#
# sup_step_1 | mean=5.392 std=1.096 median=5.298 %>0=100.0% %>1.5=100.0% first5=[4.879387378692627, 4.883761405944824, 6.491767406463623, 6.181184768676758, 8.012344360351562]
#
# Validation Accuracy: 99.12%
# validation halt steps: mean=1.00 median=1 %step1=100.0% %never=0.0% dist={1: 5000}
# Training processed epoch 61
# Training processed epoch 62
# Training processed epoch 63
# Training processed epoch 64
# Training processed epoch 65
# Training processed epoch 66
# Training processed epoch 67
# Training processed epoch 68
# Training processed epoch 69
# Training processed epoch 70
#  Training epoch 70 | CE: 0.0060 | Q-Loss: 0.0286 | Avg Steps: 1.0007107320540156
# halt logit: mean=6.188 std=1.317 max=11.589 %>0=100.0% %>1.5=99.9%
# halt steps: mean=1.00 median=1 %step1=100.0% %never=0.0% dist={1: 44999, 2: 1}
#
# Validation Logs ------
#
# sup_step_1 | mean=5.618 std=0.979 median=5.423 %>0=100.0% %>1.5=100.0% first5=[4.838068008422852, 4.769897937774658, 7.065728664398193, 6.902232646942139, 6.815415859222412]
#
# Validation Accuracy: 98.88%
# validation halt steps: mean=1.00 median=1 %step1=100.0% %never=0.0% dist={1: 5000}
# Training processed epoch 71
# Training processed epoch 72
# Training processed epoch 73
# Training processed epoch 74
# Training processed epoch 75
# Training processed epoch 76
# Training processed epoch 77
# Training processed epoch 78
# Training processed epoch 79
# Training processed epoch 80
#  Training epoch 80 | CE: 0.0098 | Q-Loss: 0.0717 | Avg Steps: 1.0
# halt logit: mean=5.183 std=1.555 max=11.000 %>0=100.0% %>1.5=99.8%
# halt steps: mean=1.00 median=1 %step1=100.0% %never=0.0% dist={1: 45000}
#
# Validation Logs ------
#
# sup_step_1 | mean=4.385 std=0.988 median=4.247 %>0=100.0% %>1.5=100.0% first5=[5.260982990264893, 4.014128684997559, 5.488131523132324, 6.388586521148682, 4.99846887588501]
#
# Validation Accuracy: 98.38%
# validation halt steps: mean=1.00 median=1 %step1=100.0% %never=0.0% dist={1: 5000}
# Training processed epoch 81
# Training processed epoch 82
# Training processed epoch 83
# Training processed epoch 84
# Training processed epoch 85
# Training processed epoch 86
# Training processed epoch 87
# Training processed epoch 88
# Training processed epoch 89
# Training processed epoch 90
#  Training epoch 90 | CE: 0.0142 | Q-Loss: 0.0704 | Avg Steps: 1.0099502487562189
# halt logit: mean=4.834 std=1.636 max=10.342 %>0=100.0% %>1.5=97.4%
# halt steps: mean=1.00 median=1 %step1=100.0% %never=0.0% dist={1: 44993, 2: 4, 5: 2, 3: 1}
#
# Validation Logs ------
#
# sup_step_1 | mean=6.331 std=1.173 median=6.457 %>0=100.0% %>1.5=100.0% first5=[7.0383830070495605, 4.649927139282227, 7.8098225593566895, 7.7703986167907715, 6.34013032913208]
#
# Validation Accuracy: 99.46%
# validation halt steps: mean=1.00 median=1 %step1=100.0% %never=0.0% dist={1: 5000}
# Training processed epoch 91
# Training processed epoch 92
# Training processed epoch 93
# Training processed epoch 94
# Training processed epoch 95
# Training processed epoch 96
# Training processed epoch 97
# Training processed epoch 98
# Training processed epoch 99

# %%
## t-1.5

# Config: n_sup=5, halt > 1.5, c=0.1, T=3, 100 epochs
# Prediction: near-identical to halt > 0. With a 0/1 target the equilibrium logit diverges
# per sample, so a fixed threshold in between should not matter (threshold-insensitivity test).
# Log: training-logs/binary-em-halt-1.5.txt

HALT_THRESHOLD = 1.5
model_training_and_validation_with_mask(c=0.1, T=3, n_sup=5, HALT_THRESHOLD = HALT_THRESHOLD)
# Out:
# PAD_TOKEN:  11
# Training Logs ------
#
# Training processed epoch 0
#  Training epoch 0 | CE: 1.6255 | Q-Loss: 0.0200 | Avg Steps: 5.0
# halt logit: mean=-7.781 std=2.765 max=0.047 %>0=0.1% %>1.5=0.0%
# halt steps: mean=5.00 median=5 %step1=0.0% %never=100.0% dist={5: 45000}
#
# Validation Logs ------
#
# sup_step_1 | mean=-7.339 std=0.990 median=-7.234 %>0=0.0% %>1.5=0.0% first5=[-8.277438163757324, -7.855916976928711, -8.353809356689453, -6.0830206871032715, -6.814644813537598]
# sup_step_2 | mean=-7.017 std=1.278 median=-6.792 %>0=0.0% %>1.5=0.0% first5=[-8.082808494567871, -8.384020805358887, -8.963379859924316, -6.521524429321289, -6.684652328491211]
# sup_step_3 | mean=-7.118 std=1.173 median=-6.985 %>0=0.0% %>1.5=0.0% first5=[-8.404810905456543, -8.205537796020508, -8.79327392578125, -6.409891128540039, -6.667150497436523]
# sup_step_4 | mean=-7.158 std=1.188 median=-6.979 %>0=0.0% %>1.5=0.0% first5=[-8.392669677734375, -8.2230863571167, -8.89934253692627, -6.383816719055176, -6.66721248626709]
# sup_step_5 | mean=-7.129 std=1.203 median=-6.974 %>0=0.0% %>1.5=0.0% first5=[-8.35365104675293, -8.295146942138672, -8.861109733581543, -6.411214828491211, -6.667243957519531]
#
# Validation Accuracy: 0.06%
# validation halt steps: mean=5.00 median=5 %step1=0.0% %never=100.0% dist={5: 5000}
# Training processed epoch 1
# Training processed epoch 2
# Training processed epoch 3
# Training processed epoch 4
# Training processed epoch 5
# Training processed epoch 6
# Training processed epoch 7
# Training processed epoch 8
# Training processed epoch 9
# Training processed epoch 10
#  Training epoch 10 | CE: 0.6819 | Q-Loss: 0.2585 | Avg Steps: 5.0
# halt logit: mean=-2.711 std=0.569 max=-0.184 %>0=0.0% %>1.5=0.0%
# halt steps: mean=5.00 median=5 %step1=0.0% %never=100.0% dist={5: 45000}
#
# Validation Logs ------
#
# sup_step_1 | mean=-2.596 std=0.599 median=-2.528 %>0=0.0% %>1.5=0.0% first5=[-2.1096112728118896, -2.3701517581939697, -2.6870734691619873, -2.3596057891845703, -2.251922130584717]
# sup_step_2 | mean=-2.633 std=0.565 median=-2.767 %>0=0.0% %>1.5=0.0% first5=[-2.154784917831421, -2.579160213470459, -2.9501733779907227, -2.511482000350952, -2.2058801651000977]
# sup_step_3 | mean=-2.572 std=0.597 median=-2.619 %>0=0.0% %>1.5=0.0% first5=[-2.157517671585083, -2.57723331451416, -2.944658041000366, -2.535482406616211, -2.2191641330718994]
# sup_step_4 | mean=-2.585 std=0.591 median=-2.640 %>0=0.0% %>1.5=0.0% first5=[-2.151498317718506, -2.5794553756713867, -2.972714424133301, -2.5391807556152344, -2.2282912731170654]
# sup_step_5 | mean=-2.607 std=0.568 median=-2.706 %>0=0.0% %>1.5=0.0% first5=[-2.1525182723999023, -2.559232234954834, -2.9762930870056152, -2.543015718460083, -2.225456714630127]
#
# Validation Accuracy: 6.86%
# validation halt steps: mean=5.00 median=5 %step1=0.0% %never=100.0% dist={5: 5000}
# Training processed epoch 11
# Training processed epoch 12
# Training processed epoch 13
# Training processed epoch 14
# Training processed epoch 15
# Training processed epoch 16
# Training processed epoch 17
# Training processed epoch 18
# Training processed epoch 19
# Training processed epoch 20
#  Training epoch 20 | CE: 0.5514 | Q-Loss: 0.3359 | Avg Steps: 5.0
# halt logit: mean=-2.202 std=0.345 max=-0.773 %>0=0.0% %>1.5=0.0%
# halt steps: mean=5.00 median=5 %step1=0.0% %never=100.0% dist={5: 45000}
#
# Validation Logs ------
#
# sup_step_1 | mean=-2.306 std=0.471 median=-2.249 %>0=0.0% %>1.5=0.0% first5=[-2.7227156162261963, -2.0898871421813965, -2.5489516258239746, -3.303244113922119, -2.1877171993255615]
# sup_step_2 | mean=-2.345 std=0.437 median=-2.339 %>0=0.0% %>1.5=0.0% first5=[-2.6548657417297363, -2.213358163833618, -2.452805995941162, -3.063619613647461, -2.190927267074585]
# sup_step_3 | mean=-2.338 std=0.437 median=-2.382 %>0=0.0% %>1.5=0.0% first5=[-2.630419969558716, -2.190572738647461, -2.4569408893585205, -3.0434069633483887, -2.195495128631592]
# sup_step_4 | mean=-2.336 std=0.439 median=-2.386 %>0=0.0% %>1.5=0.0% first5=[-2.627769708633423, -2.1473677158355713, -2.458829164505005, -3.0630085468292236, -2.2018790245056152]
# sup_step_5 | mean=-2.334 std=0.439 median=-2.374 %>0=0.0% %>1.5=0.0% first5=[-2.6343538761138916, -2.145625114440918, -2.4580328464508057, -3.061779022216797, -2.2034146785736084]
#
# Validation Accuracy: 9.22%
# validation halt steps: mean=5.00 median=5 %step1=0.0% %never=100.0% dist={5: 5000}
# Training processed epoch 21
# Training processed epoch 22
# Training processed epoch 23
# Training processed epoch 24
# Training processed epoch 25
# Training processed epoch 26
# Training processed epoch 27
# Training processed epoch 28
# Training processed epoch 29
# Training processed epoch 30
#  Training epoch 30 | CE: 0.4984 | Q-Loss: 0.4421 | Avg Steps: 5.0
# halt logit: mean=-1.696 std=0.346 max=-0.298 %>0=0.0% %>1.5=0.0%
# halt steps: mean=5.00 median=5 %step1=0.0% %never=100.0% dist={5: 45000}
#
# Validation Logs ------
#
# sup_step_1 | mean=-1.609 std=0.320 median=-1.609 %>0=0.0% %>1.5=0.0% first5=[-1.8291329145431519, -1.0618479251861572, -1.56206476688385, -2.1239571571350098, -1.468608021736145]
# sup_step_2 | mean=-1.636 std=0.317 median=-1.660 %>0=0.0% %>1.5=0.0% first5=[-1.8345098495483398, -1.149651288986206, -1.4816670417785645, -1.8712102174758911, -1.4833749532699585]
# sup_step_3 | mean=-1.632 std=0.306 median=-1.643 %>0=0.0% %>1.5=0.0% first5=[-1.818202018737793, -1.1295987367630005, -1.4695544242858887, -1.8459205627441406, -1.4690648317337036]
# sup_step_4 | mean=-1.631 std=0.305 median=-1.644 %>0=0.0% %>1.5=0.0% first5=[-1.815495491027832, -1.1265177726745605, -1.4697543382644653, -1.854421854019165, -1.4656354188919067]
# sup_step_5 | mean=-1.630 std=0.308 median=-1.644 %>0=0.0% %>1.5=0.0% first5=[-1.8180745840072632, -1.1259835958480835, -1.4702187776565552, -1.852012276649475, -1.4647830724716187]
#
# Validation Accuracy: 16.36%
# validation halt steps: mean=5.00 median=5 %step1=0.0% %never=100.0% dist={5: 5000}
# Training processed epoch 31
# Training processed epoch 32
# Training processed epoch 33
# Training processed epoch 34
# Training processed epoch 35
# Training processed epoch 36
# Training processed epoch 37
# Training processed epoch 38
# Training processed epoch 39
# Training processed epoch 40
#  Training epoch 40 | CE: 0.1610 | Q-Loss: 0.4122 | Avg Steps: 4.909026297085998
# halt logit: mean=1.865 std=0.659 max=4.327 %>0=99.3% %>1.5=72.7%
# halt steps: mean=2.03 median=1 %step1=67.6% %never=23.0% dist={1: 30402, 5: 10361, 2: 3725, 3: 448, 4: 64}
#
# Validation Logs ------
#
# sup_step_1 | mean=2.017 std=0.633 median=2.026 %>0=100.0% %>1.5=75.0% first5=[2.7106986045837402, 0.5152283906936646, 3.315119743347168, 2.542289972305298, 2.3419599533081055]
# sup_step_2 | mean=2.143 std=0.645 median=2.129 %>0=100.0% %>1.5=84.4% first5=[2.6231420040130615, 0.8623107671737671, 3.299652576446533, 2.5784013271331787, 2.4347846508026123]
# sup_step_3 | mean=2.143 std=0.624 median=2.079 %>0=100.0% %>1.5=84.4% first5=[2.6040377616882324, 0.9236893653869629, 3.25225567817688, 2.5631678104400635, 2.432199239730835]
# sup_step_4 | mean=2.135 std=0.620 median=2.074 %>0=100.0% %>1.5=84.4% first5=[2.611006498336792, 0.876116156578064, 3.2444918155670166, 2.5485470294952393, 2.423051357269287]
# sup_step_5 | mean=2.139 std=0.623 median=2.079 %>0=100.0% %>1.5=84.4% first5=[2.6109509468078613, 0.8818914294242859, 3.2496113777160645, 2.552692174911499, 2.423466920852661]
#
# Validation Accuracy: 88.08%
# validation halt steps: mean=1.48 median=1 %step1=84.1% %never=10.4% dist={1: 4203, 5: 519, 2: 222, 3: 47, 4: 9}
# Training processed epoch 41
# Training processed epoch 42
# Training processed epoch 43
# Training processed epoch 44
# Training processed epoch 45
# Training processed epoch 46
# Training processed epoch 47
# Training processed epoch 48
# Training processed epoch 49
# Training processed epoch 50
#  Training epoch 50 | CE: 0.1873 | Q-Loss: 0.3747 | Avg Steps: 4.633262260127932
# halt logit: mean=2.039 std=0.773 max=4.505 %>0=99.1% %>1.5=76.9%
# halt steps: mean=1.81 median=1 %step1=74.6% %never=18.2% dist={1: 33583, 3: 300, 5: 8201, 2: 2881, 4: 35}
#
# Validation Logs ------
#
# sup_step_1 | mean=2.299 std=0.654 median=2.152 %>0=100.0% %>1.5=90.6% first5=[3.4198789596557617, 1.6325573921203613, 3.5788674354553223, 2.0288631916046143, 2.562922477722168]
# sup_step_2 | mean=2.420 std=0.627 median=2.449 %>0=100.0% %>1.5=96.9% first5=[3.0331625938415527, 1.9655876159667969, 3.119060516357422, 1.913204550743103, 2.7868313789367676]
# sup_step_3 | mean=2.412 std=0.628 median=2.423 %>0=100.0% %>1.5=93.8% first5=[3.050644636154175, 2.0346055030822754, 3.3122851848602295, 1.9669749736785889, 2.794555187225342]
# sup_step_4 | mean=2.409 std=0.624 median=2.406 %>0=100.0% %>1.5=93.8% first5=[3.0654077529907227, 2.0449414253234863, 3.2755661010742188, 1.9496601819992065, 2.793708324432373]
# sup_step_5 | mean=2.413 std=0.624 median=2.410 %>0=100.0% %>1.5=93.8% first5=[3.0601322650909424, 2.0486207008361816, 3.2776663303375244, 1.9509599208831787, 2.793517589569092]
#
# Validation Accuracy: 86.14%
# validation halt steps: mean=1.23 median=1 %step1=91.6% %never=4.7% dist={1: 4579, 5: 235, 2: 156, 3: 25, 4: 5}
# Training processed epoch 51
# Training processed epoch 52
# Training processed epoch 53
# Training processed epoch 54
# Training processed epoch 55
# Training processed epoch 56
# Training processed epoch 57
# Training processed epoch 58
# Training processed epoch 59
# Training processed epoch 60
#  Training epoch 60 | CE: 0.1206 | Q-Loss: 0.3260 | Avg Steps: 4.384506041222459
# halt logit: mean=2.274 std=0.713 max=4.986 %>0=99.9% %>1.5=85.4%
# halt steps: mean=1.49 median=1 %step1=84.6% %never=11.0% dist={1: 38052, 5: 4929, 2: 1845, 3: 162, 4: 12}
#
# Validation Logs ------
#
# sup_step_1 | mean=2.587 std=0.552 median=2.597 %>0=100.0% %>1.5=96.9% first5=[2.4498000144958496, 2.6873347759246826, 2.9462554454803467, 2.3145744800567627, 3.809854507446289]
# sup_step_2 | mean=2.714 std=0.533 median=2.670 %>0=100.0% %>1.5=100.0% first5=[2.6645920276641846, 3.0654780864715576, 2.6733686923980713, 2.3397676944732666, 4.1530351638793945]
#
# Validation Accuracy: 92.32%
# validation halt steps: mean=1.07 median=1 %step1=96.6% %never=1.0% dist={1: 4832, 2: 111, 5: 52, 3: 5}
# Training processed epoch 61
# Training processed epoch 62
# Training processed epoch 63
# Training processed epoch 64
# Training processed epoch 65
# Training processed epoch 66
# Training processed epoch 67
# Training processed epoch 68
# Training processed epoch 69
# Training processed epoch 70
#  Training epoch 70 | CE: 0.1728 | Q-Loss: 0.3335 | Avg Steps: 4.565031982942431
# halt logit: mean=2.245 std=0.739 max=4.586 %>0=99.2% %>1.5=85.1%
# halt steps: mean=1.51 median=1 %step1=84.3% %never=11.7% dist={1: 37938, 5: 5251, 2: 1645, 3: 140, 4: 26}
#
# Validation Logs ------
#
# sup_step_1 | mean=2.387 std=0.756 median=2.576 %>0=100.0% %>1.5=84.4% first5=[2.7108092308044434, 3.273198366165161, 2.909418821334839, 1.9819930791854858, 3.368758201599121]
# sup_step_2 | mean=2.499 std=0.769 median=2.578 %>0=100.0% %>1.5=87.5% first5=[2.4914233684539795, 3.5864570140838623, 2.878689765930176, 2.0091733932495117, 3.89652419090271]
# sup_step_3 | mean=2.448 std=0.789 median=2.575 %>0=100.0% %>1.5=87.5% first5=[1.9538789987564087, 3.608853578567505, 2.8788468837738037, 1.9598910808563232, 3.987229824066162]
# sup_step_4 | mean=2.458 std=0.772 median=2.574 %>0=100.0% %>1.5=87.5% first5=[2.382807731628418, 3.563326120376587, 2.885267496109009, 1.9638960361480713, 3.9584197998046875]
# sup_step_5 | mean=2.466 std=0.776 median=2.573 %>0=100.0% %>1.5=87.5% first5=[2.451704263687134, 3.555511951446533, 2.8868443965911865, 1.9702390432357788, 3.9607508182525635]
#
# Validation Accuracy: 79.48%
# validation halt steps: mean=1.28 median=1 %step1=90.5% %never=6.1% dist={1: 4526, 2: 159, 5: 307, 3: 8}
# Training processed epoch 71
# Training processed epoch 72
# Training processed epoch 73
# Training processed epoch 74
# Training processed epoch 75
# Training processed epoch 76
# Training processed epoch 77
# Training processed epoch 78
# Training processed epoch 79
# Training processed epoch 80
#  Training epoch 80 | CE: 0.1327 | Q-Loss: 0.3194 | Avg Steps: 4.442786069651741
# halt logit: mean=2.332 std=0.768 max=5.568 %>0=99.8% %>1.5=86.0%
# halt steps: mean=1.47 median=1 %step1=85.7% %never=10.9% dist={1: 38566, 5: 4904, 2: 1397, 3: 103, 4: 30}
#
# Validation Logs ------
#
# sup_step_1 | mean=2.465 std=0.803 median=2.233 %>0=100.0% %>1.5=90.6% first5=[3.5274367332458496, 1.8906892538070679, 3.2667651176452637, 3.4092884063720703, 2.5743446350097656]
# sup_step_2 | mean=2.580 std=0.807 median=2.288 %>0=100.0% %>1.5=90.6% first5=[3.395369291305542, 1.9082273244857788, 3.3999569416046143, 3.4962596893310547, 2.7178406715393066]
# sup_step_3 | mean=2.550 std=0.783 median=2.233 %>0=100.0% %>1.5=90.6% first5=[3.282710313796997, 1.9188095331192017, 3.3977136611938477, 3.44077205657959, 2.7198891639709473]
# sup_step_4 | mean=2.546 std=0.777 median=2.233 %>0=100.0% %>1.5=90.6% first5=[3.299506187438965, 1.9169965982437134, 3.3939688205718994, 3.436368465423584, 2.7197141647338867]
# sup_step_5 | mean=2.542 std=0.770 median=2.233 %>0=100.0% %>1.5=93.8% first5=[3.3039417266845703, 1.9171470403671265, 3.393228054046631, 3.43753981590271, 2.719963550567627]
#
# Validation Accuracy: 90.64%
# validation halt steps: mean=1.18 median=1 %step1=94.3% %never=4.1% dist={1: 4714, 5: 207, 2: 74, 3: 5}
# Training processed epoch 81
# Training processed epoch 82
# Training processed epoch 83
# Training processed epoch 84
# Training processed epoch 85
# Training processed epoch 86
# Training processed epoch 87
# Training processed epoch 88
# Training processed epoch 89
# Training processed epoch 90
#  Training epoch 90 | CE: 0.0833 | Q-Loss: 0.2302 | Avg Steps: 3.037668798862829
# halt logit: mean=2.611 std=1.438 max=8.786 %>0=99.1% %>1.5=82.7%
# halt steps: mean=1.40 median=1 %step1=88.5% %never=9.5% dist={1: 39827, 3: 78, 2: 817, 5: 4263, 4: 15}
#
# Validation Logs ------
#
# sup_step_1 | mean=2.128 std=0.633 median=2.042 %>0=100.0% %>1.5=84.4% first5=[3.2446107864379883, 1.584176778793335, 2.711399555206299, 2.8446290493011475, 2.7041127681732178]
# sup_step_2 | mean=2.227 std=0.639 median=2.130 %>0=100.0% %>1.5=84.4% first5=[3.1763925552368164, 1.6095629930496216, 2.8749589920043945, 2.815507411956787, 2.932089328765869]
# sup_step_3 | mean=2.205 std=0.622 median=2.115 %>0=100.0% %>1.5=84.4% first5=[3.098672866821289, 1.6116183996200562, 2.916165828704834, 2.7763559818267822, 2.9474403858184814]
# sup_step_4 | mean=2.202 std=0.620 median=2.115 %>0=100.0% %>1.5=84.4% first5=[3.098803997039795, 1.608774185180664, 2.9239661693573, 2.7808170318603516, 2.9483587741851807]
# sup_step_5 | mean=2.206 std=0.624 median=2.115 %>0=100.0% %>1.5=84.4% first5=[3.1018691062927246, 1.608974814414978, 2.921140193939209, 2.7832727432250977, 2.9482569694519043]
#
# Validation Accuracy: 87.56%
# validation halt steps: mean=1.42 median=1 %step1=87.9% %never=10.0% dist={1: 4393, 5: 502, 2: 98, 3: 7}
# Training processed epoch 91
# Training processed epoch 92
# Training processed epoch 93
# Training processed epoch 94
# Training processed epoch 95
# Training processed epoch 96
# Training processed epoch 97
# Training processed epoch 98
# Training processed epoch 99

# %%
## t-3.0

# Config: n_sup=5, halt > 3.0, c=0.1, T=3, 100 epochs
# Prediction: same as t-1.5 -- threshold-insensitive.
# Log: training-logs/binary-em-halt-3.0.txt

HALT_THRESHOLD = 3.0
model_training_and_validation_with_mask(c=0.1, T=3, n_sup=5, HALT_THRESHOLD = HALT_THRESHOLD)
# Out:
# PAD_TOKEN:  11
# Training Logs ------
#
# Training processed epoch 0
#  Training epoch 0 | CE: 1.6359 | Q-Loss: 0.0190 | Avg Steps: 5.0
# halt logit: mean=-7.495 std=2.398 max=0.008 %>0=0.0% %>1.5=0.0%
# halt steps: mean=5.00 median=5 %step1=0.0% %never=100.0% dist={5: 45000}
#
# Validation Logs ------
#
# sup_step_1 | mean=-7.797 std=1.107 median=-7.894 %>0=0.0% %>1.5=0.0% first5=[-9.177449226379395, -7.641042709350586, -9.385202407836914, -6.172032833099365, -8.024401664733887]
# sup_step_2 | mean=-7.443 std=1.129 median=-7.565 %>0=0.0% %>1.5=0.0% first5=[-8.732939720153809, -8.344908714294434, -9.289162635803223, -6.140016555786133, -7.815437316894531]
# sup_step_3 | mean=-7.565 std=1.135 median=-7.801 %>0=0.0% %>1.5=0.0% first5=[-8.896319389343262, -8.439908981323242, -9.049473762512207, -6.155395984649658, -7.779675483703613]
# sup_step_4 | mean=-7.518 std=1.119 median=-7.739 %>0=0.0% %>1.5=0.0% first5=[-8.84854507446289, -8.447712898254395, -9.012490272521973, -6.1540327072143555, -7.827483177185059]
# sup_step_5 | mean=-7.530 std=1.117 median=-7.724 %>0=0.0% %>1.5=0.0% first5=[-8.853788375854492, -8.44753360748291, -9.017027854919434, -6.154189109802246, -7.814789772033691]
#
# Validation Accuracy: 0.10%
# validation halt steps: mean=5.00 median=5 %step1=0.0% %never=100.0% dist={5: 5000}
# Training processed epoch 1
# Training processed epoch 2
# Training processed epoch 3
# Training processed epoch 4
# Training processed epoch 5
# Training processed epoch 6
# Training processed epoch 7
# Training processed epoch 8
# Training processed epoch 9
# Training processed epoch 10
#  Training epoch 10 | CE: 0.6654 | Q-Loss: 0.2644 | Avg Steps: 5.0
# halt logit: mean=-2.674 std=0.536 max=-0.668 %>0=0.0% %>1.5=0.0%
# halt steps: mean=5.00 median=5 %step1=0.0% %never=100.0% dist={5: 45000}
#
# Validation Logs ------
#
# sup_step_1 | mean=-2.792 std=0.578 median=-2.747 %>0=0.0% %>1.5=0.0% first5=[-2.5360846519470215, -2.5425620079040527, -3.8327102661132812, -2.3552329540252686, -2.4987447261810303]
# sup_step_2 | mean=-2.645 std=0.476 median=-2.569 %>0=0.0% %>1.5=0.0% first5=[-2.38736891746521, -2.873467206954956, -3.197126865386963, -2.146314859390259, -2.452176809310913]
# sup_step_3 | mean=-2.644 std=0.476 median=-2.587 %>0=0.0% %>1.5=0.0% first5=[-2.441302537918091, -2.7952165603637695, -3.26106595993042, -2.2104504108428955, -2.4976024627685547]
# sup_step_4 | mean=-2.656 std=0.463 median=-2.596 %>0=0.0% %>1.5=0.0% first5=[-2.4529290199279785, -2.7804932594299316, -3.209170341491699, -2.1986172199249268, -2.5253593921661377]
# sup_step_5 | mean=-2.659 std=0.461 median=-2.615 %>0=0.0% %>1.5=0.0% first5=[-2.452219247817993, -2.7802443504333496, -3.2362070083618164, -2.196981430053711, -2.5172483921051025]
#
# Validation Accuracy: 7.12%
# validation halt steps: mean=5.00 median=5 %step1=0.0% %never=100.0% dist={5: 5000}
# Training processed epoch 11
# Training processed epoch 12
# Training processed epoch 13
# Training processed epoch 14
# Training processed epoch 15
# Training processed epoch 16
# Training processed epoch 17
# Training processed epoch 18
# Training processed epoch 19
# Training processed epoch 20
#  Training epoch 20 | CE: 0.5525 | Q-Loss: 0.3331 | Avg Steps: 5.0
# halt logit: mean=-2.220 std=0.357 max=-0.578 %>0=0.0% %>1.5=0.0%
# halt steps: mean=5.00 median=5 %step1=0.0% %never=100.0% dist={5: 45000}
#
# Validation Logs ------
#
# sup_step_1 | mean=-2.340 std=0.307 median=-2.348 %>0=0.0% %>1.5=0.0% first5=[-2.553859233856201, -2.287095546722412, -2.617882013320923, -2.4516963958740234, -2.7096760272979736]
# sup_step_2 | mean=-2.362 std=0.284 median=-2.418 %>0=0.0% %>1.5=0.0% first5=[-2.4557628631591797, -2.325557231903076, -2.6223816871643066, -2.3757481575012207, -2.5334486961364746]
# sup_step_3 | mean=-2.354 std=0.284 median=-2.385 %>0=0.0% %>1.5=0.0% first5=[-2.437710762023926, -2.313854217529297, -2.6056876182556152, -2.3803491592407227, -2.4625959396362305]
# sup_step_4 | mean=-2.354 std=0.284 median=-2.391 %>0=0.0% %>1.5=0.0% first5=[-2.448164463043213, -2.3080639839172363, -2.6017343997955322, -2.3911170959472656, -2.477410316467285]
# sup_step_5 | mean=-2.352 std=0.283 median=-2.389 %>0=0.0% %>1.5=0.0% first5=[-2.4460108280181885, -2.308405876159668, -2.602400779724121, -2.3887779712677, -2.488682508468628]
#
# Validation Accuracy: 8.36%
# validation halt steps: mean=5.00 median=5 %step1=0.0% %never=100.0% dist={5: 5000}
# Training processed epoch 21
# Training processed epoch 22
# Training processed epoch 23
# Training processed epoch 24
# Training processed epoch 25
# Training processed epoch 26
# Training processed epoch 27
# Training processed epoch 28
# Training processed epoch 29
# Training processed epoch 30
#  Training epoch 30 | CE: 0.5253 | Q-Loss: 0.3705 | Avg Steps: 5.0
# halt logit: mean=-2.025 std=0.321 max=-0.401 %>0=0.0% %>1.5=0.0%
# halt steps: mean=5.00 median=5 %step1=0.0% %never=100.0% dist={5: 45000}
#
# Validation Logs ------
#
# sup_step_1 | mean=-1.982 std=0.328 median=-1.962 %>0=0.0% %>1.5=0.0% first5=[-2.3014912605285645, -1.9732550382614136, -2.440025568008423, -1.9846714735031128, -1.9433698654174805]
# sup_step_2 | mean=-1.983 std=0.320 median=-1.995 %>0=0.0% %>1.5=0.0% first5=[-2.297632932662964, -1.8779116868972778, -2.4132919311523438, -1.9708551168441772, -2.1357531547546387]
# sup_step_3 | mean=-1.975 std=0.325 median=-2.019 %>0=0.0% %>1.5=0.0% first5=[-2.29473876953125, -1.8357033729553223, -2.419755220413208, -1.9491887092590332, -2.057966947555542]
# sup_step_4 | mean=-1.975 std=0.325 median=-2.013 %>0=0.0% %>1.5=0.0% first5=[-2.2910773754119873, -1.8282533884048462, -2.420790195465088, -1.9559528827667236, -2.0637927055358887]
# sup_step_5 | mean=-1.975 std=0.326 median=-2.013 %>0=0.0% %>1.5=0.0% first5=[-2.2910332679748535, -1.8297196626663208, -2.4207215309143066, -1.9586814641952515, -2.0679891109466553]
#
# Validation Accuracy: 9.36%
# validation halt steps: mean=5.00 median=5 %step1=0.0% %never=100.0% dist={5: 5000}
# Training processed epoch 31
# Training processed epoch 32
# Training processed epoch 33
# Training processed epoch 34
# Training processed epoch 35
# Training processed epoch 36
# Training processed epoch 37
# Training processed epoch 38
# Training processed epoch 39
# Training processed epoch 40
#  Training epoch 40 | CE: 0.1183 | Q-Loss: 0.3974 | Avg Steps: 5.0
# halt logit: mean=1.934 std=0.757 max=4.437 %>0=98.4% %>1.5=75.0%
# halt steps: mean=4.72 median=5 %step1=3.6% %never=91.8% dist={5: 41290, 2: 1875, 1: 1636, 4: 28, 3: 171}
#
# Validation Logs ------
#
# sup_step_1 | mean=2.026 std=0.705 median=2.063 %>0=100.0% %>1.5=81.2% first5=[2.211616039276123, 1.4225339889526367, 1.655608892440796, 1.6170941591262817, 2.9641730785369873]
# sup_step_2 | mean=2.172 std=0.663 median=2.310 %>0=100.0% %>1.5=78.1% first5=[2.339477300643921, 1.3851535320281982, 1.3394713401794434, 1.845311164855957, 2.941776990890503]
# sup_step_3 | mean=2.171 std=0.660 median=2.216 %>0=100.0% %>1.5=78.1% first5=[2.396557092666626, 1.4593534469604492, 1.3772673606872559, 1.8089146614074707, 2.944085121154785]
# sup_step_4 | mean=2.156 std=0.654 median=2.215 %>0=100.0% %>1.5=78.1% first5=[2.379626512527466, 1.413198709487915, 1.3868703842163086, 1.8019449710845947, 2.945884943008423]
# sup_step_5 | mean=2.152 std=0.659 median=2.220 %>0=100.0% %>1.5=78.1% first5=[2.376675605773926, 1.4117110967636108, 1.3733819723129272, 1.8041422367095947, 2.9471561908721924]
#
# Validation Accuracy: 89.68%
# validation halt steps: mean=4.71 median=5 %step1=5.1% %never=91.7% dist={5: 4583, 1: 253, 3: 23, 2: 136, 4: 5}
# Training processed epoch 41
# Training processed epoch 42
# Training processed epoch 43
# Training processed epoch 44
# Training processed epoch 45
# Training processed epoch 46
# Training processed epoch 47
# Training processed epoch 48
# Training processed epoch 49
# Training processed epoch 50
#  Training epoch 50 | CE: 0.0859 | Q-Loss: 0.2695 | Avg Steps: 5.0
# halt logit: mean=2.775 std=0.959 max=5.753 %>0=99.3% %>1.5=89.9%
# halt steps: mean=3.15 median=5 %step1=36.4% %never=50.1% dist={5: 22542, 1: 16387, 2: 5495, 4: 66, 3: 510}
#
# Validation Logs ------
#
# sup_step_1 | mean=2.949 std=0.786 median=2.968 %>0=100.0% %>1.5=93.8% first5=[3.5587308406829834, 3.1325836181640625, 2.931215763092041, 3.058063268661499, 4.13117790222168]
# sup_step_2 | mean=3.158 std=0.728 median=3.104 %>0=100.0% %>1.5=100.0% first5=[3.752048969268799, 3.0670042037963867, 2.823291301727295, 3.2406067848205566, 4.329914569854736]
# sup_step_3 | mean=3.162 std=0.707 median=3.147 %>0=100.0% %>1.5=100.0% first5=[3.662559986114502, 3.232041835784912, 2.7485861778259277, 3.236018657684326, 4.234313011169434]
# sup_step_4 | mean=3.154 std=0.713 median=3.154 %>0=100.0% %>1.5=100.0% first5=[3.6500966548919678, 3.179994583129883, 2.829763889312744, 3.1543095111846924, 4.288890361785889]
# sup_step_5 | mean=3.146 std=0.713 median=3.151 %>0=100.0% %>1.5=100.0% first5=[3.653499126434326, 3.167430877685547, 2.7315802574157715, 3.158149242401123, 4.27070951461792]
#
# Validation Accuracy: 94.10%
# validation halt steps: mean=2.81 median=2 %step1=43.9% %never=41.0% dist={1: 2197, 5: 2051, 2: 659, 3: 84, 4: 9}
# Training processed epoch 51
# Training processed epoch 52
# Training processed epoch 53
# Training processed epoch 54
# Training processed epoch 55
# Training processed epoch 56
# Training processed epoch 57
# Training processed epoch 58
# Training processed epoch 59
# Training processed epoch 60
#  Training epoch 60 | CE: 0.0580 | Q-Loss: 0.2031 | Avg Steps: 4.994314143567875
# halt logit: mean=3.182 std=0.885 max=6.170 %>0=99.8% %>1.5=96.0%
# halt steps: mean=2.50 median=1 %step1=53.8% %never=33.9% dist={1: 24224, 5: 15276, 2: 4804, 3: 605, 4: 91}
#
# Validation Logs ------
#
# sup_step_1 | mean=3.333 std=0.990 median=3.343 %>0=100.0% %>1.5=96.9% first5=[4.1490044593811035, 3.353635549545288, 4.097385883331299, 4.461703300476074, 3.81011700630188]
# sup_step_2 | mean=3.441 std=1.011 median=3.480 %>0=100.0% %>1.5=96.9% first5=[4.149120807647705, 3.394972562789917, 4.123203754425049, 4.672058582305908, 3.831122398376465]
# sup_step_3 | mean=3.415 std=1.021 median=3.482 %>0=100.0% %>1.5=96.9% first5=[4.07394552230835, 3.45770263671875, 3.634934663772583, 4.61194372177124, 3.8594918251037598]
# sup_step_4 | mean=3.421 std=1.025 median=3.486 %>0=100.0% %>1.5=96.9% first5=[4.102343559265137, 3.4808263778686523, 4.0298919677734375, 4.5434088706970215, 3.8556735515594482]
# sup_step_5 | mean=3.416 std=1.015 median=3.486 %>0=100.0% %>1.5=96.9% first5=[4.098721027374268, 3.46278977394104, 3.8836915493011475, 4.5375165939331055, 3.855764150619507]
#
# Validation Accuracy: 93.80%
# validation halt steps: mean=1.87 median=1 %step1=71.6% %never=19.1% dist={1: 3578, 5: 955, 2: 420, 4: 3, 3: 44}
# Training processed epoch 61
# Training processed epoch 62
# Training processed epoch 63
# Training processed epoch 64
# Training processed epoch 65
# Training processed epoch 66
# Training processed epoch 67
# Training processed epoch 68
# Training processed epoch 69
# Training processed epoch 70
#  Training epoch 70 | CE: 0.0708 | Q-Loss: 0.2000 | Avg Steps: 4.979388770433546
# halt logit: mean=3.224 std=0.916 max=6.205 %>0=99.8% %>1.5=95.4%
# halt steps: mean=2.40 median=1 %step1=56.6% %never=31.6% dist={1: 25478, 2: 4720, 5: 14224, 3: 493, 4: 85}
#
# Validation Logs ------
#
# sup_step_1 | mean=3.220 std=0.865 median=3.408 %>0=100.0% %>1.5=93.8% first5=[3.917156934738159, 3.3930864334106445, 4.254350662231445, 4.289654731750488, 4.233850955963135]
# sup_step_2 | mean=3.471 std=0.733 median=3.459 %>0=100.0% %>1.5=96.9% first5=[4.472406387329102, 3.323572874069214, 4.042357444763184, 4.417065620422363, 4.2541656494140625]
# sup_step_3 | mean=3.433 std=0.741 median=3.459 %>0=100.0% %>1.5=96.9% first5=[4.338268280029297, 3.3255248069763184, 3.836106300354004, 4.430978298187256, 4.2820210456848145]
# sup_step_4 | mean=3.431 std=0.740 median=3.503 %>0=100.0% %>1.5=96.9% first5=[4.2711052894592285, 3.31404447555542, 3.9221158027648926, 4.369925022125244, 4.292593479156494]
# sup_step_5 | mean=3.434 std=0.738 median=3.511 %>0=100.0% %>1.5=96.9% first5=[4.29489278793335, 3.2968149185180664, 3.8960890769958496, 4.364108562469482, 4.2809271812438965]
#
# Validation Accuracy: 92.50%
# validation halt steps: mean=1.81 median=1 %step1=70.3% %never=16.7% dist={1: 3515, 5: 835, 2: 579, 3: 62, 4: 9}
# Training processed epoch 71
# Training processed epoch 72
# Training processed epoch 73
# Training processed epoch 74
# Training processed epoch 75
# Training processed epoch 76
# Training processed epoch 77
# Training processed epoch 78
# Training processed epoch 79
# Training processed epoch 80
#  Training epoch 80 | CE: 0.0762 | Q-Loss: 0.1886 | Avg Steps: 4.982942430703624
# halt logit: mean=3.343 std=1.000 max=6.578 %>0=99.7% %>1.5=95.2%
# halt steps: mean=2.27 median=1 %step1=60.1% %never=28.7% dist={1: 27049, 2: 4518, 5: 12893, 3: 449, 4: 91}
#
# Validation Logs ------
#
# sup_step_1 | mean=3.174 std=0.706 median=3.136 %>0=100.0% %>1.5=96.9% first5=[2.992722749710083, 2.850862741470337, 4.112277984619141, 2.643139362335205, 3.9350128173828125]
# sup_step_2 | mean=3.346 std=0.680 median=3.279 %>0=100.0% %>1.5=96.9% first5=[3.2791976928710938, 2.5996079444885254, 4.3987507820129395, 3.054731845855713, 4.039340019226074]
# sup_step_3 | mean=3.329 std=0.691 median=3.228 %>0=100.0% %>1.5=96.9% first5=[3.2103257179260254, 2.5241546630859375, 4.4840216636657715, 3.044739007949829, 4.075399875640869]
# sup_step_4 | mean=3.325 std=0.691 median=3.219 %>0=100.0% %>1.5=96.9% first5=[3.1930534839630127, 2.523019313812256, 4.4302520751953125, 2.9425947666168213, 4.071836471557617]
# sup_step_5 | mean=3.328 std=0.691 median=3.210 %>0=100.0% %>1.5=96.9% first5=[3.1938893795013428, 2.527857542037964, 4.462165832519531, 2.9100258350372314, 4.072135925292969]
#
# Validation Accuracy: 87.94%
# validation halt steps: mean=2.29 median=1 %step1=57.4% %never=28.2% dist={2: 654, 5: 1409, 1: 2871, 4: 16, 3: 50}
# Training processed epoch 81
# Training processed epoch 82
# Training processed epoch 83
# Training processed epoch 84
# Training processed epoch 85
# Training processed epoch 86
# Training processed epoch 87
# Training processed epoch 88
# Training processed epoch 89
# Training processed epoch 90
#  Training epoch 90 | CE: 0.0652 | Q-Loss: 0.1687 | Avg Steps: 4.9502487562189055
# halt logit: mean=3.526 std=0.897 max=6.942 %>0=99.9% %>1.5=98.1%
# halt steps: mean=1.99 median=1 %step1=67.9% %never=21.8% dist={1: 30544, 2: 4165, 5: 9821, 3: 373, 4: 97}
#
# Validation Logs ------
#
# sup_step_1 | mean=1.204 std=0.879 median=1.128 %>0=90.6% %>1.5=43.8% first5=[0.22015564143657684, 2.054826498031616, 1.102502465248108, 0.2523045539855957, 2.2603442668914795]
# sup_step_2 | mean=1.395 std=0.831 median=1.320 %>0=100.0% %>1.5=50.0% first5=[0.7843855619430542, 1.7576016187667847, 1.7116901874542236, 0.5168176293373108, 2.055466413497925]
# sup_step_3 | mean=1.400 std=0.867 median=1.355 %>0=100.0% %>1.5=50.0% first5=[0.8320085406303406, 1.6733933687210083, 1.7977343797683716, 0.5400174856185913, 2.071697473526001]
# sup_step_4 | mean=1.374 std=0.867 median=1.344 %>0=100.0% %>1.5=46.9% first5=[0.7969959378242493, 1.6941722631454468, 1.3216418027877808, 0.5092111229896545, 2.078716278076172]
# sup_step_5 | mean=1.378 std=0.865 median=1.344 %>0=100.0% %>1.5=46.9% first5=[0.7961753010749817, 1.7037546634674072, 1.3188682794570923, 0.5000296831130981, 2.0763628482818604]
#
# Validation Accuracy: 81.12%
# validation halt steps: mean=4.89 median=5 %step1=1.1% %never=96.7% dist={5: 4833, 2: 88, 1: 56, 3: 18, 4: 5}
# Training processed epoch 91
# Training processed epoch 92
# Training processed epoch 93
# Training processed epoch 94
# Training processed epoch 95
# Training processed epoch 96
# Training processed epoch 97
# Training processed epoch 98
# Training processed epoch 99

# %%
## s-1

# Config: n_sup=1, halt > 0, c=0.1, T=3, 100 epochs
# Supervision sweep: no-recursion baseline under the binary-EM target.
# Log: training-logs/binary-em-nsup-1.txt

HALT_THRESHOLD = 0
model_training_and_validation_with_mask(c=0.1, T=3, n_sup=1, HALT_THRESHOLD = HALT_THRESHOLD)
# Out:
# PAD_TOKEN:  11
# Training Logs ------
#
# Training processed epoch 0
#  Training epoch 0 | CE: 1.6313 | Q-Loss: 0.0182 | Avg Steps: 1.0
# halt logit: mean=-7.587 std=2.406 max=0.019 %>0=0.0% %>1.5=0.0%
# halt steps: mean=1.00 median=1 %step1=100.0% %never=100.0% dist={1: 45000}
#
# Validation Logs ------
#
# sup_step_1 | mean=-7.235 std=0.852 median=-7.494 %>0=0.0% %>1.5=0.0% first5=[-8.46947193145752, -8.410146713256836, -7.561344623565674, -6.5032148361206055, -7.643523216247559]
#
# Validation Accuracy: 0.06%
# validation halt steps: mean=1.00 median=1 %step1=100.0% %never=100.0% dist={1: 5000}
# Training processed epoch 1
# Training processed epoch 2
# Training processed epoch 3
# Training processed epoch 4
# Training processed epoch 5
# Training processed epoch 6
# Training processed epoch 7
# Training processed epoch 8
# Training processed epoch 9
# Training processed epoch 10
#  Training epoch 10 | CE: 0.8161 | Q-Loss: 0.1780 | Avg Steps: 1.0
# halt logit: mean=-3.362 std=0.713 max=-0.911 %>0=0.0% %>1.5=0.0%
# halt steps: mean=1.00 median=1 %step1=100.0% %never=100.0% dist={1: 45000}
#
# Validation Logs ------
#
# sup_step_1 | mean=-2.586 std=0.483 median=-2.619 %>0=0.0% %>1.5=0.0% first5=[-2.6486942768096924, -2.6942532062530518, -2.4563956260681152, -2.3715240955352783, -3.1911568641662598]
#
# Validation Accuracy: 5.94%
# validation halt steps: mean=1.00 median=1 %step1=100.0% %never=100.0% dist={1: 5000}
# Training processed epoch 11
# Training processed epoch 12
# Training processed epoch 13
# Training processed epoch 14
# Training processed epoch 15
# Training processed epoch 16
# Training processed epoch 17
# Training processed epoch 18
# Training processed epoch 19
# Training processed epoch 20
#  Training epoch 20 | CE: 0.5408 | Q-Loss: 0.3399 | Avg Steps: 1.0
# halt logit: mean=-2.189 std=0.352 max=-0.644 %>0=0.0% %>1.5=0.0%
# halt steps: mean=1.00 median=1 %step1=100.0% %never=100.0% dist={1: 45000}
#
# Validation Logs ------
#
# sup_step_1 | mean=-2.054 std=0.270 median=-2.104 %>0=0.0% %>1.5=0.0% first5=[-2.150033950805664, -2.397554397583008, -1.9550522565841675, -1.7993091344833374, -2.5979199409484863]
#
# Validation Accuracy: 8.90%
# validation halt steps: mean=1.00 median=1 %step1=100.0% %never=100.0% dist={1: 5000}
# Training processed epoch 21
# Training processed epoch 22
# Training processed epoch 23
# Training processed epoch 24
# Training processed epoch 25
# Training processed epoch 26
# Training processed epoch 27
# Training processed epoch 28
# Training processed epoch 29
# Training processed epoch 30
#  Training epoch 30 | CE: 0.2601 | Q-Loss: 0.6539 | Avg Steps: 1.0
# halt logit: mean=0.304 std=0.731 max=3.389 %>0=63.9% %>1.5=5.7%
# halt steps: mean=1.00 median=1 %step1=100.0% %never=100.0% dist={1: 45000}
#
# Validation Logs ------
#
# sup_step_1 | mean=0.917 std=0.464 median=0.932 %>0=96.9% %>1.5=9.4% first5=[1.1575281620025635, 1.392614722251892, 0.6480271816253662, 1.0517399311065674, 1.7713850736618042]
#
# Validation Accuracy: 72.50%
# validation halt steps: mean=1.00 median=1 %step1=100.0% %never=100.0% dist={1: 5000}
# Training processed epoch 31
# Training processed epoch 32
# Training processed epoch 33
# Training processed epoch 34
# Training processed epoch 35
# Training processed epoch 36
# Training processed epoch 37
# Training processed epoch 38
# Training processed epoch 39
# Training processed epoch 40
#  Training epoch 40 | CE: 0.0558 | Q-Loss: 0.2249 | Avg Steps: 1.0
# halt logit: mean=3.171 std=1.219 max=7.991 %>0=99.5% %>1.5=90.7%
# halt steps: mean=1.00 median=1 %step1=100.0% %never=100.0% dist={1: 45000}
#
# Validation Logs ------
#
# sup_step_1 | mean=3.976 std=0.882 median=3.886 %>0=100.0% %>1.5=100.0% first5=[4.966269016265869, 3.8828999996185303, 3.994906187057495, 4.176351547241211, 4.926695346832275]
#
# Validation Accuracy: 95.46%
# validation halt steps: mean=1.00 median=1 %step1=100.0% %never=100.0% dist={1: 5000}
# Training processed epoch 41
# Training processed epoch 42
# Training processed epoch 43
# Training processed epoch 44
# Training processed epoch 45
# Training processed epoch 46
# Training processed epoch 47
# Training processed epoch 48
# Training processed epoch 49
# Training processed epoch 50
#  Training epoch 50 | CE: 0.0244 | Q-Loss: 0.1460 | Avg Steps: 1.0
# halt logit: mean=3.755 std=0.986 max=7.345 %>0=99.9% %>1.5=98.2%
# halt steps: mean=1.00 median=1 %step1=100.0% %never=100.0% dist={1: 45000}
#
# Validation Logs ------
#
# sup_step_1 | mean=3.367 std=0.904 median=3.339 %>0=100.0% %>1.5=96.9% first5=[4.283928394317627, 3.373412847518921, 3.3138465881347656, 4.389765739440918, 4.364147663116455]
#
# Validation Accuracy: 95.22%
# validation halt steps: mean=1.00 median=1 %step1=100.0% %never=100.0% dist={1: 5000}
# Training processed epoch 51
# Training processed epoch 52
# Training processed epoch 53
# Training processed epoch 54
# Training processed epoch 55
# Training processed epoch 56
# Training processed epoch 57
# Training processed epoch 58
# Training processed epoch 59
# Training processed epoch 60
#  Training epoch 60 | CE: 0.0207 | Q-Loss: 0.1164 | Avg Steps: 1.0
# halt logit: mean=4.211 std=1.146 max=8.554 %>0=99.9% %>1.5=98.6%
# halt steps: mean=1.00 median=1 %step1=100.0% %never=100.0% dist={1: 45000}
#
# Validation Logs ------
#
# sup_step_1 | mean=2.056 std=0.914 median=2.024 %>0=96.9% %>1.5=75.0% first5=[2.205386161804199, 0.744286060333252, 1.4796867370605469, 2.472264289855957, 1.924299716949463]
#
# Validation Accuracy: 87.20%
# validation halt steps: mean=1.00 median=1 %step1=100.0% %never=100.0% dist={1: 5000}
# Training processed epoch 61
# Training processed epoch 62
# Training processed epoch 63
# Training processed epoch 64
# Training processed epoch 65
# Training processed epoch 66
# Training processed epoch 67
# Training processed epoch 68
# Training processed epoch 69
# Training processed epoch 70
#  Training epoch 70 | CE: 0.0261 | Q-Loss: 0.1265 | Avg Steps: 1.0
# halt logit: mean=4.100 std=1.251 max=8.390 %>0=99.9% %>1.5=97.5%
# halt steps: mean=1.00 median=1 %step1=100.0% %never=100.0% dist={1: 45000}
#
# Validation Logs ------
#
# sup_step_1 | mean=4.531 std=0.815 median=4.623 %>0=100.0% %>1.5=100.0% first5=[5.444060325622559, 4.623498916625977, 3.2479803562164307, 5.864377975463867, 4.941205978393555]
#
# Validation Accuracy: 98.24%
# validation halt steps: mean=1.00 median=1 %step1=100.0% %never=100.0% dist={1: 5000}
# Training processed epoch 71
# Training processed epoch 72
# Training processed epoch 73
# Training processed epoch 74
# Training processed epoch 75
# Training processed epoch 76
# Training processed epoch 77
# Training processed epoch 78
# Training processed epoch 79
# Training processed epoch 80
#  Training epoch 80 | CE: 0.0144 | Q-Loss: 0.0998 | Avg Steps: 1.0
# halt logit: mean=4.324 std=1.055 max=8.690 %>0=100.0% %>1.5=99.3%
# halt steps: mean=1.00 median=1 %step1=100.0% %never=100.0% dist={1: 45000}
#
# Validation Logs ------
#
# sup_step_1 | mean=4.450 std=0.779 median=4.505 %>0=100.0% %>1.5=100.0% first5=[5.272744178771973, 3.7276110649108887, 3.6416733264923096, 5.6753387451171875, 5.191593170166016]
#
# Validation Accuracy: 98.32%
# validation halt steps: mean=1.00 median=1 %step1=100.0% %never=100.0% dist={1: 5000}
# Training processed epoch 81
# Training processed epoch 82
# Training processed epoch 83
# Training processed epoch 84
# Training processed epoch 85
# Training processed epoch 86
# Training processed epoch 87
# Training processed epoch 88
# Training processed epoch 89
# Training processed epoch 90
#  Training epoch 90 | CE: 0.0196 | Q-Loss: 0.0953 | Avg Steps: 1.0
# halt logit: mean=4.662 std=1.441 max=10.028 %>0=99.9% %>1.5=98.6%
# halt steps: mean=1.00 median=1 %step1=100.0% %never=100.0% dist={1: 45000}
#
# Validation Logs ------
#
# sup_step_1 | mean=5.401 std=0.773 median=5.286 %>0=100.0% %>1.5=100.0% first5=[6.057619094848633, 4.7151899337768555, 4.7808661460876465, 5.574072360992432, 6.699061393737793]
#
# Validation Accuracy: 99.06%
# validation halt steps: mean=1.00 median=1 %step1=100.0% %never=100.0% dist={1: 5000}
# Training processed epoch 91
# Training processed epoch 92
# Training processed epoch 93
# Training processed epoch 94
# Training processed epoch 95
# Training processed epoch 96
# Training processed epoch 97
# Training processed epoch 98
# Training processed epoch 99

# %%
## s-16

# Config: n_sup=16, halt > 0, c=0.1, T=3, 100 epochs
# Supervision sweep at the paper's N_sup = 16 -- the closest-to-paper config in this study.
# Slow early: no sample halts until train EM appears, so all 16 steps run per batch.
# Log: training-logs/binary-em-nsup-16.txt

HALT_THRESHOLD = 0
model_training_and_validation_with_mask(c=0.1, T=3, n_sup=16, HALT_THRESHOLD = HALT_THRESHOLD)
# Out:
# PAD_TOKEN:  11
# Training Logs ------
#
# Training processed epoch 0
#  Training epoch 0 | CE: 1.6314 | Q-Loss: 0.0194 | Avg Steps: 15.957356076759062
# halt logit: mean=-7.889 std=2.714 max=0.093 %>0=0.2% %>1.5=0.0%
# halt steps: mean=15.94 median=16 %step1=0.4% %never=99.6% dist={1: 189, 16: 44811}
#
# Validation Logs ------
#
# sup_step_1 | mean=-7.358 std=1.104 median=-7.280 %>0=0.0% %>1.5=0.0% first5=[-9.305476188659668, -7.338839054107666, -8.683209419250488, -5.780799865722656, -7.015182018280029]
# sup_step_2 | mean=-7.266 std=1.074 median=-7.449 %>0=0.0% %>1.5=0.0% first5=[-9.219782829284668, -8.06380558013916, -8.292222023010254, -5.712259769439697, -7.222961902618408]
# sup_step_3 | mean=-7.292 std=1.062 median=-7.556 %>0=0.0% %>1.5=0.0% first5=[-9.327437400817871, -8.028115272521973, -8.15738582611084, -5.793003559112549, -7.298346996307373]
# sup_step_4 | mean=-7.301 std=1.067 median=-7.501 %>0=0.0% %>1.5=0.0% first5=[-9.34048080444336, -8.121721267700195, -8.085371971130371, -5.795682430267334, -7.296314716339111]
# sup_step_5 | mean=-7.289 std=1.054 median=-7.506 %>0=0.0% %>1.5=0.0% first5=[-9.341117858886719, -8.079739570617676, -8.098433494567871, -5.787992477416992, -7.299525737762451]
# sup_step_6 | mean=-7.290 std=1.058 median=-7.507 %>0=0.0% %>1.5=0.0% first5=[-9.34083366394043, -8.09712028503418, -8.110782623291016, -5.782963275909424, -7.299351692199707]
# sup_step_7 | mean=-7.290 std=1.056 median=-7.507 %>0=0.0% %>1.5=0.0% first5=[-9.340673446655273, -8.092118263244629, -8.111738204956055, -5.780367374420166, -7.299365043640137]
# sup_step_8 | mean=-7.290 std=1.057 median=-7.507 %>0=0.0% %>1.5=0.0% first5=[-9.340609550476074, -8.092534065246582, -8.110182762145996, -5.779170036315918, -7.299381256103516]
# sup_step_9 | mean=-7.289 std=1.057 median=-7.507 %>0=0.0% %>1.5=0.0% first5=[-9.340588569641113, -8.09328556060791, -8.109689712524414, -5.778633117675781, -7.299377918243408]
# sup_step_10 | mean=-7.290 std=1.056 median=-7.507 %>0=0.0% %>1.5=0.0% first5=[-9.340581893920898, -8.092570304870605, -8.109800338745117, -5.77840518951416, -7.299377918243408]
# sup_step_11 | mean=-7.290 std=1.057 median=-7.507 %>0=0.0% %>1.5=0.0% first5=[-9.34057903289795, -8.093001365661621, -8.10989761352539, -5.778324127197266, -7.299378395080566]
# sup_step_12 | mean=-7.289 std=1.057 median=-7.507 %>0=0.0% %>1.5=0.0% first5=[-9.34057903289795, -8.09279727935791, -8.109904289245605, -5.778299808502197, -7.299378395080566]
# sup_step_13 | mean=-7.290 std=1.057 median=-7.507 %>0=0.0% %>1.5=0.0% first5=[-9.34057903289795, -8.092872619628906, -8.109890937805176, -5.778295516967773, -7.299378395080566]
# sup_step_14 | mean=-7.290 std=1.057 median=-7.507 %>0=0.0% %>1.5=0.0% first5=[-9.34057903289795, -8.092855453491211, -8.10988712310791, -5.778294086456299, -7.299378395080566]
# sup_step_15 | mean=-7.290 std=1.057 median=-7.507 %>0=0.0% %>1.5=0.0% first5=[-9.34057903289795, -8.092854499816895, -8.109889030456543, -5.778294563293457, -7.299378395080566]
# sup_step_16 | mean=-7.290 std=1.057 median=-7.507 %>0=0.0% %>1.5=0.0% first5=[-9.340578079223633, -8.092859268188477, -8.109889030456543, -5.778295040130615, -7.299378871917725]
#
# Validation Accuracy: 0.08%
# validation halt steps: mean=16.00 median=16 %step1=0.0% %never=100.0% dist={16: 5000}
# Training processed epoch 1
# Training processed epoch 2
# Training processed epoch 3
# Training processed epoch 4
# Training processed epoch 5
# Training processed epoch 6
# Training processed epoch 7
# Training processed epoch 8
# Training processed epoch 9
# Training processed epoch 10
#  Training epoch 10 | CE: 0.6857 | Q-Loss: 0.2629 | Avg Steps: 16.0
# halt logit: mean=-2.700 std=0.540 max=-0.138 %>0=0.0% %>1.5=0.0%
# halt steps: mean=16.00 median=16 %step1=0.0% %never=100.0% dist={16: 45000}
#
# Validation Logs ------
#
# sup_step_1 | mean=-2.305 std=0.402 median=-2.311 %>0=0.0% %>1.5=0.0% first5=[-2.822213888168335, -2.6268346309661865, -1.947742223739624, -2.8579533100128174, -1.8389288187026978]
# sup_step_2 | mean=-2.396 std=0.478 median=-2.335 %>0=0.0% %>1.5=0.0% first5=[-2.925546407699585, -2.770703077316284, -2.058823347091675, -3.569648027420044, -1.9533835649490356]
# sup_step_3 | mean=-2.373 std=0.433 median=-2.379 %>0=0.0% %>1.5=0.0% first5=[-2.7731258869171143, -2.7694613933563232, -2.1240322589874268, -3.233527183532715, -1.8515819311141968]
# sup_step_4 | mean=-2.369 std=0.420 median=-2.339 %>0=0.0% %>1.5=0.0% first5=[-2.776949167251587, -2.77681565284729, -2.120997190475464, -3.1863605976104736, -1.8143998384475708]
# sup_step_5 | mean=-2.369 std=0.445 median=-2.337 %>0=0.0% %>1.5=0.0% first5=[-2.772409200668335, -2.7895708084106445, -2.114812135696411, -3.404662847518921, -1.8166447877883911]
# sup_step_6 | mean=-2.367 std=0.440 median=-2.339 %>0=0.0% %>1.5=0.0% first5=[-2.787128448486328, -2.7984249591827393, -2.1151888370513916, -3.349757432937622, -1.824803113937378]
# sup_step_7 | mean=-2.365 std=0.437 median=-2.339 %>0=0.0% %>1.5=0.0% first5=[-2.7838804721832275, -2.803354024887085, -2.1159262657165527, -3.2839558124542236, -1.8251932859420776]
# sup_step_8 | mean=-2.371 std=0.442 median=-2.339 %>0=0.0% %>1.5=0.0% first5=[-2.7831602096557617, -2.805229663848877, -2.115844249725342, -3.3515818119049072, -1.8232983350753784]
# sup_step_9 | mean=-2.372 std=0.441 median=-2.339 %>0=0.0% %>1.5=0.0% first5=[-2.7833545207977295, -2.8046209812164307, -2.11576509475708, -3.3572585582733154, -1.8230162858963013]
# sup_step_10 | mean=-2.371 std=0.435 median=-2.339 %>0=0.0% %>1.5=0.0% first5=[-2.7832767963409424, -2.802544355392456, -2.1157758235931396, -3.319838285446167, -1.8233965635299683]
# sup_step_11 | mean=-2.371 std=0.436 median=-2.339 %>0=0.0% %>1.5=0.0% first5=[-2.78337025642395, -2.799699544906616, -2.1157853603363037, -3.335292100906372, -1.8234844207763672]
# sup_step_12 | mean=-2.370 std=0.440 median=-2.339 %>0=0.0% %>1.5=0.0% first5=[-2.783344030380249, -2.797123908996582, -2.1157827377319336, -3.3513410091400146, -1.823410987854004]
# sup_step_13 | mean=-2.367 std=0.439 median=-2.339 %>0=0.0% %>1.5=0.0% first5=[-2.7833423614501953, -2.795168161392212, -2.1157824993133545, -3.3354499340057373, -1.8233857154846191]
# sup_step_14 | mean=-2.366 std=0.438 median=-2.339 %>0=0.0% %>1.5=0.0% first5=[-2.783343553543091, -2.7939252853393555, -2.115781545639038, -3.333644390106201, -1.8233990669250488]
# sup_step_15 | mean=-2.368 std=0.441 median=-2.339 %>0=0.0% %>1.5=0.0% first5=[-2.783343553543091, -2.7931835651397705, -2.1157827377319336, -3.3441293239593506, -1.8234063386917114]
# sup_step_16 | mean=-2.369 std=0.444 median=-2.339 %>0=0.0% %>1.5=0.0% first5=[-2.7833430767059326, -2.793156147003174, -2.1157824993133545, -3.340383291244507, -1.8234037160873413]
#
# Validation Accuracy: 6.96%
# validation halt steps: mean=16.00 median=16 %step1=0.0% %never=100.0% dist={16: 5000}
# Training processed epoch 11
# Training processed epoch 12
# Training processed epoch 13
# Training processed epoch 14
# Training processed epoch 15
# Training processed epoch 16
# Training processed epoch 17
# Training processed epoch 18
# Training processed epoch 19
# Training processed epoch 20
#  Training epoch 20 | CE: 0.5552 | Q-Loss: 0.3342 | Avg Steps: 16.0
# halt logit: mean=-2.225 std=0.361 max=-0.659 %>0=0.0% %>1.5=0.0%
# halt steps: mean=16.00 median=16 %step1=0.0% %never=100.0% dist={16: 45000}
#
# Validation Logs ------
#
# sup_step_1 | mean=-2.407 std=0.360 median=-2.337 %>0=0.0% %>1.5=0.0% first5=[-3.328301191329956, -2.056974172592163, -2.989008665084839, -2.8531734943389893, -1.944239616394043]
# sup_step_2 | mean=-2.441 std=0.332 median=-2.413 %>0=0.0% %>1.5=0.0% first5=[-3.3844172954559326, -2.245804786682129, -2.9993858337402344, -2.65297532081604, -2.0362579822540283]
# sup_step_3 | mean=-2.430 std=0.320 median=-2.407 %>0=0.0% %>1.5=0.0% first5=[-3.240644693374634, -2.1545584201812744, -2.9780657291412354, -2.691051483154297, -2.053816318511963]
# sup_step_4 | mean=-2.419 std=0.313 median=-2.401 %>0=0.0% %>1.5=0.0% first5=[-3.2190468311309814, -2.161482334136963, -2.9782183170318604, -2.676398515701294, -2.050358533859253]
# sup_step_5 | mean=-2.419 std=0.313 median=-2.400 %>0=0.0% %>1.5=0.0% first5=[-3.228437662124634, -2.1621265411376953, -2.978515148162842, -2.6743531227111816, -2.039677858352661]
# sup_step_6 | mean=-2.420 std=0.314 median=-2.402 %>0=0.0% %>1.5=0.0% first5=[-3.233008861541748, -2.162259340286255, -2.978604555130005, -2.6766815185546875, -2.034611940383911]
# sup_step_7 | mean=-2.421 std=0.314 median=-2.400 %>0=0.0% %>1.5=0.0% first5=[-3.2328524589538574, -2.1618220806121826, -2.9784083366394043, -2.6769421100616455, -2.0364599227905273]
# sup_step_8 | mean=-2.420 std=0.314 median=-2.400 %>0=0.0% %>1.5=0.0% first5=[-3.2322356700897217, -2.1619765758514404, -2.9785048961639404, -2.676626443862915, -2.0389206409454346]
# sup_step_9 | mean=-2.419 std=0.314 median=-2.400 %>0=0.0% %>1.5=0.0% first5=[-3.2321255207061768, -2.1619603633880615, -2.9784929752349854, -2.67659854888916, -2.0392704010009766]
# sup_step_10 | mean=-2.420 std=0.314 median=-2.400 %>0=0.0% %>1.5=0.0% first5=[-3.232179641723633, -2.161958694458008, -2.9784862995147705, -2.676642417907715, -2.038811683654785]
# sup_step_11 | mean=-2.420 std=0.313 median=-2.400 %>0=0.0% %>1.5=0.0% first5=[-3.232208013534546, -2.1619584560394287, -2.9784889221191406, -2.676645040512085, -2.0384931564331055]
# sup_step_12 | mean=-2.420 std=0.314 median=-2.400 %>0=0.0% %>1.5=0.0% first5=[-3.2322068214416504, -2.161959171295166, -2.9784886837005615, -2.6766393184661865, -2.038508415222168]
# sup_step_13 | mean=-2.420 std=0.314 median=-2.400 %>0=0.0% %>1.5=0.0% first5=[-3.2322030067443848, -2.161959171295166, -2.9784884452819824, -2.67663836479187, -2.0386197566986084]
# sup_step_14 | mean=-2.420 std=0.314 median=-2.400 %>0=0.0% %>1.5=0.0% first5=[-3.232203722000122, -2.161958932876587, -2.978489398956299, -2.6766397953033447, -2.0386617183685303]
# sup_step_15 | mean=-2.420 std=0.314 median=-2.400 %>0=0.0% %>1.5=0.0% first5=[-3.232203245162964, -2.161958932876587, -2.9784886837005615, -2.67663836479187, -2.0386431217193604]
# sup_step_16 | mean=-2.420 std=0.314 median=-2.400 %>0=0.0% %>1.5=0.0% first5=[-3.2322022914886475, -2.161959171295166, -2.978489398956299, -2.6766390800476074, -2.038620710372925]
#
# Validation Accuracy: 8.32%
# validation halt steps: mean=16.00 median=16 %step1=0.0% %never=100.0% dist={16: 5000}
# Training processed epoch 21
# Training processed epoch 22
# Training processed epoch 23
# Training processed epoch 24
# Training processed epoch 25
# Training processed epoch 26
# Training processed epoch 27
# Training processed epoch 28
# Training processed epoch 29
# Training processed epoch 30
#  Training epoch 30 | CE: 0.5107 | Q-Loss: 0.4223 | Avg Steps: 16.0
# halt logit: mean=-1.791 std=0.381 max=-0.270 %>0=0.0% %>1.5=0.0%
# halt steps: mean=16.00 median=16 %step1=0.0% %never=100.0% dist={16: 45000}
#
# Validation Logs ------
#
# sup_step_1 | mean=-1.635 std=0.466 median=-1.554 %>0=0.0% %>1.5=0.0% first5=[-1.5543032884597778, -1.3108805418014526, -1.4292705059051514, -2.4355738162994385, -1.0451472997665405]
# sup_step_2 | mean=-1.595 std=0.403 median=-1.603 %>0=0.0% %>1.5=0.0% first5=[-1.7443695068359375, -1.2419486045837402, -1.6025464534759521, -1.9919649362564087, -1.1128045320510864]
# sup_step_3 | mean=-1.585 std=0.394 median=-1.571 %>0=0.0% %>1.5=0.0% first5=[-1.6583884954452515, -1.3015137910842896, -1.570565104484558, -1.916480541229248, -1.0516471862792969]
# sup_step_4 | mean=-1.589 std=0.400 median=-1.561 %>0=0.0% %>1.5=0.0% first5=[-1.6533254384994507, -1.2759360074996948, -1.5605473518371582, -2.0374536514282227, -1.0266942977905273]
# sup_step_5 | mean=-1.590 std=0.400 median=-1.551 %>0=0.0% %>1.5=0.0% first5=[-1.656136393547058, -1.2828541994094849, -1.550994634628296, -2.003206968307495, -1.03348708152771]
# sup_step_6 | mean=-1.589 std=0.398 median=-1.556 %>0=0.0% %>1.5=0.0% first5=[-1.656601071357727, -1.2819019556045532, -1.5561835765838623, -1.9916071891784668, -1.047224760055542]
# sup_step_7 | mean=-1.588 std=0.398 median=-1.557 %>0=0.0% %>1.5=0.0% first5=[-1.656568169593811, -1.282081127166748, -1.5571718215942383, -2.002016067504883, -1.0503689050674438]
# sup_step_8 | mean=-1.590 std=0.399 median=-1.556 %>0=0.0% %>1.5=0.0% first5=[-1.6565169095993042, -1.2820603847503662, -1.5563790798187256, -1.9966779947280884, -1.0457050800323486]
# sup_step_9 | mean=-1.589 std=0.398 median=-1.556 %>0=0.0% %>1.5=0.0% first5=[-1.656508445739746, -1.2820525169372559, -1.5563585758209229, -1.9982134103775024, -1.0426909923553467]
# sup_step_10 | mean=-1.590 std=0.399 median=-1.556 %>0=0.0% %>1.5=0.0% first5=[-1.6565111875534058, -1.2820574045181274, -1.5564316511154175, -1.9989093542099, -1.043174386024475]
# sup_step_11 | mean=-1.588 std=0.399 median=-1.556 %>0=0.0% %>1.5=0.0% first5=[-1.6565128564834595, -1.2820558547973633, -1.5564336776733398, -1.9981542825698853, -1.0443540811538696]
# sup_step_12 | mean=-1.589 std=0.399 median=-1.556 %>0=0.0% %>1.5=0.0% first5=[-1.6565124988555908, -1.2820560932159424, -1.556428074836731, -1.998419165611267, -1.0446854829788208]
# sup_step_13 | mean=-1.590 std=0.399 median=-1.556 %>0=0.0% %>1.5=0.0% first5=[-1.65651273727417, -1.2820559740066528, -1.5564261674880981, -1.9983779191970825, -1.044440746307373]
# sup_step_14 | mean=-1.588 std=0.399 median=-1.556 %>0=0.0% %>1.5=0.0% first5=[-1.6565121412277222, -1.2820558547973633, -1.5564274787902832, -1.9983402490615845, -1.044228196144104]
# sup_step_15 | mean=-1.590 std=0.399 median=-1.556 %>0=0.0% %>1.5=0.0% first5=[-1.6565128564834595, -1.2820558547973633, -1.5564278364181519, -1.998383641242981, -1.0442167520523071]
# sup_step_16 | mean=-1.588 std=0.399 median=-1.556 %>0=0.0% %>1.5=0.0% first5=[-1.65651273727417, -1.2820563316345215, -1.5564273595809937, -1.9983679056167603, -1.0442821979522705]
#
# Validation Accuracy: 14.24%
# validation halt steps: mean=16.00 median=16 %step1=0.0% %never=100.0% dist={16: 5000}
# Training processed epoch 31
# Training processed epoch 32
# Training processed epoch 33
# Training processed epoch 34
# Training processed epoch 35
# Training processed epoch 36
# Training processed epoch 37
# Training processed epoch 38
# Training processed epoch 39
# Training processed epoch 40
#  Training epoch 40 | CE: 0.2863 | Q-Loss: 0.6511 | Avg Steps: 12.077469793887705
# halt logit: mean=0.485 std=0.434 max=2.561 %>0=87.1% %>1.5=1.1%
# halt steps: mean=2.30 median=1 %step1=89.4% %never=8.5% dist={1: 40222, 16: 3814, 2: 825, 3: 101, 4: 19, 15: 1, 11: 2, 5: 5, 8: 1, 6: 3, 13: 1, 9: 1, 7: 2, 12: 1, 10: 1, 14: 1}
#
# Validation Logs ------
#
# sup_step_1 | mean=0.548 std=0.419 median=0.563 %>0=93.8% %>1.5=0.0% first5=[1.1458418369293213, 0.5571954250335693, 0.5450770854949951, 0.5458866357803345, 1.1577297449111938]
# sup_step_2 | mean=0.597 std=0.412 median=0.640 %>0=96.9% %>1.5=0.0% first5=[1.2168574333190918, 0.5873685479164124, 0.6546016931533813, 0.5139861106872559, 0.9793961048126221]
# sup_step_3 | mean=0.608 std=0.412 median=0.654 %>0=96.9% %>1.5=0.0% first5=[1.2788400650024414, 0.630988359451294, 0.7045319080352783, 0.5070085525512695, 0.9942318201065063]
# sup_step_4 | mean=0.608 std=0.413 median=0.635 %>0=96.9% %>1.5=0.0% first5=[1.296159029006958, 0.6072851419448853, 0.7181621789932251, 0.5124990940093994, 1.0187140703201294]
# sup_step_5 | mean=0.605 std=0.412 median=0.641 %>0=96.9% %>1.5=0.0% first5=[1.3018345832824707, 0.6114131808280945, 0.7093586921691895, 0.51047682762146, 1.022934079170227]
# sup_step_6 | mean=0.603 std=0.412 median=0.639 %>0=96.9% %>1.5=0.0% first5=[1.2996068000793457, 0.6178134679794312, 0.7063544988632202, 0.5084483623504639, 1.0195205211639404]
# sup_step_7 | mean=0.603 std=0.411 median=0.638 %>0=96.9% %>1.5=0.0% first5=[1.2881784439086914, 0.6139903664588928, 0.7078055143356323, 0.5082607269287109, 1.0185238122940063]
# sup_step_8 | mean=0.604 std=0.411 median=0.638 %>0=96.9% %>1.5=0.0% first5=[1.2717204093933105, 0.6139755249023438, 0.7084438800811768, 0.5086417198181152, 1.018908977508545]
# sup_step_9 | mean=0.604 std=0.411 median=0.638 %>0=96.9% %>1.5=0.0% first5=[1.256218433380127, 0.6154012680053711, 0.7082103490829468, 0.5087994337081909, 1.0191031694412231]
# sup_step_10 | mean=0.604 std=0.410 median=0.638 %>0=96.9% %>1.5=0.0% first5=[1.2479395866394043, 0.6144717931747437, 0.7080706357955933, 0.5087704658508301, 1.0190725326538086]
# sup_step_11 | mean=0.603 std=0.409 median=0.638 %>0=96.9% %>1.5=0.0% first5=[1.2477366924285889, 0.6144841909408569, 0.7081067562103271, 0.5087337493896484, 1.0190399885177612]
# sup_step_12 | mean=0.602 std=0.409 median=0.638 %>0=96.9% %>1.5=0.0% first5=[1.2534170150756836, 0.6148586273193359, 0.7081372737884521, 0.5087282657623291, 1.0190402269363403]
# sup_step_13 | mean=0.602 std=0.410 median=0.638 %>0=96.9% %>1.5=0.0% first5=[1.2616033554077148, 0.6146200895309448, 0.7081323862075806, 0.5087337493896484, 1.0190449953079224]
# sup_step_14 | mean=0.604 std=0.411 median=0.638 %>0=96.9% %>1.5=0.0% first5=[1.2678203582763672, 0.6146179437637329, 0.7081260681152344, 0.5087354183197021, 1.019045352935791]
# sup_step_15 | mean=0.605 std=0.411 median=0.638 %>0=96.9% %>1.5=0.0% first5=[1.2708740234375, 0.6147150993347168, 0.7081261873245239, 0.5087354183197021, 1.0190448760986328]
# sup_step_16 | mean=0.604 std=0.411 median=0.638 %>0=96.9% %>1.5=0.0% first5=[1.2704172134399414, 0.6146547794342041, 0.7081272602081299, 0.5087356567382812, 1.0190449953079224]
#
# Validation Accuracy: 52.06%
# validation halt steps: mean=1.61 median=1 %step1=93.5% %never=3.8% dist={1: 4677, 2: 106, 16: 191, 3: 17, 5: 2, 6: 1, 4: 2, 7: 1, 12: 3}
# Training processed epoch 41
# Training processed epoch 42
# Training processed epoch 43
# Training processed epoch 44
# Training processed epoch 45
# Training processed epoch 46
# Training processed epoch 47
# Training processed epoch 48
# Training processed epoch 49
# Training processed epoch 50
#  Training epoch 50 | CE: 0.3082 | Q-Loss: 0.5934 | Avg Steps: 10.985785358919687
# halt logit: mean=0.720 std=0.699 max=3.676 %>0=85.7% %>1.5=13.0%
# halt steps: mean=2.38 median=1 %step1=89.3% %never=9.1% dist={16: 4077, 1: 40199, 2: 632, 3: 79, 4: 9, 5: 3, 6: 1}
#
# Validation Logs ------
#
# sup_step_1 | mean=1.860 std=0.902 median=1.715 %>0=96.9% %>1.5=59.4% first5=[2.9587862491607666, 1.2238644361495972, 3.097273588180542, 2.6984171867370605, 1.4413179159164429]
# sup_step_2 | mean=1.922 std=0.940 median=1.724 %>0=100.0% %>1.5=59.4% first5=[3.1900110244750977, 1.136900782585144, 3.2249975204467773, 2.669677495956421, 1.3019888401031494]
#
# Validation Accuracy: 85.80%
# validation halt steps: mean=1.06 median=1 %step1=99.5% %never=0.4% dist={1: 4973, 2: 6, 16: 19, 4: 2}
# Training processed epoch 51
# Training processed epoch 52
# Training processed epoch 53
# Training processed epoch 54
# Training processed epoch 55
# Training processed epoch 56
# Training processed epoch 57
# Training processed epoch 58
# Training processed epoch 59
# Training processed epoch 60
#  Training epoch 60 | CE: 0.2086 | Q-Loss: 0.3989 | Avg Steps: 6.357498223169865
# halt logit: mean=0.710 std=0.923 max=6.222 %>0=83.9% %>1.5=10.8%
# halt steps: mean=1.87 median=1 %step1=93.6% %never=5.8% dist={1: 42130, 16: 2593, 9: 1, 2: 235, 3: 30, 4: 7, 5: 3, 8: 1}
#
# Validation Logs ------
#
# sup_step_1 | mean=3.803 std=0.947 median=3.790 %>0=100.0% %>1.5=100.0% first5=[5.054182052612305, 3.801391124725342, 5.2762956619262695, 4.380937099456787, 4.268402099609375]
#
# Validation Accuracy: 96.54%
# validation halt steps: mean=1.00 median=1 %step1=100.0% %never=0.0% dist={1: 5000}
# Training processed epoch 61
# Training processed epoch 62
# Training processed epoch 63
# Training processed epoch 64
# Training processed epoch 65
# Training processed epoch 66
# Training processed epoch 67
# Training processed epoch 68
# Training processed epoch 69
# Training processed epoch 70
#  Training epoch 70 | CE: 0.0147 | Q-Loss: 0.0655 | Avg Steps: 1.0127931769722816
# halt logit: mean=4.808 std=1.170 max=8.674 %>0=100.0% %>1.5=99.6%
# halt steps: mean=1.00 median=1 %step1=100.0% %never=0.0% dist={1: 44997, 16: 1, 2: 1, 3: 1}
#
# Validation Logs ------
#
# sup_step_1 | mean=5.494 std=1.385 median=5.282 %>0=100.0% %>1.5=100.0% first5=[7.238637924194336, 5.0323872566223145, 6.904803276062012, 6.076685905456543, 6.519742012023926]
#
# Validation Accuracy: 98.72%
# validation halt steps: mean=1.00 median=1 %step1=100.0% %never=0.0% dist={1: 5000}
# Training processed epoch 71
# Training processed epoch 72
# Training processed epoch 73
# Training processed epoch 74
# Training processed epoch 75
# Training processed epoch 76
# Training processed epoch 77
# Training processed epoch 78
# Training processed epoch 79
# Training processed epoch 80
#  Training epoch 80 | CE: 0.0104 | Q-Loss: 0.0500 | Avg Steps: 1.0
# halt logit: mean=5.048 std=0.963 max=8.194 %>0=100.0% %>1.5=100.0%
# halt steps: mean=1.00 median=1 %step1=100.0% %never=0.0% dist={1: 45000}
#
# Validation Logs ------
#
# sup_step_1 | mean=5.182 std=1.165 median=5.231 %>0=100.0% %>1.5=96.9% first5=[6.910695552825928, 4.836152076721191, 5.443209648132324, 5.705259799957275, 8.227656364440918]
#
# Validation Accuracy: 98.24%
# validation halt steps: mean=1.00 median=1 %step1=100.0% %never=0.0% dist={1: 5000}
# Training processed epoch 81
# Training processed epoch 82
# Training processed epoch 83
# Training processed epoch 84
# Training processed epoch 85
# Training processed epoch 86
# Training processed epoch 87
# Training processed epoch 88
# Training processed epoch 89
# Training processed epoch 90
#  Training epoch 90 | CE: 0.0121 | Q-Loss: 0.0612 | Avg Steps: 1.0
# halt logit: mean=4.800 std=1.043 max=9.294 %>0=100.0% %>1.5=99.9%
# halt steps: mean=1.00 median=1 %step1=100.0% %never=0.0% dist={1: 45000}
#
# Validation Logs ------
#
# sup_step_1 | mean=5.217 std=1.093 median=5.184 %>0=100.0% %>1.5=100.0% first5=[5.998239517211914, 4.0760393142700195, 5.1109819412231445, 6.277823448181152, 5.752140522003174]
#
# Validation Accuracy: 99.06%
# validation halt steps: mean=1.00 median=1 %step1=100.0% %never=0.0% dist={1: 5000}
# Training processed epoch 91
# Training processed epoch 92
# Training processed epoch 93
# Training processed epoch 94
# Training processed epoch 95
# Training processed epoch 96
# Training processed epoch 97
# Training processed epoch 98
# Training processed epoch 99

# %% [markdown]
# ## Key Observations
#
# - Using mean loss across steps harms per-example optimization
# - If q_halt becomes negative early, future optimization is skipped
# - Masking improves stability by preserving active samples

# %% [markdown]
# ### Key Observation: Effect of Halting Coefficient (c)
#
# - c controls the trade-off between prediction and halting behavior
# - With small c (0.01), model halts after 1 step (n_taken = 1)
# - This reduces effective reasoning depth despite high accuracy
# - Indicates that halting must be carefully balanced to enable multi-step reasoning
